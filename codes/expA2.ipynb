# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    #transforms.RandomRotation(degrees=15), 
    #transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA2.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.9827, Train Acc: 28.44%, Test Loss: 1.5634, Test Acc: 41.09%
# New best model saved with accuracy: 41.09%
# Epoch 2/200: Train Loss: 1.4679, Train Acc: 45.97%, Test Loss: 1.2640, Test Acc: 53.49%
# New best model saved with accuracy: 53.49%
# Epoch 3/200: Train Loss: 1.2029, Train Acc: 56.59%, Test Loss: 1.0547, Test Acc: 62.87%
# New best model saved with accuracy: 62.87%
# Epoch 4/200: Train Loss: 0.9615, Train Acc: 65.75%, Test Loss: 1.0550, Test Acc: 64.87%
# New best model saved with accuracy: 64.87%
# Epoch 5/200: Train Loss: 0.7942, Train Acc: 72.17%, Test Loss: 0.7444, Test Acc: 74.25%
# New best model saved with accuracy: 74.25%
# Epoch 6/200: Train Loss: 0.7016, Train Acc: 75.64%, Test Loss: 0.7421, Test Acc: 74.70%
# New best model saved with accuracy: 74.70%
# Epoch 7/200: Train Loss: 0.6372, Train Acc: 77.90%, Test Loss: 0.7522, Test Acc: 74.71%
# New best model saved with accuracy: 74.71%
# Epoch 8/200: Train Loss: 0.5913, Train Acc: 79.69%, Test Loss: 0.6086, Test Acc: 79.39%
# New best model saved with accuracy: 79.39%
# Epoch 9/200: Train Loss: 0.5543, Train Acc: 80.82%, Test Loss: 0.6513, Test Acc: 78.05%
# Epoch 10/200: Train Loss: 0.5398, Train Acc: 81.46%, Test Loss: 0.7385, Test Acc: 75.03%
# Epoch 11/200: Train Loss: 0.5175, Train Acc: 82.38%, Test Loss: 0.6390, Test Acc: 79.13%
# Epoch 12/200: Train Loss: 0.5020, Train Acc: 82.88%, Test Loss: 1.0928, Test Acc: 68.58%
# Epoch 13/200: Train Loss: 0.4896, Train Acc: 83.16%, Test Loss: 0.6527, Test Acc: 78.28%
# Epoch 14/200: Train Loss: 0.4828, Train Acc: 83.50%, Test Loss: 0.5505, Test Acc: 81.53%
# New best model saved with accuracy: 81.53%
# Epoch 15/200: Train Loss: 0.4716, Train Acc: 83.73%, Test Loss: 0.6688, Test Acc: 78.47%
# Epoch 16/200: Train Loss: 0.4583, Train Acc: 84.25%, Test Loss: 0.4738, Test Acc: 83.75%
# New best model saved with accuracy: 83.75%
# Epoch 17/200: Train Loss: 0.4577, Train Acc: 84.37%, Test Loss: 0.5051, Test Acc: 82.98%
# Epoch 18/200: Train Loss: 0.4470, Train Acc: 84.66%, Test Loss: 0.5626, Test Acc: 81.67%
# Epoch 19/200: Train Loss: 0.4436, Train Acc: 84.79%, Test Loss: 0.5023, Test Acc: 82.26%
# Epoch 20/200: Train Loss: 0.4292, Train Acc: 85.43%, Test Loss: 0.6069, Test Acc: 79.96%
# Epoch 21/200: Train Loss: 0.4253, Train Acc: 85.54%, Test Loss: 0.5777, Test Acc: 80.44%
# Epoch 22/200: Train Loss: 0.4211, Train Acc: 85.52%, Test Loss: 0.5385, Test Acc: 81.82%
# Epoch 23/200: Train Loss: 0.4215, Train Acc: 85.83%, Test Loss: 0.6115, Test Acc: 80.55%
# Epoch 24/200: Train Loss: 0.4054, Train Acc: 86.14%, Test Loss: 0.4496, Test Acc: 84.97%
# New best model saved with accuracy: 84.97%
# Epoch 25/200: Train Loss: 0.4066, Train Acc: 86.12%, Test Loss: 0.6922, Test Acc: 78.46%
# Epoch 26/200: Train Loss: 0.4057, Train Acc: 86.25%, Test Loss: 0.3955, Test Acc: 86.78%
# New best model saved with accuracy: 86.78%
# Epoch 27/200: Train Loss: 0.4029, Train Acc: 86.23%, Test Loss: 0.4699, Test Acc: 84.51%
# Epoch 28/200: Train Loss: 0.3988, Train Acc: 86.45%, Test Loss: 0.5072, Test Acc: 83.30%
# Epoch 29/200: Train Loss: 0.3996, Train Acc: 86.39%, Test Loss: 0.5332, Test Acc: 82.12%
# Epoch 30/200: Train Loss: 0.3931, Train Acc: 86.63%, Test Loss: 0.6729, Test Acc: 77.85%
# Epoch 31/200: Train Loss: 0.3930, Train Acc: 86.47%, Test Loss: 0.5518, Test Acc: 81.48%
# Epoch 32/200: Train Loss: 0.3860, Train Acc: 86.74%, Test Loss: 0.6709, Test Acc: 78.85%
# Epoch 33/200: Train Loss: 0.3859, Train Acc: 86.88%, Test Loss: 0.5347, Test Acc: 81.93%
# Epoch 34/200: Train Loss: 0.3830, Train Acc: 87.00%, Test Loss: 0.5769, Test Acc: 81.35%
# Epoch 35/200: Train Loss: 0.3863, Train Acc: 86.81%, Test Loss: 0.5520, Test Acc: 82.02%
# Epoch 36/200: Train Loss: 0.3800, Train Acc: 87.16%, Test Loss: 0.4037, Test Acc: 86.36%
# Epoch 37/200: Train Loss: 0.3820, Train Acc: 86.96%, Test Loss: 0.4825, Test Acc: 84.63%
# Epoch 38/200: Train Loss: 0.3837, Train Acc: 86.98%, Test Loss: 0.4405, Test Acc: 85.05%
# Epoch 39/200: Train Loss: 0.3816, Train Acc: 87.06%, Test Loss: 0.5003, Test Acc: 83.42%
# Epoch 40/200: Train Loss: 0.3809, Train Acc: 87.14%, Test Loss: 0.5569, Test Acc: 81.82%
# Epoch 41/200: Train Loss: 0.3835, Train Acc: 86.85%, Test Loss: 0.4653, Test Acc: 84.24%
# Epoch 42/200: Train Loss: 0.3739, Train Acc: 87.38%, Test Loss: 0.7781, Test Acc: 76.28%
# Epoch 43/200: Train Loss: 0.3743, Train Acc: 87.28%, Test Loss: 0.5148, Test Acc: 83.38%
# Epoch 44/200: Train Loss: 0.3708, Train Acc: 87.29%, Test Loss: 0.3935, Test Acc: 86.42%
# Epoch 45/200: Train Loss: 0.3762, Train Acc: 87.04%, Test Loss: 0.6002, Test Acc: 80.84%
# Epoch 46/200: Train Loss: 0.3702, Train Acc: 87.53%, Test Loss: 0.4646, Test Acc: 84.63%
# Epoch 47/200: Train Loss: 0.3730, Train Acc: 87.23%, Test Loss: 0.5427, Test Acc: 82.31%
# Epoch 48/200: Train Loss: 0.3660, Train Acc: 87.52%, Test Loss: 0.5384, Test Acc: 82.35%
# Epoch 49/200: Train Loss: 0.3718, Train Acc: 87.42%, Test Loss: 0.5387, Test Acc: 82.36%
# Epoch 50/200: Train Loss: 0.3671, Train Acc: 87.52%, Test Loss: 0.5578, Test Acc: 82.07%
# Epoch 51/200: Train Loss: 0.3616, Train Acc: 87.66%, Test Loss: 0.4991, Test Acc: 83.82%
# Epoch 52/200: Train Loss: 0.3728, Train Acc: 87.36%, Test Loss: 0.6734, Test Acc: 79.36%
# Epoch 53/200: Train Loss: 0.3604, Train Acc: 87.79%, Test Loss: 0.5665, Test Acc: 81.21%
# Epoch 54/200: Train Loss: 0.3663, Train Acc: 87.49%, Test Loss: 0.5020, Test Acc: 82.79%
# Epoch 55/200: Train Loss: 0.3645, Train Acc: 87.72%, Test Loss: 0.4428, Test Acc: 85.34%
# Epoch 56/200: Train Loss: 0.3564, Train Acc: 87.84%, Test Loss: 0.6242, Test Acc: 79.99%
# Epoch 57/200: Train Loss: 0.3646, Train Acc: 87.60%, Test Loss: 0.4418, Test Acc: 85.18%
# Epoch 58/200: Train Loss: 0.3649, Train Acc: 87.46%, Test Loss: 0.5909, Test Acc: 80.70%
# Epoch 59/200: Train Loss: 0.3616, Train Acc: 87.57%, Test Loss: 0.5803, Test Acc: 80.75%
# Epoch 60/200: Train Loss: 0.3630, Train Acc: 87.61%, Test Loss: 0.4601, Test Acc: 85.16%
# Epoch 61/200: Train Loss: 0.3600, Train Acc: 87.74%, Test Loss: 0.5916, Test Acc: 81.21%
# Epoch 62/200: Train Loss: 0.3643, Train Acc: 87.70%, Test Loss: 0.5730, Test Acc: 82.21%
# Epoch 63/200: Train Loss: 0.3598, Train Acc: 87.76%, Test Loss: 0.5329, Test Acc: 81.81%
# Epoch 64/200: Train Loss: 0.3659, Train Acc: 87.57%, Test Loss: 0.4340, Test Acc: 85.42%
# Epoch 65/200: Train Loss: 0.3507, Train Acc: 87.97%, Test Loss: 0.5030, Test Acc: 82.98%
# Epoch 66/200: Train Loss: 0.3540, Train Acc: 87.87%, Test Loss: 0.4732, Test Acc: 84.21%
# Epoch 67/200: Train Loss: 0.3636, Train Acc: 87.62%, Test Loss: 0.5178, Test Acc: 83.04%
# Epoch 68/200: Train Loss: 0.3513, Train Acc: 88.08%, Test Loss: 0.4178, Test Acc: 86.30%
# Epoch 69/200: Train Loss: 0.3638, Train Acc: 87.72%, Test Loss: 0.4682, Test Acc: 83.93%
# Epoch 70/200: Train Loss: 0.3506, Train Acc: 88.19%, Test Loss: 0.4855, Test Acc: 84.17%
# Epoch 71/200: Train Loss: 0.2009, Train Acc: 93.23%, Test Loss: 0.2155, Test Acc: 92.59%
# New best model saved with accuracy: 92.59%
# Epoch 72/200: Train Loss: 0.1530, Train Acc: 94.88%, Test Loss: 0.2098, Test Acc: 92.74%
# New best model saved with accuracy: 92.74%
# Epoch 73/200: Train Loss: 0.1310, Train Acc: 95.60%, Test Loss: 0.1966, Test Acc: 93.36%
# New best model saved with accuracy: 93.36%
# Epoch 74/200: Train Loss: 0.1157, Train Acc: 96.10%, Test Loss: 0.1911, Test Acc: 93.41%
# New best model saved with accuracy: 93.41%
# Epoch 75/200: Train Loss: 0.1059, Train Acc: 96.46%, Test Loss: 0.1949, Test Acc: 93.41%
# Epoch 76/200: Train Loss: 0.0980, Train Acc: 96.69%, Test Loss: 0.1899, Test Acc: 93.50%
# New best model saved with accuracy: 93.50%
# Epoch 77/200: Train Loss: 0.0905, Train Acc: 96.90%, Test Loss: 0.1904, Test Acc: 93.54%
# New best model saved with accuracy: 93.54%
# Epoch 78/200: Train Loss: 0.0817, Train Acc: 97.28%, Test Loss: 0.1978, Test Acc: 93.33%
# Epoch 79/200: Train Loss: 0.0784, Train Acc: 97.40%, Test Loss: 0.2027, Test Acc: 93.34%
# Epoch 80/200: Train Loss: 0.0701, Train Acc: 97.67%, Test Loss: 0.2058, Test Acc: 93.47%
# Epoch 81/200: Train Loss: 0.0676, Train Acc: 97.77%, Test Loss: 0.2110, Test Acc: 93.65%
# New best model saved with accuracy: 93.65%
# Epoch 82/200: Train Loss: 0.0622, Train Acc: 97.97%, Test Loss: 0.2085, Test Acc: 93.69%
# New best model saved with accuracy: 93.69%
# Epoch 83/200: Train Loss: 0.0622, Train Acc: 97.89%, Test Loss: 0.2169, Test Acc: 93.42%
# Epoch 84/200: Train Loss: 0.0595, Train Acc: 98.03%, Test Loss: 0.2125, Test Acc: 93.44%
# Epoch 85/200: Train Loss: 0.0555, Train Acc: 98.19%, Test Loss: 0.2110, Test Acc: 93.55%
# Epoch 86/200: Train Loss: 0.0559, Train Acc: 98.20%, Test Loss: 0.2133, Test Acc: 93.57%
# Epoch 87/200: Train Loss: 0.0519, Train Acc: 98.24%, Test Loss: 0.2172, Test Acc: 93.72%
# New best model saved with accuracy: 93.72%
# Epoch 88/200: Train Loss: 0.0571, Train Acc: 98.08%, Test Loss: 0.2168, Test Acc: 93.47%
# Epoch 89/200: Train Loss: 0.0537, Train Acc: 98.22%, Test Loss: 0.2335, Test Acc: 92.99%
# Epoch 90/200: Train Loss: 0.0516, Train Acc: 98.33%, Test Loss: 0.2300, Test Acc: 93.24%
# Epoch 91/200: Train Loss: 0.0492, Train Acc: 98.34%, Test Loss: 0.2222, Test Acc: 93.62%
# Epoch 92/200: Train Loss: 0.0506, Train Acc: 98.36%, Test Loss: 0.2274, Test Acc: 93.57%
# Epoch 93/200: Train Loss: 0.0526, Train Acc: 98.24%, Test Loss: 0.2135, Test Acc: 93.71%
# Epoch 94/200: Train Loss: 0.0521, Train Acc: 98.30%, Test Loss: 0.2638, Test Acc: 92.44%
# Epoch 95/200: Train Loss: 0.0523, Train Acc: 98.30%, Test Loss: 0.2626, Test Acc: 92.51%
# Epoch 96/200: Train Loss: 0.0500, Train Acc: 98.41%, Test Loss: 0.2439, Test Acc: 93.24%
# Epoch 97/200: Train Loss: 0.0526, Train Acc: 98.27%, Test Loss: 0.2428, Test Acc: 93.06%
# Epoch 98/200: Train Loss: 0.0520, Train Acc: 98.28%, Test Loss: 0.2387, Test Acc: 93.04%
# Epoch 99/200: Train Loss: 0.0569, Train Acc: 98.04%, Test Loss: 0.2420, Test Acc: 93.01%
# Epoch 100/200: Train Loss: 0.0538, Train Acc: 98.30%, Test Loss: 0.2410, Test Acc: 92.95%
# Epoch 101/200: Train Loss: 0.0546, Train Acc: 98.16%, Test Loss: 0.2446, Test Acc: 92.81%
# Epoch 102/200: Train Loss: 0.0539, Train Acc: 98.23%, Test Loss: 0.2785, Test Acc: 92.08%
# Epoch 103/200: Train Loss: 0.0505, Train Acc: 98.36%, Test Loss: 0.2373, Test Acc: 93.05%
# Epoch 104/200: Train Loss: 0.0546, Train Acc: 98.19%, Test Loss: 0.2571, Test Acc: 92.64%
# Epoch 105/200: Train Loss: 0.0565, Train Acc: 98.14%, Test Loss: 0.2614, Test Acc: 92.25%
# Epoch 106/200: Train Loss: 0.0555, Train Acc: 98.06%, Test Loss: 0.2638, Test Acc: 92.42%
# Epoch 107/200: Train Loss: 0.0596, Train Acc: 97.96%, Test Loss: 0.2494, Test Acc: 92.47%
# Epoch 108/200: Train Loss: 0.0565, Train Acc: 98.12%, Test Loss: 0.2943, Test Acc: 91.57%
# Epoch 109/200: Train Loss: 0.0582, Train Acc: 98.03%, Test Loss: 0.2595, Test Acc: 92.59%
# Epoch 110/200: Train Loss: 0.0598, Train Acc: 97.94%, Test Loss: 0.2584, Test Acc: 92.55%
# Epoch 111/200: Train Loss: 0.0588, Train Acc: 98.06%, Test Loss: 0.2537, Test Acc: 92.68%
# Epoch 112/200: Train Loss: 0.0599, Train Acc: 98.02%, Test Loss: 0.2673, Test Acc: 92.16%
# Epoch 113/200: Train Loss: 0.0583, Train Acc: 98.02%, Test Loss: 0.2705, Test Acc: 92.20%
# Epoch 114/200: Train Loss: 0.0585, Train Acc: 98.03%, Test Loss: 0.2405, Test Acc: 92.84%
# Epoch 115/200: Train Loss: 0.0577, Train Acc: 98.14%, Test Loss: 0.2765, Test Acc: 92.07%
# Epoch 116/200: Train Loss: 0.0610, Train Acc: 97.98%, Test Loss: 0.2683, Test Acc: 92.15%
# Epoch 117/200: Train Loss: 0.0591, Train Acc: 98.00%, Test Loss: 0.2803, Test Acc: 91.82%
# Epoch 118/200: Train Loss: 0.0624, Train Acc: 97.92%, Test Loss: 0.2464, Test Acc: 93.04%
# Epoch 119/200: Train Loss: 0.0606, Train Acc: 98.00%, Test Loss: 0.2772, Test Acc: 92.31%
# Epoch 120/200: Train Loss: 0.0632, Train Acc: 97.87%, Test Loss: 0.2720, Test Acc: 92.56%
# Epoch 121/200: Train Loss: 0.0318, Train Acc: 99.04%, Test Loss: 0.2085, Test Acc: 93.86%
# New best model saved with accuracy: 93.86%
# Epoch 122/200: Train Loss: 0.0199, Train Acc: 99.47%, Test Loss: 0.2025, Test Acc: 94.19%
# New best model saved with accuracy: 94.19%
# Epoch 123/200: Train Loss: 0.0168, Train Acc: 99.57%, Test Loss: 0.1991, Test Acc: 94.27%
# New best model saved with accuracy: 94.27%
# Epoch 124/200: Train Loss: 0.0145, Train Acc: 99.62%, Test Loss: 0.1986, Test Acc: 94.57%
# New best model saved with accuracy: 94.57%
# Epoch 125/200: Train Loss: 0.0127, Train Acc: 99.67%, Test Loss: 0.1992, Test Acc: 94.44%
# Epoch 126/200: Train Loss: 0.0115, Train Acc: 99.71%, Test Loss: 0.1992, Test Acc: 94.52%
# Epoch 127/200: Train Loss: 0.0102, Train Acc: 99.77%, Test Loss: 0.1987, Test Acc: 94.49%
# Epoch 128/200: Train Loss: 0.0101, Train Acc: 99.78%, Test Loss: 0.2002, Test Acc: 94.58%
# New best model saved with accuracy: 94.58%
# Epoch 129/200: Train Loss: 0.0091, Train Acc: 99.81%, Test Loss: 0.1988, Test Acc: 94.48%
# Epoch 130/200: Train Loss: 0.0088, Train Acc: 99.81%, Test Loss: 0.2010, Test Acc: 94.46%
# Epoch 131/200: Train Loss: 0.0086, Train Acc: 99.81%, Test Loss: 0.1980, Test Acc: 94.56%
# Epoch 132/200: Train Loss: 0.0076, Train Acc: 99.85%, Test Loss: 0.1994, Test Acc: 94.60%
# New best model saved with accuracy: 94.60%
# Epoch 133/200: Train Loss: 0.0076, Train Acc: 99.83%, Test Loss: 0.2020, Test Acc: 94.52%
# Epoch 134/200: Train Loss: 0.0069, Train Acc: 99.87%, Test Loss: 0.1995, Test Acc: 94.67%
# New best model saved with accuracy: 94.67%
# Epoch 135/200: Train Loss: 0.0068, Train Acc: 99.86%, Test Loss: 0.2020, Test Acc: 94.55%
# Epoch 136/200: Train Loss: 0.0067, Train Acc: 99.88%, Test Loss: 0.2010, Test Acc: 94.70%
# New best model saved with accuracy: 94.70%
# Epoch 137/200: Train Loss: 0.0067, Train Acc: 99.86%, Test Loss: 0.1996, Test Acc: 94.70%
# Epoch 138/200: Train Loss: 0.0063, Train Acc: 99.88%, Test Loss: 0.2008, Test Acc: 94.66%
# Epoch 139/200: Train Loss: 0.0061, Train Acc: 99.89%, Test Loss: 0.2031, Test Acc: 94.68%
# Epoch 140/200: Train Loss: 0.0059, Train Acc: 99.88%, Test Loss: 0.2028, Test Acc: 94.61%
# Epoch 141/200: Train Loss: 0.0053, Train Acc: 99.92%, Test Loss: 0.2052, Test Acc: 94.65%
# Epoch 142/200: Train Loss: 0.0053, Train Acc: 99.92%, Test Loss: 0.2037, Test Acc: 94.78%
# New best model saved with accuracy: 94.78%
# Epoch 143/200: Train Loss: 0.0054, Train Acc: 99.91%, Test Loss: 0.2019, Test Acc: 94.60%
# Epoch 144/200: Train Loss: 0.0052, Train Acc: 99.91%, Test Loss: 0.2024, Test Acc: 94.66%
# Epoch 145/200: Train Loss: 0.0046, Train Acc: 99.95%, Test Loss: 0.2015, Test Acc: 94.69%
# Epoch 146/200: Train Loss: 0.0052, Train Acc: 99.90%, Test Loss: 0.1990, Test Acc: 94.72%
# Epoch 147/200: Train Loss: 0.0053, Train Acc: 99.91%, Test Loss: 0.2000, Test Acc: 94.73%
# Epoch 148/200: Train Loss: 0.0054, Train Acc: 99.89%, Test Loss: 0.1997, Test Acc: 94.81%
# New best model saved with accuracy: 94.81%
# Epoch 149/200: Train Loss: 0.0049, Train Acc: 99.92%, Test Loss: 0.2022, Test Acc: 94.67%
# Epoch 150/200: Train Loss: 0.0050, Train Acc: 99.91%, Test Loss: 0.2028, Test Acc: 94.68%
# Epoch 151/200: Train Loss: 0.0046, Train Acc: 99.92%, Test Loss: 0.2032, Test Acc: 94.68%
# Epoch 152/200: Train Loss: 0.0045, Train Acc: 99.92%, Test Loss: 0.2009, Test Acc: 94.53%
# Epoch 153/200: Train Loss: 0.0040, Train Acc: 99.96%, Test Loss: 0.1997, Test Acc: 94.56%
# Epoch 154/200: Train Loss: 0.0042, Train Acc: 99.94%, Test Loss: 0.1993, Test Acc: 94.71%
# Epoch 155/200: Train Loss: 0.0044, Train Acc: 99.94%, Test Loss: 0.2006, Test Acc: 94.62%
# Epoch 156/200: Train Loss: 0.0041, Train Acc: 99.95%, Test Loss: 0.2023, Test Acc: 94.77%
# Epoch 157/200: Train Loss: 0.0038, Train Acc: 99.94%, Test Loss: 0.2022, Test Acc: 94.61%
# Epoch 158/200: Train Loss: 0.0043, Train Acc: 99.93%, Test Loss: 0.2000, Test Acc: 94.69%
# Epoch 159/200: Train Loss: 0.0041, Train Acc: 99.93%, Test Loss: 0.2007, Test Acc: 94.66%
# Epoch 160/200: Train Loss: 0.0040, Train Acc: 99.94%, Test Loss: 0.1997, Test Acc: 94.68%
# Epoch 161/200: Train Loss: 0.0042, Train Acc: 99.94%, Test Loss: 0.1986, Test Acc: 94.64%
# Epoch 162/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.1998, Test Acc: 94.67%
# Epoch 163/200: Train Loss: 0.0039, Train Acc: 99.94%, Test Loss: 0.2002, Test Acc: 94.67%
# Epoch 164/200: Train Loss: 0.0037, Train Acc: 99.96%, Test Loss: 0.1998, Test Acc: 94.66%
# Epoch 165/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.1991, Test Acc: 94.70%
# Epoch 166/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1990, Test Acc: 94.74%
# Epoch 167/200: Train Loss: 0.0037, Train Acc: 99.96%, Test Loss: 0.1990, Test Acc: 94.64%
# Epoch 168/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.1988, Test Acc: 94.68%
# Epoch 169/200: Train Loss: 0.0040, Train Acc: 99.94%, Test Loss: 0.1981, Test Acc: 94.71%
# Epoch 170/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1994, Test Acc: 94.61%
# Epoch 171/200: Train Loss: 0.0037, Train Acc: 99.94%, Test Loss: 0.1984, Test Acc: 94.77%
# Epoch 172/200: Train Loss: 0.0039, Train Acc: 99.92%, Test Loss: 0.2005, Test Acc: 94.76%
# Epoch 173/200: Train Loss: 0.0038, Train Acc: 99.95%, Test Loss: 0.1974, Test Acc: 94.70%
# Epoch 174/200: Train Loss: 0.0037, Train Acc: 99.93%, Test Loss: 0.1983, Test Acc: 94.77%
# Epoch 175/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.1973, Test Acc: 94.71%
# Epoch 176/200: Train Loss: 0.0032, Train Acc: 99.97%, Test Loss: 0.1986, Test Acc: 94.68%
# Epoch 177/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.1980, Test Acc: 94.66%
# Epoch 178/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1994, Test Acc: 94.70%
# Epoch 179/200: Train Loss: 0.0035, Train Acc: 99.95%, Test Loss: 0.1978, Test Acc: 94.72%
# Epoch 180/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.1984, Test Acc: 94.69%
# Epoch 181/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1972, Test Acc: 94.72%
# Epoch 182/200: Train Loss: 0.0035, Train Acc: 99.95%, Test Loss: 0.1980, Test Acc: 94.80%
# Epoch 183/200: Train Loss: 0.0034, Train Acc: 99.97%, Test Loss: 0.1977, Test Acc: 94.75%
# Epoch 184/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1977, Test Acc: 94.68%
# Epoch 185/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1970, Test Acc: 94.72%
# Epoch 186/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1988, Test Acc: 94.70%
# Epoch 187/200: Train Loss: 0.0028, Train Acc: 99.98%, Test Loss: 0.1976, Test Acc: 94.69%
# Epoch 188/200: Train Loss: 0.0038, Train Acc: 99.94%, Test Loss: 0.1986, Test Acc: 94.71%
# Epoch 189/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1984, Test Acc: 94.75%
# Epoch 190/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.1986, Test Acc: 94.77%
# Epoch 191/200: Train Loss: 0.0032, Train Acc: 99.96%, Test Loss: 0.1985, Test Acc: 94.73%
# Epoch 192/200: Train Loss: 0.0035, Train Acc: 99.95%, Test Loss: 0.1980, Test Acc: 94.72%
# Epoch 193/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.1968, Test Acc: 94.76%
# Epoch 194/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.1976, Test Acc: 94.74%
# Epoch 195/200: Train Loss: 0.0036, Train Acc: 99.94%, Test Loss: 0.1975, Test Acc: 94.71%
# Epoch 196/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1975, Test Acc: 94.76%
# Epoch 197/200: Train Loss: 0.0034, Train Acc: 99.97%, Test Loss: 0.1978, Test Acc: 94.70%
# Epoch 198/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.1979, Test Acc: 94.73%
# Epoch 199/200: Train Loss: 0.0032, Train Acc: 99.97%, Test Loss: 0.1980, Test Acc: 94.75%
# Epoch 200/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1961, Test Acc: 94.68%
# Training completed! Best accuracy: 94.81%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估

if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA2.pth'):
        checkpoint = torch.load('model/best_modelA2.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 94%
# Accuracy of car   : 97%
# Accuracy of bird  : 93%
# Accuracy of cat   : 87%
# Accuracy of deer  : 97%
# Accuracy of dog   : 92%
# Accuracy of frog  : 97%
# Accuracy of horse : 97%
# Accuracy of ship  : 97%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.95      0.94      0.95      1000
#          car       0.97      0.97      0.97      1000
#         bird       0.93      0.93      0.93      1000
#          cat       0.90      0.87      0.89      1000
#         deer       0.95      0.97      0.96      1000
#          dog       0.91      0.92      0.91      1000
#         frog       0.97      0.97      0.97      1000
#        horse       0.97      0.97      0.97      1000
#         ship       0.97      0.97      0.97      1000
#        truck       0.97      0.96      0.96      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
