# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    #transforms.RandomRotation(degrees=15), 
    #transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA2.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.9917, Train Acc: 29.37%, Test Loss: 1.5564, Test Acc: 41.21%
# New best model saved with accuracy: 41.21%
# Epoch 2/200: Train Loss: 1.5057, Train Acc: 44.69%, Test Loss: 1.3320, Test Acc: 51.91%
# New best model saved with accuracy: 51.91%
# Epoch 3/200: Train Loss: 1.1696, Train Acc: 57.94%, Test Loss: 1.1073, Test Acc: 61.48%
# New best model saved with accuracy: 61.48%
# Epoch 4/200: Train Loss: 0.9149, Train Acc: 67.60%, Test Loss: 1.0599, Test Acc: 64.28%
# New best model saved with accuracy: 64.28%
# Epoch 5/200: Train Loss: 0.7671, Train Acc: 73.26%, Test Loss: 0.9135, Test Acc: 70.02%
# New best model saved with accuracy: 70.02%
# Epoch 6/200: Train Loss: 0.6779, Train Acc: 76.64%, Test Loss: 0.7039, Test Acc: 76.25%
# New best model saved with accuracy: 76.25%
# Epoch 7/200: Train Loss: 0.6184, Train Acc: 78.77%, Test Loss: 0.7274, Test Acc: 74.24%
# Epoch 8/200: Train Loss: 0.5758, Train Acc: 80.23%, Test Loss: 0.7825, Test Acc: 74.08%
# Epoch 9/200: Train Loss: 0.5567, Train Acc: 80.78%, Test Loss: 0.8683, Test Acc: 71.91%
# Epoch 10/200: Train Loss: 0.5372, Train Acc: 81.73%, Test Loss: 0.5824, Test Acc: 80.65%
# New best model saved with accuracy: 80.65%
# Epoch 11/200: Train Loss: 0.5219, Train Acc: 82.32%, Test Loss: 0.8392, Test Acc: 74.29%
# Epoch 12/200: Train Loss: 0.4963, Train Acc: 83.04%, Test Loss: 0.5926, Test Acc: 79.99%
# Epoch 13/200: Train Loss: 0.4877, Train Acc: 83.33%, Test Loss: 0.5689, Test Acc: 81.10%
# New best model saved with accuracy: 81.10%
# Epoch 14/200: Train Loss: 0.4759, Train Acc: 83.61%, Test Loss: 0.5365, Test Acc: 82.02%
# New best model saved with accuracy: 82.02%
# Epoch 15/200: Train Loss: 0.4632, Train Acc: 84.10%, Test Loss: 0.8269, Test Acc: 74.46%
# Epoch 16/200: Train Loss: 0.4557, Train Acc: 84.30%, Test Loss: 0.9788, Test Acc: 72.03%
# Epoch 17/200: Train Loss: 0.4461, Train Acc: 84.81%, Test Loss: 0.6603, Test Acc: 78.89%
# Epoch 18/200: Train Loss: 0.4423, Train Acc: 84.74%, Test Loss: 0.5150, Test Acc: 82.28%
# New best model saved with accuracy: 82.28%
# Epoch 19/200: Train Loss: 0.4347, Train Acc: 85.08%, Test Loss: 0.5175, Test Acc: 82.63%
# New best model saved with accuracy: 82.63%
# Epoch 20/200: Train Loss: 0.4250, Train Acc: 85.50%, Test Loss: 0.4977, Test Acc: 82.88%
# New best model saved with accuracy: 82.88%
# Epoch 21/200: Train Loss: 0.4212, Train Acc: 85.61%, Test Loss: 0.5776, Test Acc: 81.35%
# Epoch 22/200: Train Loss: 0.4149, Train Acc: 85.75%, Test Loss: 0.5083, Test Acc: 83.54%
# New best model saved with accuracy: 83.54%
# Epoch 23/200: Train Loss: 0.4170, Train Acc: 85.76%, Test Loss: 0.5627, Test Acc: 82.43%
# Epoch 24/200: Train Loss: 0.4090, Train Acc: 86.00%, Test Loss: 0.5321, Test Acc: 82.44%
# Epoch 25/200: Train Loss: 0.4039, Train Acc: 86.45%, Test Loss: 0.4993, Test Acc: 83.39%
# Epoch 26/200: Train Loss: 0.4046, Train Acc: 86.42%, Test Loss: 0.6495, Test Acc: 79.83%
# Epoch 27/200: Train Loss: 0.4041, Train Acc: 86.30%, Test Loss: 0.5195, Test Acc: 82.59%
# Epoch 28/200: Train Loss: 0.3967, Train Acc: 86.39%, Test Loss: 0.4911, Test Acc: 82.91%
# Epoch 29/200: Train Loss: 0.3955, Train Acc: 86.54%, Test Loss: 0.5343, Test Acc: 82.75%
# Epoch 30/200: Train Loss: 0.3943, Train Acc: 86.50%, Test Loss: 0.6337, Test Acc: 80.15%
# Epoch 31/200: Train Loss: 0.3899, Train Acc: 86.82%, Test Loss: 0.5344, Test Acc: 82.30%
# Epoch 32/200: Train Loss: 0.3873, Train Acc: 86.84%, Test Loss: 0.6142, Test Acc: 80.55%
# Epoch 33/200: Train Loss: 0.3823, Train Acc: 86.91%, Test Loss: 0.4509, Test Acc: 84.74%
# New best model saved with accuracy: 84.74%
# Epoch 34/200: Train Loss: 0.3858, Train Acc: 86.87%, Test Loss: 0.5811, Test Acc: 81.40%
# Epoch 35/200: Train Loss: 0.3841, Train Acc: 86.84%, Test Loss: 0.5074, Test Acc: 83.54%
# Epoch 36/200: Train Loss: 0.3793, Train Acc: 87.02%, Test Loss: 0.6130, Test Acc: 80.62%
# Epoch 37/200: Train Loss: 0.3790, Train Acc: 87.23%, Test Loss: 0.5840, Test Acc: 81.57%
# Epoch 38/200: Train Loss: 0.3834, Train Acc: 86.93%, Test Loss: 0.5334, Test Acc: 82.03%
# Epoch 39/200: Train Loss: 0.3746, Train Acc: 87.26%, Test Loss: 0.5846, Test Acc: 81.32%
# Epoch 40/200: Train Loss: 0.3749, Train Acc: 87.17%, Test Loss: 0.4488, Test Acc: 85.03%
# New best model saved with accuracy: 85.03%
# Epoch 41/200: Train Loss: 0.3807, Train Acc: 87.01%, Test Loss: 0.6266, Test Acc: 79.79%
# Epoch 42/200: Train Loss: 0.3693, Train Acc: 87.42%, Test Loss: 0.5702, Test Acc: 81.95%
# Epoch 43/200: Train Loss: 0.3750, Train Acc: 87.18%, Test Loss: 0.4788, Test Acc: 84.33%
# Epoch 44/200: Train Loss: 0.3716, Train Acc: 87.50%, Test Loss: 0.4276, Test Acc: 85.44%
# New best model saved with accuracy: 85.44%
# Epoch 45/200: Train Loss: 0.3763, Train Acc: 87.31%, Test Loss: 0.5119, Test Acc: 83.35%
# Epoch 46/200: Train Loss: 0.3694, Train Acc: 87.50%, Test Loss: 0.6044, Test Acc: 80.73%
# Epoch 47/200: Train Loss: 0.3671, Train Acc: 87.65%, Test Loss: 0.6038, Test Acc: 80.10%
# Epoch 48/200: Train Loss: 0.3719, Train Acc: 87.31%, Test Loss: 0.5345, Test Acc: 82.61%
# Epoch 49/200: Train Loss: 0.3679, Train Acc: 87.52%, Test Loss: 0.4027, Test Acc: 86.85%
# New best model saved with accuracy: 86.85%
# Epoch 50/200: Train Loss: 0.3718, Train Acc: 87.31%, Test Loss: 0.5903, Test Acc: 80.22%
# Epoch 51/200: Train Loss: 0.3720, Train Acc: 87.52%, Test Loss: 0.5327, Test Acc: 82.16%
# Epoch 52/200: Train Loss: 0.3672, Train Acc: 87.48%, Test Loss: 0.6737, Test Acc: 78.90%
# Epoch 53/200: Train Loss: 0.3610, Train Acc: 87.58%, Test Loss: 0.4728, Test Acc: 85.10%
# Epoch 54/200: Train Loss: 0.3589, Train Acc: 87.77%, Test Loss: 0.8522, Test Acc: 74.95%
# Epoch 55/200: Train Loss: 0.3651, Train Acc: 87.52%, Test Loss: 0.5063, Test Acc: 83.24%
# Epoch 56/200: Train Loss: 0.3615, Train Acc: 87.74%, Test Loss: 0.4033, Test Acc: 86.46%
# Epoch 57/200: Train Loss: 0.3599, Train Acc: 87.95%, Test Loss: 0.4331, Test Acc: 85.69%
# Epoch 58/200: Train Loss: 0.3639, Train Acc: 87.70%, Test Loss: 0.6429, Test Acc: 80.55%
# Epoch 59/200: Train Loss: 0.3663, Train Acc: 87.58%, Test Loss: 0.4618, Test Acc: 84.38%
# Epoch 60/200: Train Loss: 0.3584, Train Acc: 87.81%, Test Loss: 0.5436, Test Acc: 82.65%
# Epoch 61/200: Train Loss: 0.3635, Train Acc: 87.64%, Test Loss: 0.4526, Test Acc: 85.33%
# Epoch 62/200: Train Loss: 0.3579, Train Acc: 87.87%, Test Loss: 0.6811, Test Acc: 79.11%
# Epoch 63/200: Train Loss: 0.3585, Train Acc: 87.85%, Test Loss: 0.6367, Test Acc: 79.65%
# Epoch 64/200: Train Loss: 0.3590, Train Acc: 87.79%, Test Loss: 0.4869, Test Acc: 83.61%
# Epoch 65/200: Train Loss: 0.3567, Train Acc: 87.88%, Test Loss: 0.5697, Test Acc: 81.21%
# Epoch 66/200: Train Loss: 0.3602, Train Acc: 87.75%, Test Loss: 0.4838, Test Acc: 84.25%
# Epoch 67/200: Train Loss: 0.3583, Train Acc: 87.86%, Test Loss: 0.4400, Test Acc: 85.09%
# Epoch 68/200: Train Loss: 0.3560, Train Acc: 87.99%, Test Loss: 0.4902, Test Acc: 83.99%
# Epoch 69/200: Train Loss: 0.3566, Train Acc: 87.84%, Test Loss: 0.5705, Test Acc: 81.93%
# Epoch 70/200: Train Loss: 0.3549, Train Acc: 87.85%, Test Loss: 0.5387, Test Acc: 82.17%
# Epoch 71/200: Train Loss: 0.2039, Train Acc: 93.20%, Test Loss: 0.2220, Test Acc: 92.48%
# New best model saved with accuracy: 92.48%
# Epoch 72/200: Train Loss: 0.1518, Train Acc: 94.89%, Test Loss: 0.2133, Test Acc: 92.78%
# New best model saved with accuracy: 92.78%
# Epoch 73/200: Train Loss: 0.1317, Train Acc: 95.55%, Test Loss: 0.2100, Test Acc: 93.04%
# New best model saved with accuracy: 93.04%
# Epoch 74/200: Train Loss: 0.1195, Train Acc: 95.98%, Test Loss: 0.2083, Test Acc: 93.01%
# Epoch 75/200: Train Loss: 0.1080, Train Acc: 96.36%, Test Loss: 0.2033, Test Acc: 93.41%
# New best model saved with accuracy: 93.41%
# Epoch 76/200: Train Loss: 0.0983, Train Acc: 96.70%, Test Loss: 0.2020, Test Acc: 93.26%
# Epoch 77/200: Train Loss: 0.0927, Train Acc: 96.92%, Test Loss: 0.2093, Test Acc: 93.21%
# Epoch 78/200: Train Loss: 0.0842, Train Acc: 97.14%, Test Loss: 0.2021, Test Acc: 93.45%
# New best model saved with accuracy: 93.45%
# Epoch 79/200: Train Loss: 0.0777, Train Acc: 97.43%, Test Loss: 0.2080, Test Acc: 93.36%
# Epoch 80/200: Train Loss: 0.0711, Train Acc: 97.62%, Test Loss: 0.2066, Test Acc: 93.42%
# Epoch 81/200: Train Loss: 0.0657, Train Acc: 97.79%, Test Loss: 0.2425, Test Acc: 92.52%
# Epoch 82/200: Train Loss: 0.0639, Train Acc: 97.81%, Test Loss: 0.2215, Test Acc: 93.24%
# Epoch 83/200: Train Loss: 0.0624, Train Acc: 97.87%, Test Loss: 0.2155, Test Acc: 93.28%
# Epoch 84/200: Train Loss: 0.0580, Train Acc: 98.10%, Test Loss: 0.2218, Test Acc: 93.24%
# Epoch 85/200: Train Loss: 0.0566, Train Acc: 98.13%, Test Loss: 0.2475, Test Acc: 92.90%
# Epoch 86/200: Train Loss: 0.0562, Train Acc: 98.08%, Test Loss: 0.2236, Test Acc: 93.33%
# Epoch 87/200: Train Loss: 0.0593, Train Acc: 98.01%, Test Loss: 0.2323, Test Acc: 93.23%
# Epoch 88/200: Train Loss: 0.0513, Train Acc: 98.36%, Test Loss: 0.2251, Test Acc: 93.58%
# New best model saved with accuracy: 93.58%
# Epoch 89/200: Train Loss: 0.0523, Train Acc: 98.29%, Test Loss: 0.2432, Test Acc: 93.07%
# Epoch 90/200: Train Loss: 0.0506, Train Acc: 98.32%, Test Loss: 0.2537, Test Acc: 92.90%
# Epoch 91/200: Train Loss: 0.0541, Train Acc: 98.15%, Test Loss: 0.2372, Test Acc: 93.18%
# Epoch 92/200: Train Loss: 0.0493, Train Acc: 98.38%, Test Loss: 0.2467, Test Acc: 93.07%
# Epoch 93/200: Train Loss: 0.0500, Train Acc: 98.31%, Test Loss: 0.2421, Test Acc: 93.20%
# Epoch 94/200: Train Loss: 0.0513, Train Acc: 98.35%, Test Loss: 0.2468, Test Acc: 92.91%
# Epoch 95/200: Train Loss: 0.0497, Train Acc: 98.37%, Test Loss: 0.2407, Test Acc: 93.02%
# Epoch 96/200: Train Loss: 0.0556, Train Acc: 98.11%, Test Loss: 0.2558, Test Acc: 92.78%
# Epoch 97/200: Train Loss: 0.0517, Train Acc: 98.29%, Test Loss: 0.2550, Test Acc: 92.77%
# Epoch 98/200: Train Loss: 0.0539, Train Acc: 98.24%, Test Loss: 0.2374, Test Acc: 93.16%
# Epoch 99/200: Train Loss: 0.0529, Train Acc: 98.26%, Test Loss: 0.2420, Test Acc: 93.08%
# Epoch 100/200: Train Loss: 0.0542, Train Acc: 98.22%, Test Loss: 0.2698, Test Acc: 92.42%
# Epoch 101/200: Train Loss: 0.0524, Train Acc: 98.30%, Test Loss: 0.2547, Test Acc: 92.87%
# Epoch 102/200: Train Loss: 0.0522, Train Acc: 98.31%, Test Loss: 0.2521, Test Acc: 92.73%
# Epoch 103/200: Train Loss: 0.0560, Train Acc: 98.09%, Test Loss: 0.2586, Test Acc: 92.51%
# Epoch 104/200: Train Loss: 0.0555, Train Acc: 98.18%, Test Loss: 0.2666, Test Acc: 92.50%
# Epoch 105/200: Train Loss: 0.0560, Train Acc: 98.10%, Test Loss: 0.2816, Test Acc: 92.12%
# Epoch 106/200: Train Loss: 0.0617, Train Acc: 97.87%, Test Loss: 0.2928, Test Acc: 91.68%
# Epoch 107/200: Train Loss: 0.0622, Train Acc: 97.94%, Test Loss: 0.2804, Test Acc: 92.10%
# Epoch 108/200: Train Loss: 0.0555, Train Acc: 98.20%, Test Loss: 0.2649, Test Acc: 92.33%
# Epoch 109/200: Train Loss: 0.0598, Train Acc: 98.00%, Test Loss: 0.2728, Test Acc: 92.34%
# Epoch 110/200: Train Loss: 0.0616, Train Acc: 97.91%, Test Loss: 0.2777, Test Acc: 92.05%
# Epoch 111/200: Train Loss: 0.0609, Train Acc: 97.98%, Test Loss: 0.2473, Test Acc: 92.75%
# Epoch 112/200: Train Loss: 0.0609, Train Acc: 98.02%, Test Loss: 0.2406, Test Acc: 92.91%
# Epoch 113/200: Train Loss: 0.0587, Train Acc: 98.04%, Test Loss: 0.2651, Test Acc: 92.38%
# Epoch 114/200: Train Loss: 0.0580, Train Acc: 98.04%, Test Loss: 0.2557, Test Acc: 92.98%
# Epoch 115/200: Train Loss: 0.0586, Train Acc: 98.10%, Test Loss: 0.2855, Test Acc: 91.92%
# Epoch 116/200: Train Loss: 0.0613, Train Acc: 98.00%, Test Loss: 0.2530, Test Acc: 92.44%
# Epoch 117/200: Train Loss: 0.0574, Train Acc: 98.12%, Test Loss: 0.3267, Test Acc: 91.25%
# Epoch 118/200: Train Loss: 0.0620, Train Acc: 97.90%, Test Loss: 0.2606, Test Acc: 92.74%
# Epoch 119/200: Train Loss: 0.0594, Train Acc: 97.99%, Test Loss: 0.2799, Test Acc: 92.13%
# Epoch 120/200: Train Loss: 0.0635, Train Acc: 97.84%, Test Loss: 0.3329, Test Acc: 90.92%
# Epoch 121/200: Train Loss: 0.0349, Train Acc: 98.88%, Test Loss: 0.2272, Test Acc: 93.68%
# New best model saved with accuracy: 93.68%
# Epoch 122/200: Train Loss: 0.0214, Train Acc: 99.39%, Test Loss: 0.2218, Test Acc: 93.84%
# New best model saved with accuracy: 93.84%
# Epoch 123/200: Train Loss: 0.0178, Train Acc: 99.54%, Test Loss: 0.2181, Test Acc: 94.08%
# New best model saved with accuracy: 94.08%
# Epoch 124/200: Train Loss: 0.0152, Train Acc: 99.60%, Test Loss: 0.2141, Test Acc: 94.13%
# New best model saved with accuracy: 94.13%
# Epoch 125/200: Train Loss: 0.0127, Train Acc: 99.69%, Test Loss: 0.2143, Test Acc: 94.32%
# New best model saved with accuracy: 94.32%
# Epoch 126/200: Train Loss: 0.0114, Train Acc: 99.75%, Test Loss: 0.2134, Test Acc: 94.27%
# Epoch 127/200: Train Loss: 0.0105, Train Acc: 99.75%, Test Loss: 0.2151, Test Acc: 94.45%
# New best model saved with accuracy: 94.45%
# Epoch 128/200: Train Loss: 0.0104, Train Acc: 99.77%, Test Loss: 0.2140, Test Acc: 94.39%
# Epoch 129/200: Train Loss: 0.0093, Train Acc: 99.79%, Test Loss: 0.2135, Test Acc: 94.32%
# Epoch 130/200: Train Loss: 0.0083, Train Acc: 99.83%, Test Loss: 0.2131, Test Acc: 94.38%
# Epoch 131/200: Train Loss: 0.0083, Train Acc: 99.82%, Test Loss: 0.2142, Test Acc: 94.45%
# Epoch 132/200: Train Loss: 0.0079, Train Acc: 99.85%, Test Loss: 0.2095, Test Acc: 94.50%
# New best model saved with accuracy: 94.50%
# Epoch 133/200: Train Loss: 0.0073, Train Acc: 99.87%, Test Loss: 0.2100, Test Acc: 94.50%
# Epoch 134/200: Train Loss: 0.0071, Train Acc: 99.86%, Test Loss: 0.2114, Test Acc: 94.54%
# New best model saved with accuracy: 94.54%
# Epoch 135/200: Train Loss: 0.0064, Train Acc: 99.87%, Test Loss: 0.2128, Test Acc: 94.40%
# Epoch 136/200: Train Loss: 0.0072, Train Acc: 99.86%, Test Loss: 0.2132, Test Acc: 94.54%
# Epoch 137/200: Train Loss: 0.0065, Train Acc: 99.87%, Test Loss: 0.2119, Test Acc: 94.54%
# Epoch 138/200: Train Loss: 0.0058, Train Acc: 99.90%, Test Loss: 0.2125, Test Acc: 94.44%
# Epoch 139/200: Train Loss: 0.0062, Train Acc: 99.88%, Test Loss: 0.2163, Test Acc: 94.44%
# Epoch 140/200: Train Loss: 0.0061, Train Acc: 99.89%, Test Loss: 0.2156, Test Acc: 94.52%
# Epoch 141/200: Train Loss: 0.0054, Train Acc: 99.90%, Test Loss: 0.2139, Test Acc: 94.49%
# Epoch 142/200: Train Loss: 0.0057, Train Acc: 99.88%, Test Loss: 0.2124, Test Acc: 94.67%
# New best model saved with accuracy: 94.67%
# Epoch 143/200: Train Loss: 0.0056, Train Acc: 99.90%, Test Loss: 0.2118, Test Acc: 94.63%
# Epoch 144/200: Train Loss: 0.0049, Train Acc: 99.92%, Test Loss: 0.2107, Test Acc: 94.57%
# Epoch 145/200: Train Loss: 0.0054, Train Acc: 99.91%, Test Loss: 0.2105, Test Acc: 94.68%
# New best model saved with accuracy: 94.68%
# Epoch 146/200: Train Loss: 0.0050, Train Acc: 99.91%, Test Loss: 0.2115, Test Acc: 94.68%
# Epoch 147/200: Train Loss: 0.0046, Train Acc: 99.92%, Test Loss: 0.2120, Test Acc: 94.63%
# Epoch 148/200: Train Loss: 0.0051, Train Acc: 99.91%, Test Loss: 0.2116, Test Acc: 94.61%
# Epoch 149/200: Train Loss: 0.0045, Train Acc: 99.93%, Test Loss: 0.2095, Test Acc: 94.66%
# Epoch 150/200: Train Loss: 0.0046, Train Acc: 99.93%, Test Loss: 0.2114, Test Acc: 94.62%
# Epoch 151/200: Train Loss: 0.0047, Train Acc: 99.93%, Test Loss: 0.2124, Test Acc: 94.58%
# Epoch 152/200: Train Loss: 0.0041, Train Acc: 99.94%, Test Loss: 0.2085, Test Acc: 94.68%
# Epoch 153/200: Train Loss: 0.0046, Train Acc: 99.93%, Test Loss: 0.2090, Test Acc: 94.71%
# New best model saved with accuracy: 94.71%
# Epoch 154/200: Train Loss: 0.0043, Train Acc: 99.94%, Test Loss: 0.2099, Test Acc: 94.59%
# Epoch 155/200: Train Loss: 0.0041, Train Acc: 99.94%, Test Loss: 0.2135, Test Acc: 94.66%
# Epoch 156/200: Train Loss: 0.0041, Train Acc: 99.95%, Test Loss: 0.2096, Test Acc: 94.53%
# Epoch 157/200: Train Loss: 0.0042, Train Acc: 99.93%, Test Loss: 0.2097, Test Acc: 94.68%
# Epoch 158/200: Train Loss: 0.0039, Train Acc: 99.95%, Test Loss: 0.2107, Test Acc: 94.63%
# Epoch 159/200: Train Loss: 0.0037, Train Acc: 99.96%, Test Loss: 0.2115, Test Acc: 94.68%
# Epoch 160/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2126, Test Acc: 94.54%
# Epoch 161/200: Train Loss: 0.0038, Train Acc: 99.94%, Test Loss: 0.2102, Test Acc: 94.59%
# Epoch 162/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2093, Test Acc: 94.59%
# Epoch 163/200: Train Loss: 0.0038, Train Acc: 99.95%, Test Loss: 0.2115, Test Acc: 94.50%
# Epoch 164/200: Train Loss: 0.0039, Train Acc: 99.95%, Test Loss: 0.2107, Test Acc: 94.68%
# Epoch 165/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2109, Test Acc: 94.60%
# Epoch 166/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.2085, Test Acc: 94.70%
# Epoch 167/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2096, Test Acc: 94.59%
# Epoch 168/200: Train Loss: 0.0036, Train Acc: 99.94%, Test Loss: 0.2101, Test Acc: 94.71%
# Epoch 169/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.2101, Test Acc: 94.62%
# Epoch 170/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2120, Test Acc: 94.62%
# Epoch 171/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.2107, Test Acc: 94.66%
# Epoch 172/200: Train Loss: 0.0033, Train Acc: 99.97%, Test Loss: 0.2098, Test Acc: 94.61%
# Epoch 173/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.2097, Test Acc: 94.70%
# Epoch 174/200: Train Loss: 0.0038, Train Acc: 99.95%, Test Loss: 0.2101, Test Acc: 94.65%
# Epoch 175/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.2119, Test Acc: 94.56%
# Epoch 176/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.2089, Test Acc: 94.63%
# Epoch 177/200: Train Loss: 0.0035, Train Acc: 99.95%, Test Loss: 0.2089, Test Acc: 94.67%
# Epoch 178/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.2083, Test Acc: 94.72%
# New best model saved with accuracy: 94.72%
# Epoch 179/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2073, Test Acc: 94.63%
# Epoch 180/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.2091, Test Acc: 94.64%
# Epoch 181/200: Train Loss: 0.0035, Train Acc: 99.93%, Test Loss: 0.2094, Test Acc: 94.60%
# Epoch 182/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.2121, Test Acc: 94.58%
# Epoch 183/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.2087, Test Acc: 94.66%
# Epoch 184/200: Train Loss: 0.0037, Train Acc: 99.94%, Test Loss: 0.2102, Test Acc: 94.62%
# Epoch 185/200: Train Loss: 0.0032, Train Acc: 99.96%, Test Loss: 0.2137, Test Acc: 94.51%
# Epoch 186/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.2080, Test Acc: 94.65%
# Epoch 187/200: Train Loss: 0.0035, Train Acc: 99.94%, Test Loss: 0.2100, Test Acc: 94.62%
# Epoch 188/200: Train Loss: 0.0036, Train Acc: 99.94%, Test Loss: 0.2089, Test Acc: 94.64%
# Epoch 189/200: Train Loss: 0.0034, Train Acc: 99.95%, Test Loss: 0.2117, Test Acc: 94.65%
# Epoch 190/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.2103, Test Acc: 94.66%
# Epoch 191/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.2110, Test Acc: 94.62%
# Epoch 192/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.2081, Test Acc: 94.73%
# New best model saved with accuracy: 94.73%
# Epoch 193/200: Train Loss: 0.0034, Train Acc: 99.95%, Test Loss: 0.2098, Test Acc: 94.58%
# Epoch 194/200: Train Loss: 0.0032, Train Acc: 99.96%, Test Loss: 0.2107, Test Acc: 94.66%
# Epoch 195/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.2090, Test Acc: 94.67%
# Epoch 196/200: Train Loss: 0.0036, Train Acc: 99.94%, Test Loss: 0.2084, Test Acc: 94.71%
# Epoch 197/200: Train Loss: 0.0035, Train Acc: 99.95%, Test Loss: 0.2084, Test Acc: 94.70%
# Epoch 198/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.2103, Test Acc: 94.70%
# Epoch 199/200: Train Loss: 0.0033, Train Acc: 99.95%, Test Loss: 0.2096, Test Acc: 94.62%
# Epoch 200/200: Train Loss: 0.0034, Train Acc: 99.95%, Test Loss: 0.2081, Test Acc: 94.69%
# Training completed! Best accuracy: 94.73%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估

if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA2.pth'):
        checkpoint = torch.load('model/best_modelA2.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 98%
# Accuracy of bird  : 93%
# Accuracy of cat   : 86%
# Accuracy of deer  : 97%
# Accuracy of dog   : 91%
# Accuracy of frog  : 97%
# Accuracy of horse : 96%
# Accuracy of ship  : 96%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.94      0.96      0.95      1000
#          car       0.97      0.98      0.98      1000
#         bird       0.94      0.93      0.94      1000
#          cat       0.89      0.86      0.88      1000
#         deer       0.95      0.97      0.96      1000
#          dog       0.91      0.91      0.91      1000
#         frog       0.96      0.97      0.97      1000
#        horse       0.98      0.96      0.97      1000
#         ship       0.96      0.96      0.96      1000
#        truck       0.96      0.96      0.96      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
