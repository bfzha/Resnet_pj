# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp4_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
class SELayer(nn.Module): # SE模块
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)  
        self.fc = nn.Sequential(
            nn.Linear(channel, max(channel // reduction, 1), bias=False),  
            nn.ReLU(inplace=True),
            nn.Linear(max(channel // reduction, 1), channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)  
        y = self.fc(y).view(b, c, 1, 1)  
        return x * y

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class SEBasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1, reduction=16):
        super(SEBasicBlock, self).__init__()
        # 主分支卷积
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        # shortcut 分支
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * self.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * self.expansion)
            )

        # SE 模块
        self.se = SELayer(planes * self.expansion, reduction)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.se(out)  # 加 SE
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %% [markdown]
# 输入 ↓ 卷积1 → BN → ReLU ↓ 卷积2 → BN ↓ SE模块（计算通道注意力权重） ↓ × 注意力权重 ↓
#
# 残差连接 ↓ ReLU ↓ 输出

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(SEBasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_model4.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.8768, Train Acc: 30.51%, Test Loss: 1.6715, Test Acc: 40.63%
# New best model saved with accuracy: 40.63%
# Epoch 2/200: Train Loss: 1.5380, Train Acc: 43.81%, Test Loss: 1.2034, Test Acc: 55.48%
# New best model saved with accuracy: 55.48%
# Epoch 3/200: Train Loss: 1.2935, Train Acc: 53.30%, Test Loss: 1.2665, Test Acc: 55.99%
# New best model saved with accuracy: 55.99%
# Epoch 4/200: Train Loss: 1.1516, Train Acc: 59.03%, Test Loss: 1.1410, Test Acc: 62.31%
# New best model saved with accuracy: 62.31%
# Epoch 5/200: Train Loss: 1.0313, Train Acc: 63.52%, Test Loss: 0.9065, Test Acc: 69.18%
# New best model saved with accuracy: 69.18%
# Epoch 6/200: Train Loss: 0.9487, Train Acc: 66.81%, Test Loss: 0.7481, Test Acc: 74.33%
# New best model saved with accuracy: 74.33%
# Epoch 7/200: Train Loss: 0.8871, Train Acc: 68.92%, Test Loss: 0.8394, Test Acc: 72.03%
# Epoch 8/200: Train Loss: 0.8527, Train Acc: 70.04%, Test Loss: 0.6893, Test Acc: 76.78%
# New best model saved with accuracy: 76.78%
# Epoch 9/200: Train Loss: 0.8242, Train Acc: 71.13%, Test Loss: 0.6507, Test Acc: 77.85%
# New best model saved with accuracy: 77.85%
# Epoch 10/200: Train Loss: 0.8038, Train Acc: 72.07%, Test Loss: 0.7517, Test Acc: 74.51%
# Epoch 11/200: Train Loss: 0.7859, Train Acc: 72.70%, Test Loss: 0.7399, Test Acc: 75.63%
# Epoch 12/200: Train Loss: 0.7676, Train Acc: 73.20%, Test Loss: 1.3161, Test Acc: 65.30%
# Epoch 13/200: Train Loss: 0.7492, Train Acc: 73.95%, Test Loss: 0.7772, Test Acc: 74.67%
# Epoch 14/200: Train Loss: 0.7343, Train Acc: 74.49%, Test Loss: 0.8147, Test Acc: 73.60%
# Epoch 15/200: Train Loss: 0.7282, Train Acc: 74.76%, Test Loss: 0.5774, Test Acc: 80.37%
# New best model saved with accuracy: 80.37%
# Epoch 16/200: Train Loss: 0.7172, Train Acc: 75.22%, Test Loss: 0.6575, Test Acc: 77.85%
# Epoch 17/200: Train Loss: 0.7051, Train Acc: 75.51%, Test Loss: 0.7171, Test Acc: 75.73%
# Epoch 18/200: Train Loss: 0.7038, Train Acc: 75.62%, Test Loss: 0.6247, Test Acc: 79.19%
# Epoch 19/200: Train Loss: 0.6930, Train Acc: 76.02%, Test Loss: 0.5456, Test Acc: 81.35%
# New best model saved with accuracy: 81.35%
# Epoch 20/200: Train Loss: 0.6857, Train Acc: 76.32%, Test Loss: 0.7456, Test Acc: 74.65%
# Epoch 21/200: Train Loss: 0.6820, Train Acc: 76.50%, Test Loss: 0.6026, Test Acc: 80.58%
# Epoch 22/200: Train Loss: 0.6727, Train Acc: 76.79%, Test Loss: 0.5589, Test Acc: 80.62%
# Epoch 23/200: Train Loss: 0.6692, Train Acc: 76.88%, Test Loss: 0.6761, Test Acc: 77.07%
# Epoch 24/200: Train Loss: 0.6678, Train Acc: 76.85%, Test Loss: 0.6657, Test Acc: 78.41%
# Epoch 25/200: Train Loss: 0.6626, Train Acc: 77.18%, Test Loss: 0.7085, Test Acc: 78.01%
# Epoch 26/200: Train Loss: 0.6621, Train Acc: 76.98%, Test Loss: 0.6206, Test Acc: 79.87%
# Epoch 27/200: Train Loss: 0.6529, Train Acc: 77.34%, Test Loss: 0.7114, Test Acc: 75.97%
# Epoch 28/200: Train Loss: 0.6545, Train Acc: 77.38%, Test Loss: 0.5292, Test Acc: 81.75%
# New best model saved with accuracy: 81.75%
# Epoch 29/200: Train Loss: 0.6420, Train Acc: 77.79%, Test Loss: 0.6738, Test Acc: 78.43%
# Epoch 30/200: Train Loss: 0.6407, Train Acc: 78.07%, Test Loss: 0.5645, Test Acc: 80.68%
# Epoch 31/200: Train Loss: 0.6450, Train Acc: 77.72%, Test Loss: 0.5990, Test Acc: 79.83%
# Epoch 32/200: Train Loss: 0.6367, Train Acc: 78.10%, Test Loss: 0.5635, Test Acc: 81.22%
# Epoch 33/200: Train Loss: 0.6295, Train Acc: 78.30%, Test Loss: 0.5145, Test Acc: 83.36%
# New best model saved with accuracy: 83.36%
# Epoch 34/200: Train Loss: 0.6349, Train Acc: 78.04%, Test Loss: 0.5308, Test Acc: 82.13%
# Epoch 35/200: Train Loss: 0.6310, Train Acc: 78.25%, Test Loss: 0.6128, Test Acc: 79.57%
# Epoch 36/200: Train Loss: 0.6286, Train Acc: 78.29%, Test Loss: 0.5154, Test Acc: 82.41%
# Epoch 37/200: Train Loss: 0.6224, Train Acc: 78.52%, Test Loss: 0.5247, Test Acc: 82.95%
# Epoch 38/200: Train Loss: 0.6172, Train Acc: 78.63%, Test Loss: 0.5327, Test Acc: 82.41%
# Epoch 39/200: Train Loss: 0.6183, Train Acc: 78.46%, Test Loss: 0.6663, Test Acc: 78.14%
# Epoch 40/200: Train Loss: 0.6094, Train Acc: 79.16%, Test Loss: 0.5643, Test Acc: 80.87%
# Epoch 41/200: Train Loss: 0.6101, Train Acc: 78.87%, Test Loss: 0.5624, Test Acc: 81.71%
# Epoch 42/200: Train Loss: 0.6039, Train Acc: 79.21%, Test Loss: 0.5973, Test Acc: 81.19%
# Epoch 43/200: Train Loss: 0.6043, Train Acc: 78.96%, Test Loss: 0.6924, Test Acc: 77.37%
# Epoch 44/200: Train Loss: 0.6078, Train Acc: 79.00%, Test Loss: 0.7236, Test Acc: 77.60%
# Epoch 45/200: Train Loss: 0.5930, Train Acc: 79.38%, Test Loss: 0.4534, Test Acc: 84.64%
# New best model saved with accuracy: 84.64%
# Epoch 46/200: Train Loss: 0.6006, Train Acc: 79.13%, Test Loss: 0.5461, Test Acc: 82.97%
# Epoch 47/200: Train Loss: 0.6014, Train Acc: 79.27%, Test Loss: 0.5247, Test Acc: 81.95%
# Epoch 48/200: Train Loss: 0.5954, Train Acc: 79.32%, Test Loss: 0.4838, Test Acc: 82.81%
# Epoch 49/200: Train Loss: 0.5941, Train Acc: 79.49%, Test Loss: 0.4614, Test Acc: 84.45%
# Epoch 50/200: Train Loss: 0.5922, Train Acc: 79.48%, Test Loss: 0.6152, Test Acc: 79.64%
# Epoch 51/200: Train Loss: 0.5883, Train Acc: 79.72%, Test Loss: 0.4959, Test Acc: 83.41%
# Epoch 52/200: Train Loss: 0.5854, Train Acc: 79.76%, Test Loss: 0.5842, Test Acc: 80.08%
# Epoch 53/200: Train Loss: 0.5807, Train Acc: 79.91%, Test Loss: 0.7874, Test Acc: 74.72%
# Epoch 54/200: Train Loss: 0.5721, Train Acc: 80.23%, Test Loss: 0.5159, Test Acc: 82.68%
# Epoch 55/200: Train Loss: 0.5827, Train Acc: 79.96%, Test Loss: 0.5905, Test Acc: 80.61%
# Epoch 56/200: Train Loss: 0.5744, Train Acc: 80.24%, Test Loss: 0.5365, Test Acc: 82.10%
# Epoch 57/200: Train Loss: 0.5729, Train Acc: 80.36%, Test Loss: 0.5075, Test Acc: 82.45%
# Epoch 58/200: Train Loss: 0.5723, Train Acc: 80.21%, Test Loss: 0.4475, Test Acc: 84.45%
# Epoch 59/200: Train Loss: 0.5719, Train Acc: 80.25%, Test Loss: 0.6197, Test Acc: 78.95%
# Epoch 60/200: Train Loss: 0.5672, Train Acc: 80.57%, Test Loss: 0.4197, Test Acc: 85.90%
# New best model saved with accuracy: 85.90%
# Epoch 61/200: Train Loss: 0.5672, Train Acc: 80.48%, Test Loss: 0.4065, Test Acc: 86.16%
# New best model saved with accuracy: 86.16%
# Epoch 62/200: Train Loss: 0.5588, Train Acc: 80.66%, Test Loss: 0.5050, Test Acc: 82.90%
# Epoch 63/200: Train Loss: 0.5620, Train Acc: 80.72%, Test Loss: 0.4651, Test Acc: 84.55%
# Epoch 64/200: Train Loss: 0.5568, Train Acc: 80.70%, Test Loss: 0.5040, Test Acc: 83.17%
# Epoch 65/200: Train Loss: 0.5524, Train Acc: 81.03%, Test Loss: 0.4805, Test Acc: 84.27%
# Epoch 66/200: Train Loss: 0.5507, Train Acc: 81.20%, Test Loss: 0.4176, Test Acc: 86.18%
# New best model saved with accuracy: 86.18%
# Epoch 67/200: Train Loss: 0.5474, Train Acc: 80.98%, Test Loss: 0.4921, Test Acc: 83.45%
# Epoch 68/200: Train Loss: 0.5506, Train Acc: 80.97%, Test Loss: 0.4290, Test Acc: 84.97%
# Epoch 69/200: Train Loss: 0.5421, Train Acc: 81.31%, Test Loss: 0.6688, Test Acc: 79.05%
# Epoch 70/200: Train Loss: 0.5407, Train Acc: 81.40%, Test Loss: 0.5936, Test Acc: 81.66%
# Epoch 71/200: Train Loss: 0.5341, Train Acc: 81.50%, Test Loss: 0.5400, Test Acc: 82.07%
# Epoch 72/200: Train Loss: 0.5372, Train Acc: 81.56%, Test Loss: 0.5042, Test Acc: 83.78%
# Epoch 73/200: Train Loss: 0.5350, Train Acc: 81.47%, Test Loss: 0.4856, Test Acc: 83.49%
# Epoch 74/200: Train Loss: 0.5375, Train Acc: 81.46%, Test Loss: 0.4319, Test Acc: 85.87%
# Epoch 75/200: Train Loss: 0.5274, Train Acc: 81.82%, Test Loss: 0.3759, Test Acc: 87.32%
# New best model saved with accuracy: 87.32%
# Epoch 76/200: Train Loss: 0.5288, Train Acc: 81.89%, Test Loss: 0.5126, Test Acc: 82.93%
# Epoch 77/200: Train Loss: 0.5239, Train Acc: 81.98%, Test Loss: 0.4508, Test Acc: 84.64%
# Epoch 78/200: Train Loss: 0.5206, Train Acc: 82.12%, Test Loss: 0.5084, Test Acc: 83.03%
# Epoch 79/200: Train Loss: 0.5152, Train Acc: 82.18%, Test Loss: 0.4593, Test Acc: 84.22%
# Epoch 80/200: Train Loss: 0.5221, Train Acc: 82.10%, Test Loss: 0.5303, Test Acc: 83.00%
# Epoch 81/200: Train Loss: 0.5136, Train Acc: 82.25%, Test Loss: 0.4808, Test Acc: 84.09%
# Epoch 82/200: Train Loss: 0.5103, Train Acc: 82.36%, Test Loss: 0.4382, Test Acc: 84.75%
# Epoch 83/200: Train Loss: 0.5122, Train Acc: 82.36%, Test Loss: 0.4732, Test Acc: 84.65%
# Epoch 84/200: Train Loss: 0.5028, Train Acc: 82.73%, Test Loss: 0.4034, Test Acc: 86.35%
# Epoch 85/200: Train Loss: 0.5057, Train Acc: 82.40%, Test Loss: 0.4163, Test Acc: 85.56%
# Epoch 86/200: Train Loss: 0.5023, Train Acc: 82.52%, Test Loss: 0.3746, Test Acc: 87.47%
# New best model saved with accuracy: 87.47%
# Epoch 87/200: Train Loss: 0.4967, Train Acc: 82.96%, Test Loss: 0.4355, Test Acc: 85.33%
# Epoch 88/200: Train Loss: 0.4989, Train Acc: 82.79%, Test Loss: 0.4913, Test Acc: 83.19%
# Epoch 89/200: Train Loss: 0.4920, Train Acc: 83.02%, Test Loss: 0.4300, Test Acc: 85.38%
# Epoch 90/200: Train Loss: 0.4904, Train Acc: 83.11%, Test Loss: 0.4134, Test Acc: 85.78%
# Epoch 91/200: Train Loss: 0.4815, Train Acc: 83.33%, Test Loss: 0.4118, Test Acc: 86.24%
# Epoch 92/200: Train Loss: 0.4822, Train Acc: 83.47%, Test Loss: 0.3118, Test Acc: 89.19%
# New best model saved with accuracy: 89.19%
# Epoch 93/200: Train Loss: 0.4798, Train Acc: 83.34%, Test Loss: 0.3928, Test Acc: 86.80%
# Epoch 94/200: Train Loss: 0.4843, Train Acc: 83.12%, Test Loss: 0.4222, Test Acc: 86.11%
# Epoch 95/200: Train Loss: 0.4740, Train Acc: 83.62%, Test Loss: 0.3557, Test Acc: 87.95%
# Epoch 96/200: Train Loss: 0.4708, Train Acc: 83.78%, Test Loss: 0.4033, Test Acc: 86.09%
# Epoch 97/200: Train Loss: 0.4707, Train Acc: 83.74%, Test Loss: 0.3726, Test Acc: 87.28%
# Epoch 98/200: Train Loss: 0.4655, Train Acc: 84.11%, Test Loss: 0.3908, Test Acc: 86.66%
# Epoch 99/200: Train Loss: 0.4663, Train Acc: 83.87%, Test Loss: 0.3585, Test Acc: 88.10%
# Epoch 100/200: Train Loss: 0.4598, Train Acc: 84.28%, Test Loss: 0.3861, Test Acc: 86.92%
# Epoch 101/200: Train Loss: 0.4559, Train Acc: 84.22%, Test Loss: 0.3204, Test Acc: 89.08%
# Epoch 102/200: Train Loss: 0.4493, Train Acc: 84.55%, Test Loss: 0.3236, Test Acc: 89.01%
# Epoch 103/200: Train Loss: 0.4487, Train Acc: 84.73%, Test Loss: 0.3634, Test Acc: 87.52%
# Epoch 104/200: Train Loss: 0.4462, Train Acc: 84.78%, Test Loss: 0.3205, Test Acc: 89.53%
# New best model saved with accuracy: 89.53%
# Epoch 105/200: Train Loss: 0.4410, Train Acc: 84.83%, Test Loss: 0.4613, Test Acc: 84.76%
# Epoch 106/200: Train Loss: 0.4392, Train Acc: 84.90%, Test Loss: 0.3826, Test Acc: 87.31%
# Epoch 107/200: Train Loss: 0.4307, Train Acc: 85.01%, Test Loss: 0.2876, Test Acc: 90.36%
# New best model saved with accuracy: 90.36%
# Epoch 108/200: Train Loss: 0.4316, Train Acc: 84.96%, Test Loss: 0.3725, Test Acc: 87.46%
# Epoch 109/200: Train Loss: 0.4286, Train Acc: 85.13%, Test Loss: 0.3676, Test Acc: 87.67%
# Epoch 110/200: Train Loss: 0.4263, Train Acc: 85.24%, Test Loss: 0.4306, Test Acc: 85.65%
# Epoch 111/200: Train Loss: 0.4212, Train Acc: 85.31%, Test Loss: 0.3531, Test Acc: 88.24%
# Epoch 112/200: Train Loss: 0.4230, Train Acc: 85.35%, Test Loss: 0.3335, Test Acc: 89.21%
# Epoch 113/200: Train Loss: 0.4096, Train Acc: 85.86%, Test Loss: 0.3397, Test Acc: 88.25%
# Epoch 114/200: Train Loss: 0.4137, Train Acc: 85.52%, Test Loss: 0.3130, Test Acc: 88.91%
# Epoch 115/200: Train Loss: 0.4106, Train Acc: 85.80%, Test Loss: 0.3353, Test Acc: 88.69%
# Epoch 116/200: Train Loss: 0.4039, Train Acc: 85.98%, Test Loss: 0.3493, Test Acc: 88.38%
# Epoch 117/200: Train Loss: 0.4045, Train Acc: 86.07%, Test Loss: 0.2939, Test Acc: 90.05%
# Epoch 118/200: Train Loss: 0.3943, Train Acc: 86.34%, Test Loss: 0.3489, Test Acc: 88.74%
# Epoch 119/200: Train Loss: 0.3933, Train Acc: 86.41%, Test Loss: 0.2748, Test Acc: 90.66%
# New best model saved with accuracy: 90.66%
# Epoch 120/200: Train Loss: 0.3822, Train Acc: 86.93%, Test Loss: 0.3140, Test Acc: 89.37%
# Epoch 121/200: Train Loss: 0.3815, Train Acc: 86.82%, Test Loss: 0.2941, Test Acc: 90.25%
# Epoch 122/200: Train Loss: 0.3809, Train Acc: 86.84%, Test Loss: 0.2939, Test Acc: 89.87%
# Epoch 123/200: Train Loss: 0.3782, Train Acc: 86.92%, Test Loss: 0.3321, Test Acc: 89.14%
# Epoch 124/200: Train Loss: 0.3787, Train Acc: 86.87%, Test Loss: 0.2891, Test Acc: 90.10%
# Epoch 125/200: Train Loss: 0.3701, Train Acc: 87.14%, Test Loss: 0.3395, Test Acc: 88.28%
# Epoch 126/200: Train Loss: 0.3634, Train Acc: 87.47%, Test Loss: 0.3235, Test Acc: 89.35%
# Epoch 127/200: Train Loss: 0.3591, Train Acc: 87.57%, Test Loss: 0.2814, Test Acc: 91.10%
# New best model saved with accuracy: 91.10%
# Epoch 128/200: Train Loss: 0.3570, Train Acc: 87.85%, Test Loss: 0.2670, Test Acc: 91.10%
# Epoch 129/200: Train Loss: 0.3551, Train Acc: 87.66%, Test Loss: 0.2933, Test Acc: 89.98%
# Epoch 130/200: Train Loss: 0.3512, Train Acc: 87.88%, Test Loss: 0.2877, Test Acc: 90.21%
# Epoch 131/200: Train Loss: 0.3449, Train Acc: 88.14%, Test Loss: 0.2933, Test Acc: 90.19%
# Epoch 132/200: Train Loss: 0.3406, Train Acc: 88.25%, Test Loss: 0.2874, Test Acc: 90.25%
# Epoch 133/200: Train Loss: 0.3385, Train Acc: 88.40%, Test Loss: 0.2585, Test Acc: 91.35%
# New best model saved with accuracy: 91.35%
# Epoch 134/200: Train Loss: 0.3344, Train Acc: 88.49%, Test Loss: 0.2658, Test Acc: 91.12%
# Epoch 135/200: Train Loss: 0.3292, Train Acc: 88.51%, Test Loss: 0.2557, Test Acc: 91.62%
# New best model saved with accuracy: 91.62%
# Epoch 136/200: Train Loss: 0.3222, Train Acc: 88.92%, Test Loss: 0.2809, Test Acc: 90.76%
# Epoch 137/200: Train Loss: 0.3264, Train Acc: 88.67%, Test Loss: 0.2759, Test Acc: 91.18%
# Epoch 138/200: Train Loss: 0.3109, Train Acc: 89.29%, Test Loss: 0.2803, Test Acc: 90.67%
# Epoch 139/200: Train Loss: 0.3140, Train Acc: 89.15%, Test Loss: 0.2331, Test Acc: 92.36%
# New best model saved with accuracy: 92.36%
# Epoch 140/200: Train Loss: 0.3090, Train Acc: 89.26%, Test Loss: 0.2435, Test Acc: 91.66%
# Epoch 141/200: Train Loss: 0.3001, Train Acc: 89.59%, Test Loss: 0.2868, Test Acc: 90.67%
# Epoch 142/200: Train Loss: 0.2974, Train Acc: 89.71%, Test Loss: 0.2341, Test Acc: 92.27%
# Epoch 143/200: Train Loss: 0.2910, Train Acc: 89.95%, Test Loss: 0.2906, Test Acc: 90.76%
# Epoch 144/200: Train Loss: 0.2863, Train Acc: 90.09%, Test Loss: 0.2411, Test Acc: 92.32%
# Epoch 145/200: Train Loss: 0.2818, Train Acc: 90.23%, Test Loss: 0.2596, Test Acc: 91.61%
# Epoch 146/200: Train Loss: 0.2777, Train Acc: 90.60%, Test Loss: 0.2609, Test Acc: 91.47%
# Epoch 147/200: Train Loss: 0.2716, Train Acc: 90.61%, Test Loss: 0.2311, Test Acc: 92.24%
# Epoch 148/200: Train Loss: 0.2704, Train Acc: 90.61%, Test Loss: 0.2369, Test Acc: 92.09%
# Epoch 149/200: Train Loss: 0.2681, Train Acc: 90.78%, Test Loss: 0.2282, Test Acc: 92.48%
# New best model saved with accuracy: 92.48%
# Epoch 150/200: Train Loss: 0.2583, Train Acc: 91.13%, Test Loss: 0.2209, Test Acc: 92.96%
# New best model saved with accuracy: 92.96%
# Epoch 151/200: Train Loss: 0.2531, Train Acc: 91.24%, Test Loss: 0.2126, Test Acc: 93.35%
# New best model saved with accuracy: 93.35%
# Epoch 152/200: Train Loss: 0.2497, Train Acc: 91.48%, Test Loss: 0.2256, Test Acc: 92.88%
# Epoch 153/200: Train Loss: 0.2395, Train Acc: 91.76%, Test Loss: 0.2076, Test Acc: 93.39%
# New best model saved with accuracy: 93.39%
# Epoch 154/200: Train Loss: 0.2398, Train Acc: 91.63%, Test Loss: 0.2278, Test Acc: 92.65%
# Epoch 155/200: Train Loss: 0.2344, Train Acc: 91.86%, Test Loss: 0.2348, Test Acc: 92.48%
# Epoch 156/200: Train Loss: 0.2306, Train Acc: 92.04%, Test Loss: 0.1933, Test Acc: 93.70%
# New best model saved with accuracy: 93.70%
# Epoch 157/200: Train Loss: 0.2251, Train Acc: 92.17%, Test Loss: 0.2117, Test Acc: 93.37%
# Epoch 158/200: Train Loss: 0.2224, Train Acc: 92.33%, Test Loss: 0.2103, Test Acc: 93.51%
# Epoch 159/200: Train Loss: 0.2105, Train Acc: 92.70%, Test Loss: 0.2105, Test Acc: 93.33%
# Epoch 160/200: Train Loss: 0.2083, Train Acc: 92.88%, Test Loss: 0.1919, Test Acc: 93.96%
# New best model saved with accuracy: 93.96%
# Epoch 161/200: Train Loss: 0.2060, Train Acc: 92.92%, Test Loss: 0.2122, Test Acc: 93.47%
# Epoch 162/200: Train Loss: 0.1963, Train Acc: 93.33%, Test Loss: 0.1884, Test Acc: 94.09%
# New best model saved with accuracy: 94.09%
# Epoch 163/200: Train Loss: 0.1900, Train Acc: 93.54%, Test Loss: 0.1964, Test Acc: 94.03%
# Epoch 164/200: Train Loss: 0.1906, Train Acc: 93.44%, Test Loss: 0.2080, Test Acc: 93.61%
# Epoch 165/200: Train Loss: 0.1879, Train Acc: 93.51%, Test Loss: 0.1888, Test Acc: 93.87%
# Epoch 166/200: Train Loss: 0.1788, Train Acc: 93.92%, Test Loss: 0.1958, Test Acc: 93.85%
# Epoch 167/200: Train Loss: 0.1769, Train Acc: 93.82%, Test Loss: 0.1781, Test Acc: 94.15%
# New best model saved with accuracy: 94.15%
# Epoch 168/200: Train Loss: 0.1682, Train Acc: 94.31%, Test Loss: 0.1723, Test Acc: 94.54%
# New best model saved with accuracy: 94.54%
# Epoch 169/200: Train Loss: 0.1616, Train Acc: 94.40%, Test Loss: 0.1788, Test Acc: 94.48%
# Epoch 170/200: Train Loss: 0.1590, Train Acc: 94.49%, Test Loss: 0.1742, Test Acc: 94.64%
# New best model saved with accuracy: 94.64%
# Epoch 171/200: Train Loss: 0.1537, Train Acc: 94.77%, Test Loss: 0.1800, Test Acc: 94.65%
# New best model saved with accuracy: 94.65%
# Epoch 172/200: Train Loss: 0.1496, Train Acc: 94.94%, Test Loss: 0.1812, Test Acc: 94.39%
# Epoch 173/200: Train Loss: 0.1396, Train Acc: 95.37%, Test Loss: 0.1684, Test Acc: 94.85%
# New best model saved with accuracy: 94.85%
# Epoch 174/200: Train Loss: 0.1426, Train Acc: 95.18%, Test Loss: 0.1807, Test Acc: 94.47%
# Epoch 175/200: Train Loss: 0.1375, Train Acc: 95.26%, Test Loss: 0.1669, Test Acc: 94.75%
# Epoch 176/200: Train Loss: 0.1283, Train Acc: 95.62%, Test Loss: 0.1666, Test Acc: 95.00%
# New best model saved with accuracy: 95.00%
# Epoch 177/200: Train Loss: 0.1229, Train Acc: 95.77%, Test Loss: 0.1657, Test Acc: 95.06%
# New best model saved with accuracy: 95.06%
# Epoch 178/200: Train Loss: 0.1191, Train Acc: 95.92%, Test Loss: 0.1665, Test Acc: 95.04%
# Epoch 179/200: Train Loss: 0.1190, Train Acc: 95.99%, Test Loss: 0.1610, Test Acc: 95.08%
# New best model saved with accuracy: 95.08%
# Epoch 180/200: Train Loss: 0.1143, Train Acc: 96.14%, Test Loss: 0.1667, Test Acc: 95.16%
# New best model saved with accuracy: 95.16%
# Epoch 181/200: Train Loss: 0.1094, Train Acc: 96.32%, Test Loss: 0.1615, Test Acc: 95.41%
# New best model saved with accuracy: 95.41%
# Epoch 182/200: Train Loss: 0.1078, Train Acc: 96.35%, Test Loss: 0.1623, Test Acc: 95.23%
# Epoch 183/200: Train Loss: 0.1005, Train Acc: 96.69%, Test Loss: 0.1613, Test Acc: 95.35%
# Epoch 184/200: Train Loss: 0.1011, Train Acc: 96.58%, Test Loss: 0.1654, Test Acc: 95.10%
# Epoch 185/200: Train Loss: 0.0984, Train Acc: 96.74%, Test Loss: 0.1537, Test Acc: 95.40%
# Epoch 186/200: Train Loss: 0.0927, Train Acc: 96.90%, Test Loss: 0.1552, Test Acc: 95.33%
# Epoch 187/200: Train Loss: 0.0892, Train Acc: 97.04%, Test Loss: 0.1526, Test Acc: 95.56%
# New best model saved with accuracy: 95.56%
# Epoch 188/200: Train Loss: 0.0907, Train Acc: 96.97%, Test Loss: 0.1518, Test Acc: 95.55%
# Epoch 189/200: Train Loss: 0.0860, Train Acc: 97.14%, Test Loss: 0.1482, Test Acc: 95.74%
# New best model saved with accuracy: 95.74%
# Epoch 190/200: Train Loss: 0.0878, Train Acc: 97.04%, Test Loss: 0.1452, Test Acc: 95.78%
# New best model saved with accuracy: 95.78%
# Epoch 191/200: Train Loss: 0.0822, Train Acc: 97.26%, Test Loss: 0.1488, Test Acc: 95.60%
# Epoch 192/200: Train Loss: 0.0812, Train Acc: 97.32%, Test Loss: 0.1482, Test Acc: 95.66%
# Epoch 193/200: Train Loss: 0.0828, Train Acc: 97.32%, Test Loss: 0.1502, Test Acc: 95.74%
# Epoch 194/200: Train Loss: 0.0787, Train Acc: 97.41%, Test Loss: 0.1476, Test Acc: 95.72%
# Epoch 195/200: Train Loss: 0.0848, Train Acc: 97.16%, Test Loss: 0.1466, Test Acc: 95.77%
# Epoch 196/200: Train Loss: 0.0795, Train Acc: 97.38%, Test Loss: 0.1479, Test Acc: 95.65%
# Epoch 197/200: Train Loss: 0.0766, Train Acc: 97.45%, Test Loss: 0.1459, Test Acc: 95.77%
# Epoch 198/200: Train Loss: 0.0769, Train Acc: 97.46%, Test Loss: 0.1468, Test Acc: 95.75%
# Epoch 199/200: Train Loss: 0.0790, Train Acc: 97.40%, Test Loss: 0.1479, Test Acc: 95.74%
# Epoch 200/200: Train Loss: 0.0799, Train Acc: 97.39%, Test Loss: 0.1465, Test Acc: 95.79%
# New best model saved with accuracy: 95.79%
# Training completed! Best accuracy: 95.79%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_model4.pth'):
        checkpoint = torch.load('model/best_model4.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 99%
# Accuracy of bird  : 95%
# Accuracy of cat   : 91%
# Accuracy of deer  : 97%
# Accuracy of dog   : 91%
# Accuracy of frog  : 97%
# Accuracy of horse : 97%
# Accuracy of ship  : 98%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.96      0.96      0.96      1000
#          car       0.98      0.99      0.98      1000
#         bird       0.95      0.95      0.95      1000
#          cat       0.89      0.91      0.90      1000
#         deer       0.95      0.97      0.96      1000
#          dog       0.93      0.91      0.92      1000
#         frog       0.98      0.97      0.98      1000
#        horse       0.99      0.97      0.98      1000
#         ship       0.97      0.98      0.97      1000
#        truck       0.98      0.96      0.97      1000
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
# === ROC曲线 ===
