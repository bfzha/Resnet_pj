# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性
    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)
# Out:
# 100%|██████████| 170M/170M [00:13<00:00, 12.9MB/s]

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_model1.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.8211, Train Acc: 34.37%, Test Loss: 1.4184, Test Acc: 47.68%
# New best model saved with accuracy: 47.68%
# Epoch 2/200: Train Loss: 1.3309, Train Acc: 51.60%, Test Loss: 1.2505, Test Acc: 55.37%
# New best model saved with accuracy: 55.37%
# Epoch 3/200: Train Loss: 1.0711, Train Acc: 61.53%, Test Loss: 1.0977, Test Acc: 62.09%
# New best model saved with accuracy: 62.09%
# Epoch 4/200: Train Loss: 0.9048, Train Acc: 67.74%, Test Loss: 1.1606, Test Acc: 61.06%
# Epoch 5/200: Train Loss: 0.7625, Train Acc: 73.40%, Test Loss: 0.7863, Test Acc: 72.82%
# New best model saved with accuracy: 72.82%
# Epoch 6/200: Train Loss: 0.6601, Train Acc: 77.16%, Test Loss: 0.6805, Test Acc: 76.72%
# New best model saved with accuracy: 76.72%
# Epoch 7/200: Train Loss: 0.5923, Train Acc: 79.51%, Test Loss: 0.8099, Test Acc: 73.20%
# Epoch 8/200: Train Loss: 0.5513, Train Acc: 80.96%, Test Loss: 0.8101, Test Acc: 73.90%
# Epoch 9/200: Train Loss: 0.5200, Train Acc: 82.05%, Test Loss: 0.7370, Test Acc: 76.52%
# Epoch 10/200: Train Loss: 0.4973, Train Acc: 83.07%, Test Loss: 0.7247, Test Acc: 75.94%
# Epoch 11/200: Train Loss: 0.4788, Train Acc: 83.59%, Test Loss: 0.5195, Test Acc: 82.82%
# New best model saved with accuracy: 82.82%
# Epoch 12/200: Train Loss: 0.4591, Train Acc: 84.36%, Test Loss: 0.6392, Test Acc: 79.18%
# Epoch 13/200: Train Loss: 0.4533, Train Acc: 84.29%, Test Loss: 0.5630, Test Acc: 81.68%
# Epoch 14/200: Train Loss: 0.4397, Train Acc: 84.91%, Test Loss: 0.5792, Test Acc: 81.29%
# Epoch 15/200: Train Loss: 0.4279, Train Acc: 85.31%, Test Loss: 0.6150, Test Acc: 79.73%
# Epoch 16/200: Train Loss: 0.4183, Train Acc: 85.68%, Test Loss: 0.5086, Test Acc: 82.73%
# Epoch 17/200: Train Loss: 0.4146, Train Acc: 85.80%, Test Loss: 0.5695, Test Acc: 81.38%
# Epoch 18/200: Train Loss: 0.4063, Train Acc: 86.01%, Test Loss: 0.5380, Test Acc: 82.00%
# Epoch 19/200: Train Loss: 0.3945, Train Acc: 86.49%, Test Loss: 0.4641, Test Acc: 83.99%
# New best model saved with accuracy: 83.99%
# Epoch 20/200: Train Loss: 0.3913, Train Acc: 86.69%, Test Loss: 0.5364, Test Acc: 81.99%
# Epoch 21/200: Train Loss: 0.3847, Train Acc: 87.01%, Test Loss: 0.5150, Test Acc: 82.94%
# Epoch 22/200: Train Loss: 0.3810, Train Acc: 86.91%, Test Loss: 0.5388, Test Acc: 81.70%
# Epoch 23/200: Train Loss: 0.3779, Train Acc: 87.11%, Test Loss: 0.4952, Test Acc: 83.68%
# Epoch 24/200: Train Loss: 0.3738, Train Acc: 87.24%, Test Loss: 0.6592, Test Acc: 79.58%
# Epoch 25/200: Train Loss: 0.3761, Train Acc: 87.22%, Test Loss: 0.5658, Test Acc: 81.50%
# Epoch 26/200: Train Loss: 0.3667, Train Acc: 87.39%, Test Loss: 0.4496, Test Acc: 84.57%
# New best model saved with accuracy: 84.57%
# Epoch 27/200: Train Loss: 0.3617, Train Acc: 87.76%, Test Loss: 0.4988, Test Acc: 83.11%
# Epoch 28/200: Train Loss: 0.3596, Train Acc: 87.65%, Test Loss: 0.5968, Test Acc: 81.42%
# Epoch 29/200: Train Loss: 0.3582, Train Acc: 87.66%, Test Loss: 0.4884, Test Acc: 84.28%
# Epoch 30/200: Train Loss: 0.3556, Train Acc: 87.97%, Test Loss: 0.4770, Test Acc: 84.31%
# Epoch 31/200: Train Loss: 0.3493, Train Acc: 88.11%, Test Loss: 0.5029, Test Acc: 83.68%
# Epoch 32/200: Train Loss: 0.3526, Train Acc: 87.98%, Test Loss: 0.5576, Test Acc: 82.30%
# Epoch 33/200: Train Loss: 0.3522, Train Acc: 87.97%, Test Loss: 0.4492, Test Acc: 85.42%
# New best model saved with accuracy: 85.42%
# Epoch 34/200: Train Loss: 0.3496, Train Acc: 88.19%, Test Loss: 0.5746, Test Acc: 81.40%
# Epoch 35/200: Train Loss: 0.3456, Train Acc: 88.32%, Test Loss: 0.7069, Test Acc: 79.36%
# Epoch 36/200: Train Loss: 0.3440, Train Acc: 88.35%, Test Loss: 0.5738, Test Acc: 81.13%
# Epoch 37/200: Train Loss: 0.3428, Train Acc: 88.27%, Test Loss: 0.5314, Test Acc: 82.64%
# Epoch 38/200: Train Loss: 0.3450, Train Acc: 88.20%, Test Loss: 0.3906, Test Acc: 86.99%
# New best model saved with accuracy: 86.99%
# Epoch 39/200: Train Loss: 0.3453, Train Acc: 88.19%, Test Loss: 0.6692, Test Acc: 78.82%
# Epoch 40/200: Train Loss: 0.3448, Train Acc: 88.43%, Test Loss: 0.4866, Test Acc: 83.81%
# Epoch 41/200: Train Loss: 0.3455, Train Acc: 88.24%, Test Loss: 0.5109, Test Acc: 83.27%
# Epoch 42/200: Train Loss: 0.3419, Train Acc: 88.56%, Test Loss: 0.4628, Test Acc: 85.19%
# Epoch 43/200: Train Loss: 0.3342, Train Acc: 88.68%, Test Loss: 0.4386, Test Acc: 85.51%
# Epoch 44/200: Train Loss: 0.3335, Train Acc: 88.55%, Test Loss: 0.4711, Test Acc: 84.45%
# Epoch 45/200: Train Loss: 0.3411, Train Acc: 88.39%, Test Loss: 0.4672, Test Acc: 84.53%
# Epoch 46/200: Train Loss: 0.3310, Train Acc: 88.75%, Test Loss: 0.5101, Test Acc: 83.91%
# Epoch 47/200: Train Loss: 0.3327, Train Acc: 88.71%, Test Loss: 0.6618, Test Acc: 78.63%
# Epoch 48/200: Train Loss: 0.3394, Train Acc: 88.44%, Test Loss: 0.4575, Test Acc: 84.43%
# Epoch 49/200: Train Loss: 0.3307, Train Acc: 88.70%, Test Loss: 0.4652, Test Acc: 84.57%
# Epoch 50/200: Train Loss: 0.3308, Train Acc: 88.86%, Test Loss: 0.5714, Test Acc: 81.30%
# Epoch 51/200: Train Loss: 0.3315, Train Acc: 88.68%, Test Loss: 0.4919, Test Acc: 83.81%
# Epoch 52/200: Train Loss: 0.3308, Train Acc: 88.77%, Test Loss: 0.5615, Test Acc: 82.41%
# Epoch 53/200: Train Loss: 0.3285, Train Acc: 88.94%, Test Loss: 0.7114, Test Acc: 79.63%
# Epoch 54/200: Train Loss: 0.3298, Train Acc: 88.78%, Test Loss: 0.4441, Test Acc: 85.65%
# Epoch 55/200: Train Loss: 0.3303, Train Acc: 88.73%, Test Loss: 0.5480, Test Acc: 81.95%
# Epoch 56/200: Train Loss: 0.3259, Train Acc: 88.90%, Test Loss: 0.4623, Test Acc: 84.61%
# Epoch 57/200: Train Loss: 0.3286, Train Acc: 88.75%, Test Loss: 0.6036, Test Acc: 81.15%
# Epoch 58/200: Train Loss: 0.3180, Train Acc: 89.19%, Test Loss: 0.4815, Test Acc: 84.45%
# Epoch 59/200: Train Loss: 0.3257, Train Acc: 88.88%, Test Loss: 0.4180, Test Acc: 85.72%
# Epoch 60/200: Train Loss: 0.3262, Train Acc: 88.95%, Test Loss: 0.5819, Test Acc: 81.56%
# Epoch 61/200: Train Loss: 0.3253, Train Acc: 88.90%, Test Loss: 0.6211, Test Acc: 80.01%
# Epoch 62/200: Train Loss: 0.3286, Train Acc: 88.68%, Test Loss: 0.5921, Test Acc: 81.20%
# Epoch 63/200: Train Loss: 0.3256, Train Acc: 88.95%, Test Loss: 0.4172, Test Acc: 86.10%
# Epoch 64/200: Train Loss: 0.3180, Train Acc: 89.08%, Test Loss: 0.5199, Test Acc: 83.22%
# Epoch 65/200: Train Loss: 0.3147, Train Acc: 89.25%, Test Loss: 0.6476, Test Acc: 81.10%
# Epoch 66/200: Train Loss: 0.3257, Train Acc: 88.76%, Test Loss: 0.4457, Test Acc: 85.49%
# Epoch 67/200: Train Loss: 0.3173, Train Acc: 89.18%, Test Loss: 0.4730, Test Acc: 84.63%
# Epoch 68/200: Train Loss: 0.3206, Train Acc: 89.07%, Test Loss: 0.6105, Test Acc: 80.37%
# Epoch 69/200: Train Loss: 0.3256, Train Acc: 88.87%, Test Loss: 0.4582, Test Acc: 84.83%
# Epoch 70/200: Train Loss: 0.3258, Train Acc: 89.00%, Test Loss: 0.4793, Test Acc: 83.84%
# Epoch 71/200: Train Loss: 0.1734, Train Acc: 94.24%, Test Loss: 0.2093, Test Acc: 93.06%
# New best model saved with accuracy: 93.06%
# Epoch 72/200: Train Loss: 0.1228, Train Acc: 95.84%, Test Loss: 0.2006, Test Acc: 93.42%
# New best model saved with accuracy: 93.42%
# Epoch 73/200: Train Loss: 0.1031, Train Acc: 96.66%, Test Loss: 0.1982, Test Acc: 93.70%
# New best model saved with accuracy: 93.70%
# Epoch 74/200: Train Loss: 0.0915, Train Acc: 96.96%, Test Loss: 0.1915, Test Acc: 93.84%
# New best model saved with accuracy: 93.84%
# Epoch 75/200: Train Loss: 0.0814, Train Acc: 97.29%, Test Loss: 0.1929, Test Acc: 93.87%
# New best model saved with accuracy: 93.87%
# Epoch 76/200: Train Loss: 0.0709, Train Acc: 97.63%, Test Loss: 0.1963, Test Acc: 93.96%
# New best model saved with accuracy: 93.96%
# Epoch 77/200: Train Loss: 0.0644, Train Acc: 97.85%, Test Loss: 0.2010, Test Acc: 93.94%
# Epoch 78/200: Train Loss: 0.0594, Train Acc: 98.04%, Test Loss: 0.2043, Test Acc: 93.62%
# Epoch 79/200: Train Loss: 0.0551, Train Acc: 98.17%, Test Loss: 0.1978, Test Acc: 94.28%
# New best model saved with accuracy: 94.28%
# Epoch 80/200: Train Loss: 0.0467, Train Acc: 98.53%, Test Loss: 0.2097, Test Acc: 93.99%
# Epoch 81/200: Train Loss: 0.0464, Train Acc: 98.47%, Test Loss: 0.2022, Test Acc: 93.94%
# Epoch 82/200: Train Loss: 0.0417, Train Acc: 98.64%, Test Loss: 0.2121, Test Acc: 93.76%
# Epoch 83/200: Train Loss: 0.0372, Train Acc: 98.85%, Test Loss: 0.2116, Test Acc: 93.89%
# Epoch 84/200: Train Loss: 0.0371, Train Acc: 98.81%, Test Loss: 0.2173, Test Acc: 93.86%
# Epoch 85/200: Train Loss: 0.0350, Train Acc: 98.88%, Test Loss: 0.2245, Test Acc: 93.68%
# Epoch 86/200: Train Loss: 0.0348, Train Acc: 98.84%, Test Loss: 0.2242, Test Acc: 93.65%
# Epoch 87/200: Train Loss: 0.0351, Train Acc: 98.88%, Test Loss: 0.2277, Test Acc: 93.76%
# Epoch 88/200: Train Loss: 0.0362, Train Acc: 98.79%, Test Loss: 0.2263, Test Acc: 93.69%
# Epoch 89/200: Train Loss: 0.0312, Train Acc: 98.97%, Test Loss: 0.2278, Test Acc: 93.58%
# Epoch 90/200: Train Loss: 0.0332, Train Acc: 98.92%, Test Loss: 0.2217, Test Acc: 94.03%
# Epoch 91/200: Train Loss: 0.0318, Train Acc: 98.93%, Test Loss: 0.2447, Test Acc: 93.31%
# Epoch 92/200: Train Loss: 0.0332, Train Acc: 98.93%, Test Loss: 0.2180, Test Acc: 93.65%
# Epoch 93/200: Train Loss: 0.0326, Train Acc: 98.94%, Test Loss: 0.2203, Test Acc: 93.78%
# Epoch 94/200: Train Loss: 0.0347, Train Acc: 98.84%, Test Loss: 0.2323, Test Acc: 93.61%
# Epoch 95/200: Train Loss: 0.0311, Train Acc: 99.04%, Test Loss: 0.2567, Test Acc: 93.27%
# Epoch 96/200: Train Loss: 0.0353, Train Acc: 98.86%, Test Loss: 0.2447, Test Acc: 93.28%
# Epoch 97/200: Train Loss: 0.0352, Train Acc: 98.84%, Test Loss: 0.2526, Test Acc: 92.94%
# Epoch 98/200: Train Loss: 0.0355, Train Acc: 98.86%, Test Loss: 0.2619, Test Acc: 92.83%
# Epoch 99/200: Train Loss: 0.0393, Train Acc: 98.72%, Test Loss: 0.2630, Test Acc: 92.68%
# Epoch 100/200: Train Loss: 0.0407, Train Acc: 98.63%, Test Loss: 0.2325, Test Acc: 93.57%
# Epoch 101/200: Train Loss: 0.0374, Train Acc: 98.82%, Test Loss: 0.2443, Test Acc: 93.46%
# Epoch 102/200: Train Loss: 0.0416, Train Acc: 98.57%, Test Loss: 0.2550, Test Acc: 93.24%
# Epoch 103/200: Train Loss: 0.0403, Train Acc: 98.69%, Test Loss: 0.2614, Test Acc: 92.98%
# Epoch 104/200: Train Loss: 0.0392, Train Acc: 98.66%, Test Loss: 0.2761, Test Acc: 92.59%
# Epoch 105/200: Train Loss: 0.0436, Train Acc: 98.58%, Test Loss: 0.2644, Test Acc: 92.65%
# Epoch 106/200: Train Loss: 0.0396, Train Acc: 98.72%, Test Loss: 0.2499, Test Acc: 92.86%
# Epoch 107/200: Train Loss: 0.0429, Train Acc: 98.54%, Test Loss: 0.2527, Test Acc: 93.01%
# Epoch 108/200: Train Loss: 0.0416, Train Acc: 98.63%, Test Loss: 0.2665, Test Acc: 92.54%
# Epoch 109/200: Train Loss: 0.0445, Train Acc: 98.52%, Test Loss: 0.2698, Test Acc: 92.51%
# Epoch 110/200: Train Loss: 0.0432, Train Acc: 98.59%, Test Loss: 0.2735, Test Acc: 92.50%
# Epoch 111/200: Train Loss: 0.0446, Train Acc: 98.50%, Test Loss: 0.2540, Test Acc: 92.72%
# Epoch 112/200: Train Loss: 0.0461, Train Acc: 98.52%, Test Loss: 0.2664, Test Acc: 92.51%
# Epoch 113/200: Train Loss: 0.0467, Train Acc: 98.52%, Test Loss: 0.2758, Test Acc: 92.49%
# Epoch 114/200: Train Loss: 0.0460, Train Acc: 98.50%, Test Loss: 0.3046, Test Acc: 91.86%
# Epoch 115/200: Train Loss: 0.0481, Train Acc: 98.41%, Test Loss: 0.2523, Test Acc: 93.16%
# Epoch 116/200: Train Loss: 0.0499, Train Acc: 98.34%, Test Loss: 0.2311, Test Acc: 93.31%
# Epoch 117/200: Train Loss: 0.0461, Train Acc: 98.49%, Test Loss: 0.2815, Test Acc: 92.07%
# Epoch 118/200: Train Loss: 0.0462, Train Acc: 98.44%, Test Loss: 0.3025, Test Acc: 91.60%
# Epoch 119/200: Train Loss: 0.0503, Train Acc: 98.30%, Test Loss: 0.2438, Test Acc: 93.22%
# Epoch 120/200: Train Loss: 0.0445, Train Acc: 98.56%, Test Loss: 0.2593, Test Acc: 92.77%
# Epoch 121/200: Train Loss: 0.0226, Train Acc: 99.33%, Test Loss: 0.2091, Test Acc: 94.32%
# New best model saved with accuracy: 94.32%
# Epoch 122/200: Train Loss: 0.0124, Train Acc: 99.70%, Test Loss: 0.2058, Test Acc: 94.33%
# New best model saved with accuracy: 94.33%
# Epoch 123/200: Train Loss: 0.0102, Train Acc: 99.78%, Test Loss: 0.2027, Test Acc: 94.46%
# New best model saved with accuracy: 94.46%
# Epoch 124/200: Train Loss: 0.0083, Train Acc: 99.84%, Test Loss: 0.2029, Test Acc: 94.44%
# Epoch 125/200: Train Loss: 0.0076, Train Acc: 99.86%, Test Loss: 0.2009, Test Acc: 94.61%
# New best model saved with accuracy: 94.61%
# Epoch 126/200: Train Loss: 0.0068, Train Acc: 99.87%, Test Loss: 0.2031, Test Acc: 94.58%
# Epoch 127/200: Train Loss: 0.0061, Train Acc: 99.90%, Test Loss: 0.2007, Test Acc: 94.68%
# New best model saved with accuracy: 94.68%
# Epoch 128/200: Train Loss: 0.0055, Train Acc: 99.93%, Test Loss: 0.1999, Test Acc: 94.70%
# New best model saved with accuracy: 94.70%
# Epoch 129/200: Train Loss: 0.0055, Train Acc: 99.92%, Test Loss: 0.2018, Test Acc: 94.61%
# Epoch 130/200: Train Loss: 0.0053, Train Acc: 99.90%, Test Loss: 0.2000, Test Acc: 94.53%
# Epoch 131/200: Train Loss: 0.0052, Train Acc: 99.91%, Test Loss: 0.2028, Test Acc: 94.56%
# Epoch 132/200: Train Loss: 0.0045, Train Acc: 99.94%, Test Loss: 0.2024, Test Acc: 94.60%
# Epoch 133/200: Train Loss: 0.0045, Train Acc: 99.94%, Test Loss: 0.2020, Test Acc: 94.71%
# New best model saved with accuracy: 94.71%
# Epoch 134/200: Train Loss: 0.0044, Train Acc: 99.94%, Test Loss: 0.1998, Test Acc: 94.56%
# Epoch 135/200: Train Loss: 0.0042, Train Acc: 99.95%, Test Loss: 0.2025, Test Acc: 94.66%
# Epoch 136/200: Train Loss: 0.0038, Train Acc: 99.95%, Test Loss: 0.2016, Test Acc: 94.70%
# Epoch 137/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.2022, Test Acc: 94.58%
# Epoch 138/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.2024, Test Acc: 94.74%
# New best model saved with accuracy: 94.74%
# Epoch 139/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.2009, Test Acc: 94.65%
# Epoch 140/200: Train Loss: 0.0037, Train Acc: 99.96%, Test Loss: 0.2018, Test Acc: 94.76%
# New best model saved with accuracy: 94.76%
# Epoch 141/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1988, Test Acc: 94.62%
# Epoch 142/200: Train Loss: 0.0034, Train Acc: 99.96%, Test Loss: 0.2003, Test Acc: 94.67%
# Epoch 143/200: Train Loss: 0.0035, Train Acc: 99.96%, Test Loss: 0.1989, Test Acc: 94.67%
# Epoch 144/200: Train Loss: 0.0029, Train Acc: 99.98%, Test Loss: 0.1994, Test Acc: 94.68%
# Epoch 145/200: Train Loss: 0.0030, Train Acc: 99.98%, Test Loss: 0.1997, Test Acc: 94.67%
# Epoch 146/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1993, Test Acc: 94.70%
# Epoch 147/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.2012, Test Acc: 94.71%
# Epoch 148/200: Train Loss: 0.0029, Train Acc: 99.97%, Test Loss: 0.1999, Test Acc: 94.82%
# New best model saved with accuracy: 94.82%
# Epoch 149/200: Train Loss: 0.0026, Train Acc: 100.00%, Test Loss: 0.2012, Test Acc: 94.78%
# Epoch 150/200: Train Loss: 0.0028, Train Acc: 99.97%, Test Loss: 0.1984, Test Acc: 94.80%
# Epoch 151/200: Train Loss: 0.0025, Train Acc: 99.99%, Test Loss: 0.1993, Test Acc: 94.75%
# Epoch 152/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1970, Test Acc: 94.83%
# New best model saved with accuracy: 94.83%
# Epoch 153/200: Train Loss: 0.0027, Train Acc: 99.98%, Test Loss: 0.1971, Test Acc: 94.80%
# Epoch 154/200: Train Loss: 0.0025, Train Acc: 99.99%, Test Loss: 0.1991, Test Acc: 94.77%
# Epoch 155/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1990, Test Acc: 94.76%
# Epoch 156/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1989, Test Acc: 94.86%
# New best model saved with accuracy: 94.86%
# Epoch 157/200: Train Loss: 0.0028, Train Acc: 99.97%, Test Loss: 0.1999, Test Acc: 94.93%
# New best model saved with accuracy: 94.93%
# Epoch 158/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.2020, Test Acc: 94.71%
# Epoch 159/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1988, Test Acc: 94.92%
# Epoch 160/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.2005, Test Acc: 94.79%
# Epoch 161/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1996, Test Acc: 94.64%
# Epoch 162/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1988, Test Acc: 94.75%
# Epoch 163/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1981, Test Acc: 94.74%
# Epoch 164/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1998, Test Acc: 94.81%
# Epoch 165/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1981, Test Acc: 94.76%
# Epoch 166/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1980, Test Acc: 94.75%
# Epoch 167/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1988, Test Acc: 94.75%
# Epoch 168/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1977, Test Acc: 94.76%
# Epoch 169/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1988, Test Acc: 94.79%
# Epoch 170/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1988, Test Acc: 94.78%
# Epoch 171/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1973, Test Acc: 94.77%
# Epoch 172/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1970, Test Acc: 94.80%
# Epoch 173/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1982, Test Acc: 94.72%
# Epoch 174/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1998, Test Acc: 94.73%
# Epoch 175/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1984, Test Acc: 94.76%
# Epoch 176/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1971, Test Acc: 94.80%
# Epoch 177/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1970, Test Acc: 94.75%
# Epoch 178/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1978, Test Acc: 94.84%
# Epoch 179/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1968, Test Acc: 94.86%
# Epoch 180/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1995, Test Acc: 94.77%
# Epoch 181/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1964, Test Acc: 94.83%
# Epoch 182/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1991, Test Acc: 94.77%
# Epoch 183/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1983, Test Acc: 94.78%
# Epoch 184/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1987, Test Acc: 94.79%
# Epoch 185/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1959, Test Acc: 94.82%
# Epoch 186/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1972, Test Acc: 94.75%
# Epoch 187/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1972, Test Acc: 94.77%
# Epoch 188/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1983, Test Acc: 94.84%
# Epoch 189/200: Train Loss: 0.0020, Train Acc: 100.00%, Test Loss: 0.1982, Test Acc: 94.74%
# Epoch 190/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1972, Test Acc: 94.79%
# Epoch 191/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1969, Test Acc: 94.78%
# Epoch 192/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1983, Test Acc: 94.77%
# Epoch 193/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1989, Test Acc: 94.89%
# Epoch 194/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1984, Test Acc: 94.86%
# Epoch 195/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1978, Test Acc: 94.82%
# Epoch 196/200: Train Loss: 0.0022, Train Acc: 99.98%, Test Loss: 0.1989, Test Acc: 94.88%
# Epoch 197/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1971, Test Acc: 94.77%
# Epoch 198/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1986, Test Acc: 94.71%
# Epoch 199/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1976, Test Acc: 94.80%
# Epoch 200/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1967, Test Acc: 94.83%
# Training completed! Best accuracy: 94.93%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_model1.pth'):
        checkpoint = torch.load('model/best_model1.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 97%
# Accuracy of bird  : 93%
# Accuracy of cat   : 90%
# Accuracy of deer  : 96%
# Accuracy of dog   : 90%
# Accuracy of frog  : 97%
# Accuracy of horse : 97%
# Accuracy of ship  : 96%
# Accuracy of truck : 97%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.94      0.96      0.95      1000
#          car       0.98      0.97      0.97      1000
#         bird       0.95      0.93      0.94      1000
#          cat       0.89      0.90      0.90      1000
#         deer       0.95      0.96      0.96      1000
#          dog       0.93      0.90      0.92      1000
#         frog       0.96      0.97      0.96      1000
#        horse       0.98      0.97      0.97      1000
#         ship       0.96      0.96      0.96      1000
#        truck       0.96      0.97      0.96      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
