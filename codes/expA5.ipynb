# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=18)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=18)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA5.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.0808, Train Acc: 25.35%, Test Loss: 1.7792, Test Acc: 35.11%
# New best model saved with accuracy: 35.11%
# Epoch 2/200: Train Loss: 1.7088, Train Acc: 36.95%, Test Loss: 1.4869, Test Acc: 45.17%
# New best model saved with accuracy: 45.17%
# Epoch 3/200: Train Loss: 1.5362, Train Acc: 43.82%, Test Loss: 1.4278, Test Acc: 49.38%
# New best model saved with accuracy: 49.38%
# Epoch 4/200: Train Loss: 1.3682, Train Acc: 50.47%, Test Loss: 1.1490, Test Acc: 60.03%
# New best model saved with accuracy: 60.03%
# Epoch 5/200: Train Loss: 1.2153, Train Acc: 56.67%, Test Loss: 1.1416, Test Acc: 60.06%
# New best model saved with accuracy: 60.06%
# Epoch 6/200: Train Loss: 1.0954, Train Acc: 61.16%, Test Loss: 1.0011, Test Acc: 65.99%
# New best model saved with accuracy: 65.99%
# Epoch 7/200: Train Loss: 0.9959, Train Acc: 64.84%, Test Loss: 0.8758, Test Acc: 69.67%
# New best model saved with accuracy: 69.67%
# Epoch 8/200: Train Loss: 0.9322, Train Acc: 67.05%, Test Loss: 0.8658, Test Acc: 70.02%
# New best model saved with accuracy: 70.02%
# Epoch 9/200: Train Loss: 0.8879, Train Acc: 68.75%, Test Loss: 0.7635, Test Acc: 74.64%
# New best model saved with accuracy: 74.64%
# Epoch 10/200: Train Loss: 0.8565, Train Acc: 70.00%, Test Loss: 0.7339, Test Acc: 75.47%
# New best model saved with accuracy: 75.47%
# Epoch 11/200: Train Loss: 0.8294, Train Acc: 71.09%, Test Loss: 0.6980, Test Acc: 75.96%
# New best model saved with accuracy: 75.96%
# Epoch 12/200: Train Loss: 0.8135, Train Acc: 71.61%, Test Loss: 0.7158, Test Acc: 76.04%
# New best model saved with accuracy: 76.04%
# Epoch 13/200: Train Loss: 0.7944, Train Acc: 72.32%, Test Loss: 0.6624, Test Acc: 77.62%
# New best model saved with accuracy: 77.62%
# Epoch 14/200: Train Loss: 0.7741, Train Acc: 73.10%, Test Loss: 0.6993, Test Acc: 75.99%
# Epoch 15/200: Train Loss: 0.7700, Train Acc: 73.16%, Test Loss: 0.6365, Test Acc: 78.46%
# New best model saved with accuracy: 78.46%
# Epoch 16/200: Train Loss: 0.7591, Train Acc: 73.59%, Test Loss: 0.6709, Test Acc: 77.57%
# Epoch 17/200: Train Loss: 0.7412, Train Acc: 74.36%, Test Loss: 0.7045, Test Acc: 77.28%
# Epoch 18/200: Train Loss: 0.7341, Train Acc: 74.37%, Test Loss: 0.8059, Test Acc: 74.98%
# Epoch 19/200: Train Loss: 0.7228, Train Acc: 75.11%, Test Loss: 0.9888, Test Acc: 69.66%
# Epoch 20/200: Train Loss: 0.7128, Train Acc: 75.39%, Test Loss: 0.7657, Test Acc: 74.75%
# Epoch 21/200: Train Loss: 0.7081, Train Acc: 75.71%, Test Loss: 0.6547, Test Acc: 77.67%
# Epoch 22/200: Train Loss: 0.7006, Train Acc: 75.69%, Test Loss: 0.5765, Test Acc: 80.33%
# New best model saved with accuracy: 80.33%
# Epoch 23/200: Train Loss: 0.6998, Train Acc: 75.60%, Test Loss: 0.6952, Test Acc: 76.32%
# Epoch 24/200: Train Loss: 0.6878, Train Acc: 76.26%, Test Loss: 0.7128, Test Acc: 76.22%
# Epoch 25/200: Train Loss: 0.6871, Train Acc: 76.19%, Test Loss: 0.5368, Test Acc: 81.71%
# New best model saved with accuracy: 81.71%
# Epoch 26/200: Train Loss: 0.6856, Train Acc: 76.20%, Test Loss: 0.6277, Test Acc: 78.56%
# Epoch 27/200: Train Loss: 0.6777, Train Acc: 76.45%, Test Loss: 0.6109, Test Acc: 78.79%
# Epoch 28/200: Train Loss: 0.6755, Train Acc: 76.56%, Test Loss: 0.6263, Test Acc: 79.53%
# Epoch 29/200: Train Loss: 0.6697, Train Acc: 76.78%, Test Loss: 0.5671, Test Acc: 81.61%
# Epoch 30/200: Train Loss: 0.6693, Train Acc: 76.91%, Test Loss: 0.5535, Test Acc: 82.07%
# New best model saved with accuracy: 82.07%
# Epoch 31/200: Train Loss: 0.6693, Train Acc: 76.86%, Test Loss: 0.6884, Test Acc: 76.28%
# Epoch 32/200: Train Loss: 0.6604, Train Acc: 76.97%, Test Loss: 0.7023, Test Acc: 76.91%
# Epoch 33/200: Train Loss: 0.6569, Train Acc: 77.35%, Test Loss: 0.6299, Test Acc: 78.87%
# Epoch 34/200: Train Loss: 0.6556, Train Acc: 77.35%, Test Loss: 0.5889, Test Acc: 79.83%
# Epoch 35/200: Train Loss: 0.6579, Train Acc: 77.16%, Test Loss: 0.5603, Test Acc: 81.45%
# Epoch 36/200: Train Loss: 0.6569, Train Acc: 77.25%, Test Loss: 0.5617, Test Acc: 81.40%
# Epoch 37/200: Train Loss: 0.6531, Train Acc: 77.58%, Test Loss: 0.6331, Test Acc: 79.31%
# Epoch 38/200: Train Loss: 0.6526, Train Acc: 77.37%, Test Loss: 0.5270, Test Acc: 81.86%
# Epoch 39/200: Train Loss: 0.6502, Train Acc: 77.65%, Test Loss: 0.6278, Test Acc: 79.35%
# Epoch 40/200: Train Loss: 0.6461, Train Acc: 77.77%, Test Loss: 0.5699, Test Acc: 80.77%
# Epoch 41/200: Train Loss: 0.6486, Train Acc: 77.38%, Test Loss: 0.4772, Test Acc: 84.03%
# New best model saved with accuracy: 84.03%
# Epoch 42/200: Train Loss: 0.6471, Train Acc: 77.53%, Test Loss: 0.6645, Test Acc: 78.28%
# Epoch 43/200: Train Loss: 0.6395, Train Acc: 78.14%, Test Loss: 0.6272, Test Acc: 79.59%
# Epoch 44/200: Train Loss: 0.6462, Train Acc: 77.70%, Test Loss: 0.5066, Test Acc: 83.41%
# Epoch 45/200: Train Loss: 0.6342, Train Acc: 77.98%, Test Loss: 0.5074, Test Acc: 82.92%
# Epoch 46/200: Train Loss: 0.6373, Train Acc: 78.02%, Test Loss: 0.4922, Test Acc: 83.38%
# Epoch 47/200: Train Loss: 0.6346, Train Acc: 78.11%, Test Loss: 0.4819, Test Acc: 83.84%
# Epoch 48/200: Train Loss: 0.6291, Train Acc: 78.16%, Test Loss: 0.6814, Test Acc: 77.65%
# Epoch 49/200: Train Loss: 0.6383, Train Acc: 77.97%, Test Loss: 0.4562, Test Acc: 84.49%
# New best model saved with accuracy: 84.49%
# Epoch 50/200: Train Loss: 0.6351, Train Acc: 78.05%, Test Loss: 0.5115, Test Acc: 82.38%
# Epoch 51/200: Train Loss: 0.6383, Train Acc: 77.95%, Test Loss: 0.5031, Test Acc: 82.75%
# Epoch 52/200: Train Loss: 0.6294, Train Acc: 78.26%, Test Loss: 0.5300, Test Acc: 82.60%
# Epoch 53/200: Train Loss: 0.6330, Train Acc: 78.16%, Test Loss: 0.5395, Test Acc: 82.32%
# Epoch 54/200: Train Loss: 0.6309, Train Acc: 78.21%, Test Loss: 0.6145, Test Acc: 79.86%
# Epoch 55/200: Train Loss: 0.6262, Train Acc: 78.31%, Test Loss: 0.6827, Test Acc: 76.83%
# Epoch 56/200: Train Loss: 0.6255, Train Acc: 78.43%, Test Loss: 0.5500, Test Acc: 81.36%
# Epoch 57/200: Train Loss: 0.6252, Train Acc: 78.49%, Test Loss: 0.5769, Test Acc: 80.26%
# Epoch 58/200: Train Loss: 0.6235, Train Acc: 78.44%, Test Loss: 0.5046, Test Acc: 82.76%
# Epoch 59/200: Train Loss: 0.6245, Train Acc: 78.35%, Test Loss: 0.5139, Test Acc: 82.85%
# Epoch 60/200: Train Loss: 0.6279, Train Acc: 78.36%, Test Loss: 0.5467, Test Acc: 81.34%
# Epoch 61/200: Train Loss: 0.6181, Train Acc: 78.59%, Test Loss: 0.4938, Test Acc: 83.38%
# Epoch 62/200: Train Loss: 0.6268, Train Acc: 78.38%, Test Loss: 0.6060, Test Acc: 80.12%
# Epoch 63/200: Train Loss: 0.6199, Train Acc: 78.58%, Test Loss: 0.6682, Test Acc: 78.66%
# Epoch 64/200: Train Loss: 0.6242, Train Acc: 78.56%, Test Loss: 0.6787, Test Acc: 77.84%
# Epoch 65/200: Train Loss: 0.6199, Train Acc: 78.72%, Test Loss: 0.5756, Test Acc: 80.98%
# Epoch 66/200: Train Loss: 0.6189, Train Acc: 78.61%, Test Loss: 0.6004, Test Acc: 78.56%
# Epoch 67/200: Train Loss: 0.6210, Train Acc: 78.42%, Test Loss: 0.5192, Test Acc: 82.61%
# Epoch 68/200: Train Loss: 0.6232, Train Acc: 78.38%, Test Loss: 0.5306, Test Acc: 82.10%
# Epoch 69/200: Train Loss: 0.6124, Train Acc: 79.02%, Test Loss: 0.6634, Test Acc: 78.65%
# Epoch 70/200: Train Loss: 0.6196, Train Acc: 78.69%, Test Loss: 0.6865, Test Acc: 78.59%
# Epoch 71/200: Train Loss: 0.4321, Train Acc: 84.99%, Test Loss: 0.2606, Test Acc: 90.94%
# New best model saved with accuracy: 90.94%
# Epoch 72/200: Train Loss: 0.3674, Train Acc: 87.33%, Test Loss: 0.2430, Test Acc: 91.38%
# New best model saved with accuracy: 91.38%
# Epoch 73/200: Train Loss: 0.3477, Train Acc: 87.90%, Test Loss: 0.2289, Test Acc: 91.98%
# New best model saved with accuracy: 91.98%
# Epoch 74/200: Train Loss: 0.3331, Train Acc: 88.51%, Test Loss: 0.2220, Test Acc: 92.31%
# New best model saved with accuracy: 92.31%
# Epoch 75/200: Train Loss: 0.3194, Train Acc: 88.84%, Test Loss: 0.2229, Test Acc: 92.27%
# Epoch 76/200: Train Loss: 0.3130, Train Acc: 89.26%, Test Loss: 0.2241, Test Acc: 92.46%
# New best model saved with accuracy: 92.46%
# Epoch 77/200: Train Loss: 0.3102, Train Acc: 89.26%, Test Loss: 0.2280, Test Acc: 92.34%
# Epoch 78/200: Train Loss: 0.3043, Train Acc: 89.34%, Test Loss: 0.2160, Test Acc: 92.71%
# New best model saved with accuracy: 92.71%
# Epoch 79/200: Train Loss: 0.2938, Train Acc: 89.88%, Test Loss: 0.2071, Test Acc: 92.92%
# New best model saved with accuracy: 92.92%
# Epoch 80/200: Train Loss: 0.2872, Train Acc: 90.03%, Test Loss: 0.2250, Test Acc: 92.17%
# Epoch 81/200: Train Loss: 0.2868, Train Acc: 90.02%, Test Loss: 0.2180, Test Acc: 92.81%
# Epoch 82/200: Train Loss: 0.2805, Train Acc: 90.19%, Test Loss: 0.2014, Test Acc: 93.27%
# New best model saved with accuracy: 93.27%
# Epoch 83/200: Train Loss: 0.2756, Train Acc: 90.41%, Test Loss: 0.2168, Test Acc: 92.70%
# Epoch 84/200: Train Loss: 0.2682, Train Acc: 90.70%, Test Loss: 0.2065, Test Acc: 93.33%
# New best model saved with accuracy: 93.33%
# Epoch 85/200: Train Loss: 0.2703, Train Acc: 90.64%, Test Loss: 0.2050, Test Acc: 93.04%
# Epoch 86/200: Train Loss: 0.2669, Train Acc: 90.80%, Test Loss: 0.2012, Test Acc: 93.36%
# New best model saved with accuracy: 93.36%
# Epoch 87/200: Train Loss: 0.2655, Train Acc: 90.80%, Test Loss: 0.2069, Test Acc: 93.27%
# Epoch 88/200: Train Loss: 0.2637, Train Acc: 90.71%, Test Loss: 0.2163, Test Acc: 92.92%
# Epoch 89/200: Train Loss: 0.2606, Train Acc: 90.79%, Test Loss: 0.2172, Test Acc: 92.87%
# Epoch 90/200: Train Loss: 0.2648, Train Acc: 90.73%, Test Loss: 0.2159, Test Acc: 92.84%
# Epoch 91/200: Train Loss: 0.2613, Train Acc: 90.94%, Test Loss: 0.2155, Test Acc: 92.93%
# Epoch 92/200: Train Loss: 0.2525, Train Acc: 91.38%, Test Loss: 0.2258, Test Acc: 92.85%
# Epoch 93/200: Train Loss: 0.2615, Train Acc: 90.89%, Test Loss: 0.2224, Test Acc: 92.57%
# Epoch 94/200: Train Loss: 0.2550, Train Acc: 91.05%, Test Loss: 0.2104, Test Acc: 93.21%
# Epoch 95/200: Train Loss: 0.2566, Train Acc: 90.97%, Test Loss: 0.2159, Test Acc: 92.92%
# Epoch 96/200: Train Loss: 0.2562, Train Acc: 91.08%, Test Loss: 0.2260, Test Acc: 92.65%
# Epoch 97/200: Train Loss: 0.2569, Train Acc: 91.03%, Test Loss: 0.2091, Test Acc: 93.01%
# Epoch 98/200: Train Loss: 0.2540, Train Acc: 91.18%, Test Loss: 0.2414, Test Acc: 92.34%
# Epoch 99/200: Train Loss: 0.2538, Train Acc: 91.16%, Test Loss: 0.2136, Test Acc: 92.90%
# Epoch 100/200: Train Loss: 0.2515, Train Acc: 91.08%, Test Loss: 0.2387, Test Acc: 92.18%
# Epoch 101/200: Train Loss: 0.2508, Train Acc: 91.34%, Test Loss: 0.2068, Test Acc: 93.09%
# Epoch 102/200: Train Loss: 0.2530, Train Acc: 91.28%, Test Loss: 0.2156, Test Acc: 92.81%
# Epoch 103/200: Train Loss: 0.2553, Train Acc: 91.09%, Test Loss: 0.2164, Test Acc: 92.68%
# Epoch 104/200: Train Loss: 0.2486, Train Acc: 91.44%, Test Loss: 0.2215, Test Acc: 92.61%
# Epoch 105/200: Train Loss: 0.2533, Train Acc: 91.20%, Test Loss: 0.2173, Test Acc: 92.79%
# Epoch 106/200: Train Loss: 0.2492, Train Acc: 91.42%, Test Loss: 0.2371, Test Acc: 92.46%
# Epoch 107/200: Train Loss: 0.2515, Train Acc: 91.21%, Test Loss: 0.2216, Test Acc: 92.82%
# Epoch 108/200: Train Loss: 0.2452, Train Acc: 91.53%, Test Loss: 0.2213, Test Acc: 92.72%
# Epoch 109/200: Train Loss: 0.2519, Train Acc: 91.30%, Test Loss: 0.2196, Test Acc: 92.70%
# Epoch 110/200: Train Loss: 0.2467, Train Acc: 91.49%, Test Loss: 0.2428, Test Acc: 92.01%
# Epoch 111/200: Train Loss: 0.2440, Train Acc: 91.57%, Test Loss: 0.2294, Test Acc: 92.72%
# Epoch 112/200: Train Loss: 0.2509, Train Acc: 91.32%, Test Loss: 0.2318, Test Acc: 92.76%
# Epoch 113/200: Train Loss: 0.2505, Train Acc: 91.21%, Test Loss: 0.2222, Test Acc: 92.91%
# Epoch 114/200: Train Loss: 0.2480, Train Acc: 91.42%, Test Loss: 0.2340, Test Acc: 92.46%
# Epoch 115/200: Train Loss: 0.2465, Train Acc: 91.43%, Test Loss: 0.2286, Test Acc: 92.58%
# Epoch 116/200: Train Loss: 0.2483, Train Acc: 91.38%, Test Loss: 0.2297, Test Acc: 92.57%
# Epoch 117/200: Train Loss: 0.2452, Train Acc: 91.52%, Test Loss: 0.2318, Test Acc: 92.56%
# Epoch 118/200: Train Loss: 0.2441, Train Acc: 91.52%, Test Loss: 0.2442, Test Acc: 92.37%
# Epoch 119/200: Train Loss: 0.2429, Train Acc: 91.58%, Test Loss: 0.2392, Test Acc: 91.97%
# Epoch 120/200: Train Loss: 0.2401, Train Acc: 91.66%, Test Loss: 0.2315, Test Acc: 92.54%
# Epoch 121/200: Train Loss: 0.1883, Train Acc: 93.65%, Test Loss: 0.1701, Test Acc: 94.45%
# New best model saved with accuracy: 94.45%
# Epoch 122/200: Train Loss: 0.1608, Train Acc: 94.46%, Test Loss: 0.1660, Test Acc: 94.72%
# New best model saved with accuracy: 94.72%
# Epoch 123/200: Train Loss: 0.1550, Train Acc: 94.73%, Test Loss: 0.1617, Test Acc: 94.92%
# New best model saved with accuracy: 94.92%
# Epoch 124/200: Train Loss: 0.1501, Train Acc: 94.83%, Test Loss: 0.1640, Test Acc: 94.78%
# Epoch 125/200: Train Loss: 0.1441, Train Acc: 95.07%, Test Loss: 0.1604, Test Acc: 94.91%
# Epoch 126/200: Train Loss: 0.1397, Train Acc: 95.26%, Test Loss: 0.1615, Test Acc: 94.78%
# Epoch 127/200: Train Loss: 0.1350, Train Acc: 95.46%, Test Loss: 0.1619, Test Acc: 95.00%
# New best model saved with accuracy: 95.00%
# Epoch 128/200: Train Loss: 0.1337, Train Acc: 95.41%, Test Loss: 0.1644, Test Acc: 94.69%
# Epoch 129/200: Train Loss: 0.1317, Train Acc: 95.55%, Test Loss: 0.1609, Test Acc: 94.95%
# Epoch 130/200: Train Loss: 0.1276, Train Acc: 95.65%, Test Loss: 0.1660, Test Acc: 94.71%
# Epoch 131/200: Train Loss: 0.1261, Train Acc: 95.67%, Test Loss: 0.1603, Test Acc: 94.79%
# Epoch 132/200: Train Loss: 0.1287, Train Acc: 95.62%, Test Loss: 0.1607, Test Acc: 94.95%
# Epoch 133/200: Train Loss: 0.1241, Train Acc: 95.77%, Test Loss: 0.1565, Test Acc: 95.08%
# New best model saved with accuracy: 95.08%
# Epoch 134/200: Train Loss: 0.1234, Train Acc: 95.72%, Test Loss: 0.1599, Test Acc: 94.92%
# Epoch 135/200: Train Loss: 0.1248, Train Acc: 95.79%, Test Loss: 0.1614, Test Acc: 95.01%
# Epoch 136/200: Train Loss: 0.1239, Train Acc: 95.90%, Test Loss: 0.1625, Test Acc: 94.99%
# Epoch 137/200: Train Loss: 0.1190, Train Acc: 96.04%, Test Loss: 0.1637, Test Acc: 94.89%
# Epoch 138/200: Train Loss: 0.1173, Train Acc: 96.08%, Test Loss: 0.1601, Test Acc: 94.98%
# Epoch 139/200: Train Loss: 0.1136, Train Acc: 96.11%, Test Loss: 0.1605, Test Acc: 95.07%
# Epoch 140/200: Train Loss: 0.1163, Train Acc: 95.97%, Test Loss: 0.1613, Test Acc: 95.07%
# Epoch 141/200: Train Loss: 0.1116, Train Acc: 96.24%, Test Loss: 0.1654, Test Acc: 95.01%
# Epoch 142/200: Train Loss: 0.1114, Train Acc: 96.29%, Test Loss: 0.1635, Test Acc: 94.96%
# Epoch 143/200: Train Loss: 0.1102, Train Acc: 96.27%, Test Loss: 0.1604, Test Acc: 95.09%
# New best model saved with accuracy: 95.09%
# Epoch 144/200: Train Loss: 0.1109, Train Acc: 96.25%, Test Loss: 0.1634, Test Acc: 94.94%
# Epoch 145/200: Train Loss: 0.1112, Train Acc: 96.12%, Test Loss: 0.1619, Test Acc: 95.12%
# New best model saved with accuracy: 95.12%
# Epoch 146/200: Train Loss: 0.1121, Train Acc: 96.18%, Test Loss: 0.1641, Test Acc: 95.06%
# Epoch 147/200: Train Loss: 0.1088, Train Acc: 96.28%, Test Loss: 0.1635, Test Acc: 95.11%
# Epoch 148/200: Train Loss: 0.1101, Train Acc: 96.23%, Test Loss: 0.1646, Test Acc: 94.99%
# Epoch 149/200: Train Loss: 0.1090, Train Acc: 96.29%, Test Loss: 0.1637, Test Acc: 95.06%
# Epoch 150/200: Train Loss: 0.1045, Train Acc: 96.48%, Test Loss: 0.1632, Test Acc: 94.93%
# Epoch 151/200: Train Loss: 0.1066, Train Acc: 96.44%, Test Loss: 0.1668, Test Acc: 94.97%
# Epoch 152/200: Train Loss: 0.1057, Train Acc: 96.49%, Test Loss: 0.1638, Test Acc: 95.01%
# Epoch 153/200: Train Loss: 0.1025, Train Acc: 96.48%, Test Loss: 0.1673, Test Acc: 94.96%
# Epoch 154/200: Train Loss: 0.1030, Train Acc: 96.49%, Test Loss: 0.1653, Test Acc: 95.08%
# Epoch 155/200: Train Loss: 0.1017, Train Acc: 96.65%, Test Loss: 0.1679, Test Acc: 94.93%
# Epoch 156/200: Train Loss: 0.1044, Train Acc: 96.50%, Test Loss: 0.1665, Test Acc: 94.92%
# Epoch 157/200: Train Loss: 0.1042, Train Acc: 96.50%, Test Loss: 0.1675, Test Acc: 94.90%
# Epoch 158/200: Train Loss: 0.1019, Train Acc: 96.55%, Test Loss: 0.1625, Test Acc: 95.28%
# New best model saved with accuracy: 95.28%
# Epoch 159/200: Train Loss: 0.1014, Train Acc: 96.56%, Test Loss: 0.1658, Test Acc: 94.95%
# Epoch 160/200: Train Loss: 0.1006, Train Acc: 96.65%, Test Loss: 0.1625, Test Acc: 95.23%
# Epoch 161/200: Train Loss: 0.0950, Train Acc: 96.81%, Test Loss: 0.1619, Test Acc: 95.25%
# Epoch 162/200: Train Loss: 0.0966, Train Acc: 96.76%, Test Loss: 0.1606, Test Acc: 95.37%
# New best model saved with accuracy: 95.37%
# Epoch 163/200: Train Loss: 0.0925, Train Acc: 96.87%, Test Loss: 0.1623, Test Acc: 95.28%
# Epoch 164/200: Train Loss: 0.0916, Train Acc: 96.87%, Test Loss: 0.1602, Test Acc: 95.37%
# Epoch 165/200: Train Loss: 0.0947, Train Acc: 96.81%, Test Loss: 0.1619, Test Acc: 95.31%
# Epoch 166/200: Train Loss: 0.0909, Train Acc: 96.93%, Test Loss: 0.1602, Test Acc: 95.25%
# Epoch 167/200: Train Loss: 0.0903, Train Acc: 96.98%, Test Loss: 0.1613, Test Acc: 95.31%
# Epoch 168/200: Train Loss: 0.0864, Train Acc: 97.15%, Test Loss: 0.1608, Test Acc: 95.26%
# Epoch 169/200: Train Loss: 0.0923, Train Acc: 96.95%, Test Loss: 0.1605, Test Acc: 95.12%
# Epoch 170/200: Train Loss: 0.0910, Train Acc: 96.97%, Test Loss: 0.1609, Test Acc: 95.20%
# Epoch 171/200: Train Loss: 0.0901, Train Acc: 96.89%, Test Loss: 0.1600, Test Acc: 95.22%
# Epoch 172/200: Train Loss: 0.0928, Train Acc: 96.93%, Test Loss: 0.1597, Test Acc: 95.28%
# Epoch 173/200: Train Loss: 0.0898, Train Acc: 96.98%, Test Loss: 0.1606, Test Acc: 95.24%
# Epoch 174/200: Train Loss: 0.0883, Train Acc: 97.05%, Test Loss: 0.1606, Test Acc: 95.29%
# Epoch 175/200: Train Loss: 0.0874, Train Acc: 97.18%, Test Loss: 0.1601, Test Acc: 95.31%
# Epoch 176/200: Train Loss: 0.0901, Train Acc: 96.97%, Test Loss: 0.1595, Test Acc: 95.35%
# Epoch 177/200: Train Loss: 0.0894, Train Acc: 97.01%, Test Loss: 0.1591, Test Acc: 95.34%
# Epoch 178/200: Train Loss: 0.0932, Train Acc: 96.80%, Test Loss: 0.1603, Test Acc: 95.34%
# Epoch 179/200: Train Loss: 0.0915, Train Acc: 97.01%, Test Loss: 0.1606, Test Acc: 95.26%
# Epoch 180/200: Train Loss: 0.0877, Train Acc: 97.04%, Test Loss: 0.1618, Test Acc: 95.30%
# Epoch 181/200: Train Loss: 0.0881, Train Acc: 97.01%, Test Loss: 0.1613, Test Acc: 95.36%
# Epoch 182/200: Train Loss: 0.0897, Train Acc: 96.95%, Test Loss: 0.1594, Test Acc: 95.29%
# Epoch 183/200: Train Loss: 0.0898, Train Acc: 97.06%, Test Loss: 0.1592, Test Acc: 95.36%
# Epoch 184/200: Train Loss: 0.0880, Train Acc: 97.01%, Test Loss: 0.1578, Test Acc: 95.36%
# Epoch 185/200: Train Loss: 0.0883, Train Acc: 97.09%, Test Loss: 0.1593, Test Acc: 95.27%
# Epoch 186/200: Train Loss: 0.0908, Train Acc: 96.97%, Test Loss: 0.1592, Test Acc: 95.23%
# Epoch 187/200: Train Loss: 0.0875, Train Acc: 97.06%, Test Loss: 0.1595, Test Acc: 95.32%
# Epoch 188/200: Train Loss: 0.0863, Train Acc: 97.06%, Test Loss: 0.1598, Test Acc: 95.27%
# Epoch 189/200: Train Loss: 0.0860, Train Acc: 97.18%, Test Loss: 0.1589, Test Acc: 95.33%
# Epoch 190/200: Train Loss: 0.0868, Train Acc: 97.13%, Test Loss: 0.1592, Test Acc: 95.39%
# New best model saved with accuracy: 95.39%
# Epoch 191/200: Train Loss: 0.0894, Train Acc: 97.01%, Test Loss: 0.1586, Test Acc: 95.27%
# Epoch 192/200: Train Loss: 0.0849, Train Acc: 97.15%, Test Loss: 0.1591, Test Acc: 95.24%
# Epoch 193/200: Train Loss: 0.0892, Train Acc: 96.98%, Test Loss: 0.1596, Test Acc: 95.31%
# Epoch 194/200: Train Loss: 0.0891, Train Acc: 96.95%, Test Loss: 0.1601, Test Acc: 95.25%
# Epoch 195/200: Train Loss: 0.0894, Train Acc: 96.98%, Test Loss: 0.1597, Test Acc: 95.35%
# Epoch 196/200: Train Loss: 0.0864, Train Acc: 97.00%, Test Loss: 0.1590, Test Acc: 95.32%
# Epoch 197/200: Train Loss: 0.0861, Train Acc: 97.03%, Test Loss: 0.1577, Test Acc: 95.33%
# Epoch 198/200: Train Loss: 0.0839, Train Acc: 97.21%, Test Loss: 0.1587, Test Acc: 95.30%
# Epoch 199/200: Train Loss: 0.0869, Train Acc: 97.00%, Test Loss: 0.1590, Test Acc: 95.31%
# Epoch 200/200: Train Loss: 0.0880, Train Acc: 97.15%, Test Loss: 0.1605, Test Acc: 95.23%
# Training completed! Best accuracy: 95.39%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA5.pth'):
        checkpoint = torch.load('model/best_modelA5.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 95%
# Accuracy of car   : 98%
# Accuracy of bird  : 94%
# Accuracy of cat   : 91%
# Accuracy of deer  : 96%
# Accuracy of dog   : 91%
# Accuracy of frog  : 97%
# Accuracy of horse : 98%
# Accuracy of ship  : 98%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.97      0.95      0.96      1000
#          car       0.98      0.98      0.98      1000
#         bird       0.94      0.94      0.94      1000
#          cat       0.90      0.91      0.90      1000
#         deer       0.94      0.96      0.95      1000
#          dog       0.92      0.91      0.92      1000
#         frog       0.97      0.97      0.97      1000
#        horse       0.98      0.98      0.98      1000
#         ship       0.96      0.98      0.97      1000
#        truck       0.97      0.96      0.97      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
