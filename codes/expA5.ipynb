# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA5.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.0974, Train Acc: 24.52%, Test Loss: 1.7570, Test Acc: 35.69%
# New best model saved with accuracy: 35.69%
# Epoch 2/200: Train Loss: 1.7975, Train Acc: 33.42%, Test Loss: 1.5898, Test Acc: 39.97%
# New best model saved with accuracy: 39.97%
# Epoch 3/200: Train Loss: 1.6765, Train Acc: 38.39%, Test Loss: 1.5299, Test Acc: 44.44%
# New best model saved with accuracy: 44.44%
# Epoch 4/200: Train Loss: 1.5456, Train Acc: 43.75%, Test Loss: 1.3061, Test Acc: 53.82%
# New best model saved with accuracy: 53.82%
# Epoch 5/200: Train Loss: 1.3577, Train Acc: 51.20%, Test Loss: 1.1618, Test Acc: 58.90%
# New best model saved with accuracy: 58.90%
# Epoch 6/200: Train Loss: 1.2116, Train Acc: 56.72%, Test Loss: 1.0811, Test Acc: 62.19%
# New best model saved with accuracy: 62.19%
# Epoch 7/200: Train Loss: 1.1084, Train Acc: 60.83%, Test Loss: 1.0309, Test Acc: 64.27%
# New best model saved with accuracy: 64.27%
# Epoch 8/200: Train Loss: 1.0199, Train Acc: 63.96%, Test Loss: 0.8733, Test Acc: 70.66%
# New best model saved with accuracy: 70.66%
# Epoch 9/200: Train Loss: 0.9437, Train Acc: 66.73%, Test Loss: 0.9151, Test Acc: 68.76%
# Epoch 10/200: Train Loss: 0.9034, Train Acc: 68.50%, Test Loss: 0.7487, Test Acc: 74.31%
# New best model saved with accuracy: 74.31%
# Epoch 11/200: Train Loss: 0.8729, Train Acc: 69.35%, Test Loss: 0.6906, Test Acc: 76.60%
# New best model saved with accuracy: 76.60%
# Epoch 12/200: Train Loss: 0.8437, Train Acc: 70.31%, Test Loss: 0.6690, Test Acc: 76.46%
# Epoch 13/200: Train Loss: 0.8228, Train Acc: 71.23%, Test Loss: 0.7893, Test Acc: 72.34%
# Epoch 14/200: Train Loss: 0.8060, Train Acc: 71.85%, Test Loss: 0.6587, Test Acc: 76.87%
# New best model saved with accuracy: 76.87%
# Epoch 15/200: Train Loss: 0.7926, Train Acc: 72.47%, Test Loss: 0.7653, Test Acc: 75.27%
# Epoch 16/200: Train Loss: 0.7760, Train Acc: 72.96%, Test Loss: 0.6274, Test Acc: 78.35%
# New best model saved with accuracy: 78.35%
# Epoch 17/200: Train Loss: 0.7546, Train Acc: 73.80%, Test Loss: 0.6497, Test Acc: 77.66%
# Epoch 18/200: Train Loss: 0.7470, Train Acc: 74.26%, Test Loss: 0.5881, Test Acc: 79.43%
# New best model saved with accuracy: 79.43%
# Epoch 19/200: Train Loss: 0.7474, Train Acc: 74.24%, Test Loss: 0.5917, Test Acc: 79.41%
# Epoch 20/200: Train Loss: 0.7360, Train Acc: 74.56%, Test Loss: 0.6639, Test Acc: 77.73%
# Epoch 21/200: Train Loss: 0.7248, Train Acc: 74.69%, Test Loss: 0.6372, Test Acc: 77.70%
# Epoch 22/200: Train Loss: 0.7172, Train Acc: 75.00%, Test Loss: 0.6360, Test Acc: 79.27%
# Epoch 23/200: Train Loss: 0.7125, Train Acc: 75.38%, Test Loss: 0.7314, Test Acc: 76.01%
# Epoch 24/200: Train Loss: 0.7111, Train Acc: 75.20%, Test Loss: 0.5766, Test Acc: 80.02%
# New best model saved with accuracy: 80.02%
# Epoch 25/200: Train Loss: 0.7055, Train Acc: 75.53%, Test Loss: 0.7182, Test Acc: 76.20%
# Epoch 26/200: Train Loss: 0.7038, Train Acc: 75.47%, Test Loss: 0.4920, Test Acc: 83.72%
# New best model saved with accuracy: 83.72%
# Epoch 27/200: Train Loss: 0.6827, Train Acc: 76.52%, Test Loss: 0.6236, Test Acc: 78.73%
# Epoch 28/200: Train Loss: 0.6926, Train Acc: 75.94%, Test Loss: 0.6092, Test Acc: 79.64%
# Epoch 29/200: Train Loss: 0.6798, Train Acc: 76.66%, Test Loss: 0.7954, Test Acc: 75.11%
# Epoch 30/200: Train Loss: 0.6785, Train Acc: 76.69%, Test Loss: 0.5730, Test Acc: 81.13%
# Epoch 31/200: Train Loss: 0.6790, Train Acc: 76.56%, Test Loss: 0.6837, Test Acc: 77.98%
# Epoch 32/200: Train Loss: 0.6704, Train Acc: 76.76%, Test Loss: 0.6310, Test Acc: 79.63%
# Epoch 33/200: Train Loss: 0.6697, Train Acc: 76.69%, Test Loss: 0.5680, Test Acc: 80.39%
# Epoch 34/200: Train Loss: 0.6657, Train Acc: 77.16%, Test Loss: 0.5397, Test Acc: 81.46%
# Epoch 35/200: Train Loss: 0.6660, Train Acc: 77.01%, Test Loss: 0.7446, Test Acc: 76.31%
# Epoch 36/200: Train Loss: 0.6621, Train Acc: 77.16%, Test Loss: 0.4965, Test Acc: 83.01%
# Epoch 37/200: Train Loss: 0.6632, Train Acc: 77.03%, Test Loss: 0.7884, Test Acc: 73.72%
# Epoch 38/200: Train Loss: 0.6587, Train Acc: 76.95%, Test Loss: 0.7011, Test Acc: 76.68%
# Epoch 39/200: Train Loss: 0.6595, Train Acc: 77.19%, Test Loss: 0.6455, Test Acc: 79.26%
# Epoch 40/200: Train Loss: 0.6525, Train Acc: 77.43%, Test Loss: 0.5398, Test Acc: 82.21%
# Epoch 41/200: Train Loss: 0.6476, Train Acc: 77.51%, Test Loss: 0.7491, Test Acc: 75.78%
# Epoch 42/200: Train Loss: 0.6491, Train Acc: 77.61%, Test Loss: 0.5301, Test Acc: 82.12%
# Epoch 43/200: Train Loss: 0.6580, Train Acc: 77.12%, Test Loss: 0.6378, Test Acc: 78.67%
# Epoch 44/200: Train Loss: 0.6458, Train Acc: 77.83%, Test Loss: 0.5458, Test Acc: 81.10%
# Epoch 45/200: Train Loss: 0.6348, Train Acc: 78.10%, Test Loss: 0.5083, Test Acc: 83.07%
# Epoch 46/200: Train Loss: 0.6464, Train Acc: 77.65%, Test Loss: 0.7810, Test Acc: 76.48%
# Epoch 47/200: Train Loss: 0.6359, Train Acc: 78.09%, Test Loss: 0.5363, Test Acc: 81.50%
# Epoch 48/200: Train Loss: 0.6442, Train Acc: 77.58%, Test Loss: 0.8399, Test Acc: 73.03%
# Epoch 49/200: Train Loss: 0.6414, Train Acc: 77.89%, Test Loss: 0.5634, Test Acc: 80.56%
# Epoch 50/200: Train Loss: 0.6300, Train Acc: 78.40%, Test Loss: 0.5651, Test Acc: 80.92%
# Epoch 51/200: Train Loss: 0.6348, Train Acc: 78.15%, Test Loss: 0.5236, Test Acc: 82.40%
# Epoch 52/200: Train Loss: 0.6340, Train Acc: 78.23%, Test Loss: 0.6498, Test Acc: 77.94%
# Epoch 53/200: Train Loss: 0.6448, Train Acc: 77.74%, Test Loss: 0.6712, Test Acc: 78.21%
# Epoch 54/200: Train Loss: 0.6298, Train Acc: 78.28%, Test Loss: 0.5531, Test Acc: 81.34%
# Epoch 55/200: Train Loss: 0.6355, Train Acc: 77.87%, Test Loss: 0.5278, Test Acc: 81.86%
# Epoch 56/200: Train Loss: 0.6320, Train Acc: 78.17%, Test Loss: 0.5485, Test Acc: 81.98%
# Epoch 57/200: Train Loss: 0.6315, Train Acc: 77.98%, Test Loss: 0.6238, Test Acc: 78.64%
# Epoch 58/200: Train Loss: 0.6299, Train Acc: 78.09%, Test Loss: 0.6371, Test Acc: 78.87%
# Epoch 59/200: Train Loss: 0.6214, Train Acc: 78.68%, Test Loss: 0.4953, Test Acc: 83.35%
# Epoch 60/200: Train Loss: 0.6261, Train Acc: 78.21%, Test Loss: 0.4949, Test Acc: 83.41%
# Epoch 61/200: Train Loss: 0.6244, Train Acc: 78.54%, Test Loss: 0.5764, Test Acc: 80.85%
# Epoch 62/200: Train Loss: 0.6295, Train Acc: 78.29%, Test Loss: 0.4544, Test Acc: 84.62%
# New best model saved with accuracy: 84.62%
# Epoch 63/200: Train Loss: 0.6270, Train Acc: 78.37%, Test Loss: 0.6295, Test Acc: 78.96%
# Epoch 64/200: Train Loss: 0.6285, Train Acc: 78.27%, Test Loss: 0.5203, Test Acc: 82.16%
# Epoch 65/200: Train Loss: 0.6300, Train Acc: 78.32%, Test Loss: 0.5799, Test Acc: 80.98%
# Epoch 66/200: Train Loss: 0.6221, Train Acc: 78.61%, Test Loss: 0.5080, Test Acc: 83.19%
# Epoch 67/200: Train Loss: 0.6232, Train Acc: 78.54%, Test Loss: 0.6598, Test Acc: 78.07%
# Epoch 68/200: Train Loss: 0.6269, Train Acc: 78.40%, Test Loss: 0.5605, Test Acc: 80.93%
# Epoch 69/200: Train Loss: 0.6222, Train Acc: 78.53%, Test Loss: 0.5970, Test Acc: 80.02%
# Epoch 70/200: Train Loss: 0.6231, Train Acc: 78.61%, Test Loss: 0.5408, Test Acc: 81.62%
# Epoch 71/200: Train Loss: 0.4448, Train Acc: 84.73%, Test Loss: 0.2639, Test Acc: 90.63%
# New best model saved with accuracy: 90.63%
# Epoch 72/200: Train Loss: 0.3720, Train Acc: 87.23%, Test Loss: 0.2490, Test Acc: 91.35%
# New best model saved with accuracy: 91.35%
# Epoch 73/200: Train Loss: 0.3503, Train Acc: 87.92%, Test Loss: 0.2359, Test Acc: 92.01%
# New best model saved with accuracy: 92.01%
# Epoch 74/200: Train Loss: 0.3341, Train Acc: 88.55%, Test Loss: 0.2352, Test Acc: 91.81%
# Epoch 75/200: Train Loss: 0.3189, Train Acc: 88.87%, Test Loss: 0.2193, Test Acc: 92.33%
# New best model saved with accuracy: 92.33%
# Epoch 76/200: Train Loss: 0.3134, Train Acc: 89.09%, Test Loss: 0.2217, Test Acc: 92.28%
# Epoch 77/200: Train Loss: 0.3037, Train Acc: 89.38%, Test Loss: 0.2199, Test Acc: 92.26%
# Epoch 78/200: Train Loss: 0.2997, Train Acc: 89.56%, Test Loss: 0.2289, Test Acc: 92.18%
# Epoch 79/200: Train Loss: 0.3002, Train Acc: 89.63%, Test Loss: 0.2145, Test Acc: 92.63%
# New best model saved with accuracy: 92.63%
# Epoch 80/200: Train Loss: 0.2904, Train Acc: 89.83%, Test Loss: 0.2132, Test Acc: 92.69%
# New best model saved with accuracy: 92.69%
# Epoch 81/200: Train Loss: 0.2809, Train Acc: 90.19%, Test Loss: 0.2125, Test Acc: 92.88%
# New best model saved with accuracy: 92.88%
# Epoch 82/200: Train Loss: 0.2776, Train Acc: 90.26%, Test Loss: 0.2100, Test Acc: 92.94%
# New best model saved with accuracy: 92.94%
# Epoch 83/200: Train Loss: 0.2743, Train Acc: 90.39%, Test Loss: 0.2293, Test Acc: 92.25%
# Epoch 84/200: Train Loss: 0.2699, Train Acc: 90.62%, Test Loss: 0.2130, Test Acc: 92.74%
# Epoch 85/200: Train Loss: 0.2711, Train Acc: 90.58%, Test Loss: 0.2052, Test Acc: 92.78%
# Epoch 86/200: Train Loss: 0.2646, Train Acc: 90.87%, Test Loss: 0.2159, Test Acc: 92.63%
# Epoch 87/200: Train Loss: 0.2623, Train Acc: 90.88%, Test Loss: 0.2072, Test Acc: 93.27%
# New best model saved with accuracy: 93.27%
# Epoch 88/200: Train Loss: 0.2640, Train Acc: 90.88%, Test Loss: 0.2034, Test Acc: 93.06%
# Epoch 89/200: Train Loss: 0.2624, Train Acc: 90.90%, Test Loss: 0.2119, Test Acc: 92.83%
# Epoch 90/200: Train Loss: 0.2615, Train Acc: 90.97%, Test Loss: 0.2166, Test Acc: 92.94%
# Epoch 91/200: Train Loss: 0.2542, Train Acc: 91.28%, Test Loss: 0.2245, Test Acc: 92.53%
# Epoch 92/200: Train Loss: 0.2610, Train Acc: 90.97%, Test Loss: 0.2269, Test Acc: 92.48%
# Epoch 93/200: Train Loss: 0.2547, Train Acc: 91.16%, Test Loss: 0.2220, Test Acc: 92.69%
# Epoch 94/200: Train Loss: 0.2559, Train Acc: 91.17%, Test Loss: 0.2222, Test Acc: 92.83%
# Epoch 95/200: Train Loss: 0.2511, Train Acc: 91.33%, Test Loss: 0.2239, Test Acc: 92.73%
# Epoch 96/200: Train Loss: 0.2541, Train Acc: 91.13%, Test Loss: 0.2346, Test Acc: 92.27%
# Epoch 97/200: Train Loss: 0.2517, Train Acc: 91.24%, Test Loss: 0.2292, Test Acc: 92.53%
# Epoch 98/200: Train Loss: 0.2481, Train Acc: 91.35%, Test Loss: 0.2152, Test Acc: 92.80%
# Epoch 99/200: Train Loss: 0.2505, Train Acc: 91.24%, Test Loss: 0.2256, Test Acc: 92.43%
# Epoch 100/200: Train Loss: 0.2519, Train Acc: 91.18%, Test Loss: 0.2115, Test Acc: 93.11%
# Epoch 101/200: Train Loss: 0.2516, Train Acc: 91.22%, Test Loss: 0.2360, Test Acc: 92.37%
# Epoch 102/200: Train Loss: 0.2489, Train Acc: 91.25%, Test Loss: 0.2364, Test Acc: 92.13%
# Epoch 103/200: Train Loss: 0.2481, Train Acc: 91.40%, Test Loss: 0.2249, Test Acc: 92.82%
# Epoch 104/200: Train Loss: 0.2503, Train Acc: 91.34%, Test Loss: 0.2205, Test Acc: 92.96%
# Epoch 105/200: Train Loss: 0.2491, Train Acc: 91.34%, Test Loss: 0.2243, Test Acc: 92.97%
# Epoch 106/200: Train Loss: 0.2508, Train Acc: 91.22%, Test Loss: 0.2344, Test Acc: 92.26%
# Epoch 107/200: Train Loss: 0.2429, Train Acc: 91.53%, Test Loss: 0.2650, Test Acc: 91.42%
# Epoch 108/200: Train Loss: 0.2505, Train Acc: 91.34%, Test Loss: 0.2407, Test Acc: 92.36%
# Epoch 109/200: Train Loss: 0.2477, Train Acc: 91.36%, Test Loss: 0.2473, Test Acc: 92.09%
# Epoch 110/200: Train Loss: 0.2442, Train Acc: 91.67%, Test Loss: 0.2290, Test Acc: 92.90%
# Epoch 111/200: Train Loss: 0.2480, Train Acc: 91.31%, Test Loss: 0.2300, Test Acc: 92.72%
# Epoch 112/200: Train Loss: 0.2432, Train Acc: 91.59%, Test Loss: 0.2289, Test Acc: 92.92%
# Epoch 113/200: Train Loss: 0.2425, Train Acc: 91.62%, Test Loss: 0.2195, Test Acc: 92.65%
# Epoch 114/200: Train Loss: 0.2402, Train Acc: 91.66%, Test Loss: 0.2480, Test Acc: 92.40%
# Epoch 115/200: Train Loss: 0.2433, Train Acc: 91.61%, Test Loss: 0.2393, Test Acc: 92.57%
# Epoch 116/200: Train Loss: 0.2398, Train Acc: 91.79%, Test Loss: 0.2642, Test Acc: 91.64%
# Epoch 117/200: Train Loss: 0.2361, Train Acc: 91.75%, Test Loss: 0.2214, Test Acc: 92.99%
# Epoch 118/200: Train Loss: 0.2446, Train Acc: 91.38%, Test Loss: 0.2395, Test Acc: 92.27%
# Epoch 119/200: Train Loss: 0.2376, Train Acc: 91.83%, Test Loss: 0.2173, Test Acc: 93.20%
# Epoch 120/200: Train Loss: 0.2359, Train Acc: 91.76%, Test Loss: 0.2368, Test Acc: 92.56%
# Epoch 121/200: Train Loss: 0.1860, Train Acc: 93.63%, Test Loss: 0.1788, Test Acc: 94.18%
# New best model saved with accuracy: 94.18%
# Epoch 122/200: Train Loss: 0.1606, Train Acc: 94.47%, Test Loss: 0.1750, Test Acc: 94.23%
# New best model saved with accuracy: 94.23%
# Epoch 123/200: Train Loss: 0.1525, Train Acc: 94.89%, Test Loss: 0.1702, Test Acc: 94.51%
# New best model saved with accuracy: 94.51%
# Epoch 124/200: Train Loss: 0.1452, Train Acc: 95.01%, Test Loss: 0.1699, Test Acc: 94.46%
# Epoch 125/200: Train Loss: 0.1401, Train Acc: 95.22%, Test Loss: 0.1661, Test Acc: 94.70%
# New best model saved with accuracy: 94.70%
# Epoch 126/200: Train Loss: 0.1337, Train Acc: 95.50%, Test Loss: 0.1659, Test Acc: 94.39%
# Epoch 127/200: Train Loss: 0.1300, Train Acc: 95.63%, Test Loss: 0.1668, Test Acc: 94.47%
# Epoch 128/200: Train Loss: 0.1299, Train Acc: 95.61%, Test Loss: 0.1677, Test Acc: 94.51%
# Epoch 129/200: Train Loss: 0.1292, Train Acc: 95.69%, Test Loss: 0.1692, Test Acc: 94.44%
# Epoch 130/200: Train Loss: 0.1278, Train Acc: 95.68%, Test Loss: 0.1691, Test Acc: 94.63%
# Epoch 131/200: Train Loss: 0.1223, Train Acc: 95.85%, Test Loss: 0.1674, Test Acc: 94.76%
# New best model saved with accuracy: 94.76%
# Epoch 132/200: Train Loss: 0.1206, Train Acc: 95.94%, Test Loss: 0.1716, Test Acc: 94.56%
# Epoch 133/200: Train Loss: 0.1220, Train Acc: 95.83%, Test Loss: 0.1650, Test Acc: 94.88%
# New best model saved with accuracy: 94.88%
# Epoch 134/200: Train Loss: 0.1199, Train Acc: 95.98%, Test Loss: 0.1684, Test Acc: 94.73%
# Epoch 135/200: Train Loss: 0.1190, Train Acc: 96.01%, Test Loss: 0.1670, Test Acc: 94.64%
# Epoch 136/200: Train Loss: 0.1161, Train Acc: 95.97%, Test Loss: 0.1689, Test Acc: 94.86%
# Epoch 137/200: Train Loss: 0.1158, Train Acc: 96.05%, Test Loss: 0.1658, Test Acc: 94.75%
# Epoch 138/200: Train Loss: 0.1123, Train Acc: 96.19%, Test Loss: 0.1689, Test Acc: 94.72%
# Epoch 139/200: Train Loss: 0.1134, Train Acc: 96.09%, Test Loss: 0.1658, Test Acc: 94.85%
# Epoch 140/200: Train Loss: 0.1118, Train Acc: 96.33%, Test Loss: 0.1687, Test Acc: 94.85%
# Epoch 141/200: Train Loss: 0.1147, Train Acc: 96.09%, Test Loss: 0.1672, Test Acc: 94.77%
# Epoch 142/200: Train Loss: 0.1088, Train Acc: 96.35%, Test Loss: 0.1616, Test Acc: 94.98%
# New best model saved with accuracy: 94.98%
# Epoch 143/200: Train Loss: 0.1070, Train Acc: 96.49%, Test Loss: 0.1647, Test Acc: 95.10%
# New best model saved with accuracy: 95.10%
# Epoch 144/200: Train Loss: 0.1070, Train Acc: 96.37%, Test Loss: 0.1671, Test Acc: 94.79%
# Epoch 145/200: Train Loss: 0.1036, Train Acc: 96.46%, Test Loss: 0.1667, Test Acc: 94.90%
# Epoch 146/200: Train Loss: 0.1056, Train Acc: 96.46%, Test Loss: 0.1699, Test Acc: 94.85%
# Epoch 147/200: Train Loss: 0.1045, Train Acc: 96.46%, Test Loss: 0.1696, Test Acc: 94.98%
# Epoch 148/200: Train Loss: 0.1066, Train Acc: 96.29%, Test Loss: 0.1675, Test Acc: 94.90%
# Epoch 149/200: Train Loss: 0.1060, Train Acc: 96.41%, Test Loss: 0.1697, Test Acc: 94.80%
# Epoch 150/200: Train Loss: 0.1025, Train Acc: 96.60%, Test Loss: 0.1681, Test Acc: 95.01%
# Epoch 151/200: Train Loss: 0.1018, Train Acc: 96.55%, Test Loss: 0.1656, Test Acc: 95.02%
# Epoch 152/200: Train Loss: 0.1028, Train Acc: 96.44%, Test Loss: 0.1704, Test Acc: 94.93%
# Epoch 153/200: Train Loss: 0.0978, Train Acc: 96.66%, Test Loss: 0.1679, Test Acc: 94.91%
# Epoch 154/200: Train Loss: 0.0997, Train Acc: 96.65%, Test Loss: 0.1702, Test Acc: 94.88%
# Epoch 155/200: Train Loss: 0.0968, Train Acc: 96.71%, Test Loss: 0.1701, Test Acc: 95.03%
# Epoch 156/200: Train Loss: 0.0981, Train Acc: 96.76%, Test Loss: 0.1744, Test Acc: 94.71%
# Epoch 157/200: Train Loss: 0.1011, Train Acc: 96.64%, Test Loss: 0.1720, Test Acc: 94.92%
# Epoch 158/200: Train Loss: 0.0965, Train Acc: 96.76%, Test Loss: 0.1715, Test Acc: 94.68%
# Epoch 159/200: Train Loss: 0.0974, Train Acc: 96.65%, Test Loss: 0.1691, Test Acc: 94.96%
# Epoch 160/200: Train Loss: 0.0943, Train Acc: 96.79%, Test Loss: 0.1698, Test Acc: 95.06%
# Epoch 161/200: Train Loss: 0.0938, Train Acc: 96.88%, Test Loss: 0.1688, Test Acc: 95.03%
# Epoch 162/200: Train Loss: 0.0916, Train Acc: 96.90%, Test Loss: 0.1671, Test Acc: 95.03%
# Epoch 163/200: Train Loss: 0.0916, Train Acc: 96.86%, Test Loss: 0.1678, Test Acc: 95.06%
# Epoch 164/200: Train Loss: 0.0897, Train Acc: 97.04%, Test Loss: 0.1686, Test Acc: 95.00%
# Epoch 165/200: Train Loss: 0.0887, Train Acc: 97.00%, Test Loss: 0.1665, Test Acc: 95.04%
# Epoch 166/200: Train Loss: 0.0882, Train Acc: 97.04%, Test Loss: 0.1657, Test Acc: 95.12%
# New best model saved with accuracy: 95.12%
# Epoch 167/200: Train Loss: 0.0866, Train Acc: 97.15%, Test Loss: 0.1666, Test Acc: 95.07%
# Epoch 168/200: Train Loss: 0.0908, Train Acc: 97.02%, Test Loss: 0.1653, Test Acc: 95.09%
# Epoch 169/200: Train Loss: 0.0887, Train Acc: 96.91%, Test Loss: 0.1656, Test Acc: 95.06%
# Epoch 170/200: Train Loss: 0.0858, Train Acc: 97.14%, Test Loss: 0.1657, Test Acc: 94.97%
# Epoch 171/200: Train Loss: 0.0879, Train Acc: 96.99%, Test Loss: 0.1666, Test Acc: 95.03%
# Epoch 172/200: Train Loss: 0.0879, Train Acc: 97.07%, Test Loss: 0.1665, Test Acc: 95.14%
# New best model saved with accuracy: 95.14%
# Epoch 173/200: Train Loss: 0.0882, Train Acc: 97.06%, Test Loss: 0.1665, Test Acc: 95.06%
# Epoch 174/200: Train Loss: 0.0870, Train Acc: 97.01%, Test Loss: 0.1657, Test Acc: 95.08%
# Epoch 175/200: Train Loss: 0.0871, Train Acc: 96.95%, Test Loss: 0.1643, Test Acc: 95.13%
# Epoch 176/200: Train Loss: 0.0828, Train Acc: 97.22%, Test Loss: 0.1648, Test Acc: 95.21%
# New best model saved with accuracy: 95.21%
# Epoch 177/200: Train Loss: 0.0822, Train Acc: 97.33%, Test Loss: 0.1653, Test Acc: 95.24%
# New best model saved with accuracy: 95.24%
# Epoch 178/200: Train Loss: 0.0855, Train Acc: 97.05%, Test Loss: 0.1665, Test Acc: 95.06%
# Epoch 179/200: Train Loss: 0.0858, Train Acc: 97.13%, Test Loss: 0.1649, Test Acc: 95.16%
# Epoch 180/200: Train Loss: 0.0851, Train Acc: 97.13%, Test Loss: 0.1670, Test Acc: 95.02%
# Epoch 181/200: Train Loss: 0.0840, Train Acc: 97.23%, Test Loss: 0.1653, Test Acc: 95.20%
# Epoch 182/200: Train Loss: 0.0840, Train Acc: 97.21%, Test Loss: 0.1655, Test Acc: 95.15%
# Epoch 183/200: Train Loss: 0.0827, Train Acc: 97.24%, Test Loss: 0.1666, Test Acc: 95.05%
# Epoch 184/200: Train Loss: 0.0822, Train Acc: 97.26%, Test Loss: 0.1665, Test Acc: 95.13%
# Epoch 185/200: Train Loss: 0.0877, Train Acc: 97.04%, Test Loss: 0.1656, Test Acc: 95.09%
# Epoch 186/200: Train Loss: 0.0864, Train Acc: 97.05%, Test Loss: 0.1652, Test Acc: 95.22%
# Epoch 187/200: Train Loss: 0.0852, Train Acc: 97.18%, Test Loss: 0.1651, Test Acc: 95.10%
# Epoch 188/200: Train Loss: 0.0842, Train Acc: 97.27%, Test Loss: 0.1651, Test Acc: 95.07%
# Epoch 189/200: Train Loss: 0.0826, Train Acc: 97.21%, Test Loss: 0.1651, Test Acc: 95.16%
# Epoch 190/200: Train Loss: 0.0838, Train Acc: 97.17%, Test Loss: 0.1652, Test Acc: 95.16%
# Epoch 191/200: Train Loss: 0.0849, Train Acc: 97.10%, Test Loss: 0.1645, Test Acc: 95.20%
# Epoch 192/200: Train Loss: 0.0837, Train Acc: 97.26%, Test Loss: 0.1648, Test Acc: 95.09%
# Epoch 193/200: Train Loss: 0.0839, Train Acc: 97.17%, Test Loss: 0.1631, Test Acc: 95.18%
# Epoch 194/200: Train Loss: 0.0842, Train Acc: 97.16%, Test Loss: 0.1641, Test Acc: 95.21%
# Epoch 195/200: Train Loss: 0.0813, Train Acc: 97.28%, Test Loss: 0.1646, Test Acc: 95.17%
# Epoch 196/200: Train Loss: 0.0842, Train Acc: 97.21%, Test Loss: 0.1646, Test Acc: 95.12%
# Epoch 197/200: Train Loss: 0.0796, Train Acc: 97.33%, Test Loss: 0.1635, Test Acc: 95.21%
# Epoch 198/200: Train Loss: 0.0856, Train Acc: 97.12%, Test Loss: 0.1646, Test Acc: 95.07%
# Epoch 199/200: Train Loss: 0.0851, Train Acc: 97.13%, Test Loss: 0.1650, Test Acc: 95.05%
# Epoch 200/200: Train Loss: 0.0822, Train Acc: 97.28%, Test Loss: 0.1639, Test Acc: 95.07%
# Training completed! Best accuracy: 95.24%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA5.pth'):
        checkpoint = torch.load('model/best_modelA5.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 95%
# Accuracy of car   : 98%
# Accuracy of bird  : 94%
# Accuracy of cat   : 89%
# Accuracy of deer  : 96%
# Accuracy of dog   : 91%
# Accuracy of frog  : 98%
# Accuracy of horse : 97%
# Accuracy of ship  : 97%
# Accuracy of truck : 97%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.96      0.95      0.96      1000
#          car       0.98      0.98      0.98      1000
#         bird       0.94      0.94      0.94      1000
#          cat       0.89      0.89      0.89      1000
#         deer       0.94      0.96      0.95      1000
#          dog       0.92      0.91      0.91      1000
#         frog       0.97      0.98      0.97      1000
#        horse       0.98      0.97      0.98      1000
#         ship       0.98      0.97      0.97      1000
#        truck       0.97      0.97      0.97      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
