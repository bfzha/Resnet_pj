# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp2_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_model2.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.1106, Train Acc: 24.08%, Test Loss: 1.7053, Test Acc: 38.19%
# New best model saved with accuracy: 38.19%
# Epoch 2/200: Train Loss: 1.7466, Train Acc: 35.44%, Test Loss: 1.5610, Test Acc: 42.83%
# New best model saved with accuracy: 42.83%
# Epoch 3/200: Train Loss: 1.5857, Train Acc: 41.55%, Test Loss: 1.3877, Test Acc: 49.58%
# New best model saved with accuracy: 49.58%
# Epoch 4/200: Train Loss: 1.4369, Train Acc: 47.88%, Test Loss: 1.2036, Test Acc: 56.61%
# New best model saved with accuracy: 56.61%
# Epoch 5/200: Train Loss: 1.3146, Train Acc: 52.66%, Test Loss: 1.2348, Test Acc: 58.18%
# New best model saved with accuracy: 58.18%
# Epoch 6/200: Train Loss: 1.2078, Train Acc: 57.09%, Test Loss: 1.0664, Test Acc: 63.04%
# New best model saved with accuracy: 63.04%
# Epoch 7/200: Train Loss: 1.1095, Train Acc: 60.88%, Test Loss: 1.3292, Test Acc: 59.74%
# Epoch 8/200: Train Loss: 1.0144, Train Acc: 63.82%, Test Loss: 0.9266, Test Acc: 68.39%
# New best model saved with accuracy: 68.39%
# Epoch 9/200: Train Loss: 0.9516, Train Acc: 66.63%, Test Loss: 0.8594, Test Acc: 70.02%
# New best model saved with accuracy: 70.02%
# Epoch 10/200: Train Loss: 0.9058, Train Acc: 68.22%, Test Loss: 0.9903, Test Acc: 67.15%
# Epoch 11/200: Train Loss: 0.8766, Train Acc: 69.34%, Test Loss: 0.8417, Test Acc: 72.20%
# New best model saved with accuracy: 72.20%
# Epoch 12/200: Train Loss: 0.8456, Train Acc: 70.40%, Test Loss: 0.6390, Test Acc: 77.92%
# New best model saved with accuracy: 77.92%
# Epoch 13/200: Train Loss: 0.8199, Train Acc: 71.45%, Test Loss: 0.7080, Test Acc: 76.39%
# Epoch 14/200: Train Loss: 0.8029, Train Acc: 71.77%, Test Loss: 0.7817, Test Acc: 75.06%
# Epoch 15/200: Train Loss: 0.7851, Train Acc: 72.89%, Test Loss: 0.6617, Test Acc: 77.17%
# Epoch 16/200: Train Loss: 0.7723, Train Acc: 73.03%, Test Loss: 0.8288, Test Acc: 73.07%
# Epoch 17/200: Train Loss: 0.7551, Train Acc: 73.69%, Test Loss: 0.5891, Test Acc: 80.00%
# New best model saved with accuracy: 80.00%
# Epoch 18/200: Train Loss: 0.7444, Train Acc: 74.07%, Test Loss: 0.5263, Test Acc: 82.20%
# New best model saved with accuracy: 82.20%
# Epoch 19/200: Train Loss: 0.7288, Train Acc: 74.61%, Test Loss: 0.5884, Test Acc: 79.42%
# Epoch 20/200: Train Loss: 0.7224, Train Acc: 74.90%, Test Loss: 0.6208, Test Acc: 79.02%
# Epoch 21/200: Train Loss: 0.7144, Train Acc: 75.25%, Test Loss: 0.8956, Test Acc: 71.08%
# Epoch 22/200: Train Loss: 0.7092, Train Acc: 75.34%, Test Loss: 0.6780, Test Acc: 77.64%
# Epoch 23/200: Train Loss: 0.7062, Train Acc: 75.51%, Test Loss: 0.5727, Test Acc: 81.01%
# Epoch 24/200: Train Loss: 0.6978, Train Acc: 75.90%, Test Loss: 0.5726, Test Acc: 80.68%
# Epoch 25/200: Train Loss: 0.6892, Train Acc: 76.14%, Test Loss: 0.5937, Test Acc: 79.65%
# Epoch 26/200: Train Loss: 0.6798, Train Acc: 76.72%, Test Loss: 0.5662, Test Acc: 80.29%
# Epoch 27/200: Train Loss: 0.6835, Train Acc: 76.42%, Test Loss: 0.5151, Test Acc: 82.02%
# Epoch 28/200: Train Loss: 0.6722, Train Acc: 76.64%, Test Loss: 0.6939, Test Acc: 76.50%
# Epoch 29/200: Train Loss: 0.6679, Train Acc: 76.82%, Test Loss: 0.6979, Test Acc: 75.96%
# Epoch 30/200: Train Loss: 0.6640, Train Acc: 76.94%, Test Loss: 0.5299, Test Acc: 81.81%
# Epoch 31/200: Train Loss: 0.6542, Train Acc: 77.45%, Test Loss: 0.7709, Test Acc: 76.89%
# Epoch 32/200: Train Loss: 0.6464, Train Acc: 77.56%, Test Loss: 0.5805, Test Acc: 80.95%
# Epoch 33/200: Train Loss: 0.6555, Train Acc: 77.32%, Test Loss: 0.5571, Test Acc: 81.04%
# Epoch 34/200: Train Loss: 0.6402, Train Acc: 77.85%, Test Loss: 0.4990, Test Acc: 83.21%
# New best model saved with accuracy: 83.21%
# Epoch 35/200: Train Loss: 0.6441, Train Acc: 77.69%, Test Loss: 0.5480, Test Acc: 81.52%
# Epoch 36/200: Train Loss: 0.6410, Train Acc: 77.90%, Test Loss: 0.4773, Test Acc: 83.74%
# New best model saved with accuracy: 83.74%
# Epoch 37/200: Train Loss: 0.6390, Train Acc: 77.91%, Test Loss: 0.6151, Test Acc: 79.68%
# Epoch 38/200: Train Loss: 0.6419, Train Acc: 77.76%, Test Loss: 0.5938, Test Acc: 80.19%
# Epoch 39/200: Train Loss: 0.6324, Train Acc: 77.91%, Test Loss: 0.5716, Test Acc: 81.25%
# Epoch 40/200: Train Loss: 0.6300, Train Acc: 78.22%, Test Loss: 0.5729, Test Acc: 80.28%
# Epoch 41/200: Train Loss: 0.6252, Train Acc: 78.48%, Test Loss: 0.5319, Test Acc: 82.04%
# Epoch 42/200: Train Loss: 0.6182, Train Acc: 78.63%, Test Loss: 0.5553, Test Acc: 81.64%
# Epoch 43/200: Train Loss: 0.6205, Train Acc: 78.71%, Test Loss: 0.4720, Test Acc: 83.82%
# New best model saved with accuracy: 83.82%
# Epoch 44/200: Train Loss: 0.6227, Train Acc: 78.46%, Test Loss: 0.6504, Test Acc: 78.23%
# Epoch 45/200: Train Loss: 0.6206, Train Acc: 78.52%, Test Loss: 0.5709, Test Acc: 81.45%
# Epoch 46/200: Train Loss: 0.6137, Train Acc: 78.82%, Test Loss: 0.6270, Test Acc: 79.68%
# Epoch 47/200: Train Loss: 0.6094, Train Acc: 78.98%, Test Loss: 0.5413, Test Acc: 81.76%
# Epoch 48/200: Train Loss: 0.6044, Train Acc: 78.94%, Test Loss: 0.6418, Test Acc: 79.58%
# Epoch 49/200: Train Loss: 0.5988, Train Acc: 79.20%, Test Loss: 0.4645, Test Acc: 84.13%
# New best model saved with accuracy: 84.13%
# Epoch 50/200: Train Loss: 0.6049, Train Acc: 79.11%, Test Loss: 0.5197, Test Acc: 82.67%
# Epoch 51/200: Train Loss: 0.5983, Train Acc: 79.16%, Test Loss: 0.5438, Test Acc: 81.90%
# Epoch 52/200: Train Loss: 0.5992, Train Acc: 79.47%, Test Loss: 0.6377, Test Acc: 79.96%
# Epoch 53/200: Train Loss: 0.5896, Train Acc: 79.66%, Test Loss: 0.5234, Test Acc: 82.86%
# Epoch 54/200: Train Loss: 0.5932, Train Acc: 79.55%, Test Loss: 0.5712, Test Acc: 81.10%
# Epoch 55/200: Train Loss: 0.5856, Train Acc: 79.66%, Test Loss: 0.4885, Test Acc: 83.36%
# Epoch 56/200: Train Loss: 0.5876, Train Acc: 79.77%, Test Loss: 0.4484, Test Acc: 84.37%
# New best model saved with accuracy: 84.37%
# Epoch 57/200: Train Loss: 0.5922, Train Acc: 79.50%, Test Loss: 0.4980, Test Acc: 82.51%
# Epoch 58/200: Train Loss: 0.5763, Train Acc: 79.98%, Test Loss: 0.5125, Test Acc: 82.90%
# Epoch 59/200: Train Loss: 0.5721, Train Acc: 80.27%, Test Loss: 0.4663, Test Acc: 84.45%
# New best model saved with accuracy: 84.45%
# Epoch 60/200: Train Loss: 0.5773, Train Acc: 80.16%, Test Loss: 0.4999, Test Acc: 83.46%
# Epoch 61/200: Train Loss: 0.5676, Train Acc: 80.24%, Test Loss: 0.4935, Test Acc: 83.49%
# Epoch 62/200: Train Loss: 0.5718, Train Acc: 80.30%, Test Loss: 0.4998, Test Acc: 83.40%
# Epoch 63/200: Train Loss: 0.5647, Train Acc: 80.53%, Test Loss: 0.5382, Test Acc: 82.01%
# Epoch 64/200: Train Loss: 0.5665, Train Acc: 80.43%, Test Loss: 0.4316, Test Acc: 86.18%
# New best model saved with accuracy: 86.18%
# Epoch 65/200: Train Loss: 0.5638, Train Acc: 80.64%, Test Loss: 0.4319, Test Acc: 85.41%
# Epoch 66/200: Train Loss: 0.5568, Train Acc: 80.77%, Test Loss: 0.4045, Test Acc: 86.35%
# New best model saved with accuracy: 86.35%
# Epoch 67/200: Train Loss: 0.5589, Train Acc: 80.57%, Test Loss: 0.6486, Test Acc: 79.74%
# Epoch 68/200: Train Loss: 0.5614, Train Acc: 80.62%, Test Loss: 0.4889, Test Acc: 83.65%
# Epoch 69/200: Train Loss: 0.5522, Train Acc: 80.93%, Test Loss: 0.4359, Test Acc: 84.86%
# Epoch 70/200: Train Loss: 0.5527, Train Acc: 81.03%, Test Loss: 0.4259, Test Acc: 85.77%
# Epoch 71/200: Train Loss: 0.5514, Train Acc: 81.12%, Test Loss: 0.5405, Test Acc: 82.78%
# Epoch 72/200: Train Loss: 0.5433, Train Acc: 81.40%, Test Loss: 0.4870, Test Acc: 82.97%
# Epoch 73/200: Train Loss: 0.5428, Train Acc: 81.16%, Test Loss: 0.4504, Test Acc: 84.89%
# Epoch 74/200: Train Loss: 0.5447, Train Acc: 81.15%, Test Loss: 0.4185, Test Acc: 86.01%
# Epoch 75/200: Train Loss: 0.5361, Train Acc: 81.53%, Test Loss: 0.4327, Test Acc: 85.78%
# Epoch 76/200: Train Loss: 0.5355, Train Acc: 81.56%, Test Loss: 0.4383, Test Acc: 85.41%
# Epoch 77/200: Train Loss: 0.5373, Train Acc: 81.46%, Test Loss: 0.4769, Test Acc: 84.77%
# Epoch 78/200: Train Loss: 0.5319, Train Acc: 81.87%, Test Loss: 0.4783, Test Acc: 84.07%
# Epoch 79/200: Train Loss: 0.5266, Train Acc: 81.94%, Test Loss: 0.5196, Test Acc: 82.52%
# Epoch 80/200: Train Loss: 0.5246, Train Acc: 81.71%, Test Loss: 0.4391, Test Acc: 84.98%
# Epoch 81/200: Train Loss: 0.5206, Train Acc: 82.08%, Test Loss: 0.4593, Test Acc: 84.36%
# Epoch 82/200: Train Loss: 0.5186, Train Acc: 82.06%, Test Loss: 0.4331, Test Acc: 85.39%
# Epoch 83/200: Train Loss: 0.5152, Train Acc: 82.22%, Test Loss: 0.4191, Test Acc: 85.95%
# Epoch 84/200: Train Loss: 0.5061, Train Acc: 82.53%, Test Loss: 0.3678, Test Acc: 87.45%
# New best model saved with accuracy: 87.45%
# Epoch 85/200: Train Loss: 0.5103, Train Acc: 82.36%, Test Loss: 0.4248, Test Acc: 85.29%
# Epoch 86/200: Train Loss: 0.5070, Train Acc: 82.63%, Test Loss: 0.3500, Test Acc: 88.29%
# New best model saved with accuracy: 88.29%
# Epoch 87/200: Train Loss: 0.5022, Train Acc: 82.54%, Test Loss: 0.3957, Test Acc: 86.30%
# Epoch 88/200: Train Loss: 0.4969, Train Acc: 82.93%, Test Loss: 0.4086, Test Acc: 85.74%
# Epoch 89/200: Train Loss: 0.4919, Train Acc: 82.99%, Test Loss: 0.4222, Test Acc: 85.97%
# Epoch 90/200: Train Loss: 0.4921, Train Acc: 83.13%, Test Loss: 0.4228, Test Acc: 85.96%
# Epoch 91/200: Train Loss: 0.4985, Train Acc: 82.77%, Test Loss: 0.3820, Test Acc: 86.97%
# Epoch 92/200: Train Loss: 0.4818, Train Acc: 83.38%, Test Loss: 0.3873, Test Acc: 86.84%
# Epoch 93/200: Train Loss: 0.4868, Train Acc: 83.35%, Test Loss: 0.3998, Test Acc: 86.44%
# Epoch 94/200: Train Loss: 0.4861, Train Acc: 83.35%, Test Loss: 0.3772, Test Acc: 87.38%
# Epoch 95/200: Train Loss: 0.4837, Train Acc: 83.40%, Test Loss: 0.4105, Test Acc: 86.33%
# Epoch 96/200: Train Loss: 0.4693, Train Acc: 83.86%, Test Loss: 0.3250, Test Acc: 88.88%
# New best model saved with accuracy: 88.88%
# Epoch 97/200: Train Loss: 0.4746, Train Acc: 83.65%, Test Loss: 0.3876, Test Acc: 86.98%
# Epoch 98/200: Train Loss: 0.4735, Train Acc: 83.71%, Test Loss: 0.4255, Test Acc: 85.89%
# Epoch 99/200: Train Loss: 0.4587, Train Acc: 84.16%, Test Loss: 0.4065, Test Acc: 85.91%
# Epoch 100/200: Train Loss: 0.4652, Train Acc: 84.05%, Test Loss: 0.3516, Test Acc: 87.99%
# Epoch 101/200: Train Loss: 0.4631, Train Acc: 83.87%, Test Loss: 0.4288, Test Acc: 85.85%
# Epoch 102/200: Train Loss: 0.4565, Train Acc: 84.26%, Test Loss: 0.3470, Test Acc: 88.02%
# Epoch 103/200: Train Loss: 0.4547, Train Acc: 84.32%, Test Loss: 0.3466, Test Acc: 88.13%
# Epoch 104/200: Train Loss: 0.4530, Train Acc: 84.25%, Test Loss: 0.4064, Test Acc: 86.91%
# Epoch 105/200: Train Loss: 0.4479, Train Acc: 84.56%, Test Loss: 0.3103, Test Acc: 89.33%
# New best model saved with accuracy: 89.33%
# Epoch 106/200: Train Loss: 0.4370, Train Acc: 84.85%, Test Loss: 0.3381, Test Acc: 88.80%
# Epoch 107/200: Train Loss: 0.4369, Train Acc: 84.81%, Test Loss: 0.3817, Test Acc: 86.91%
# Epoch 108/200: Train Loss: 0.4399, Train Acc: 84.76%, Test Loss: 0.3740, Test Acc: 87.23%
# Epoch 109/200: Train Loss: 0.4337, Train Acc: 84.96%, Test Loss: 0.3513, Test Acc: 88.36%
# Epoch 110/200: Train Loss: 0.4306, Train Acc: 85.03%, Test Loss: 0.4607, Test Acc: 84.59%
# Epoch 111/200: Train Loss: 0.4239, Train Acc: 85.48%, Test Loss: 0.3243, Test Acc: 89.11%
# Epoch 112/200: Train Loss: 0.4180, Train Acc: 85.60%, Test Loss: 0.3212, Test Acc: 88.85%
# Epoch 113/200: Train Loss: 0.4242, Train Acc: 85.33%, Test Loss: 0.2829, Test Acc: 90.48%
# New best model saved with accuracy: 90.48%
# Epoch 114/200: Train Loss: 0.4082, Train Acc: 85.92%, Test Loss: 0.3334, Test Acc: 88.71%
# Epoch 115/200: Train Loss: 0.4151, Train Acc: 85.54%, Test Loss: 0.2971, Test Acc: 90.00%
# Epoch 116/200: Train Loss: 0.4036, Train Acc: 86.08%, Test Loss: 0.3341, Test Acc: 88.61%
# Epoch 117/200: Train Loss: 0.4012, Train Acc: 86.19%, Test Loss: 0.2948, Test Acc: 89.96%
# Epoch 118/200: Train Loss: 0.3968, Train Acc: 86.31%, Test Loss: 0.3933, Test Acc: 87.21%
# Epoch 119/200: Train Loss: 0.3996, Train Acc: 86.21%, Test Loss: 0.3105, Test Acc: 89.80%
# Epoch 120/200: Train Loss: 0.3983, Train Acc: 86.29%, Test Loss: 0.3071, Test Acc: 89.91%
# Epoch 121/200: Train Loss: 0.3850, Train Acc: 86.66%, Test Loss: 0.2792, Test Acc: 90.76%
# New best model saved with accuracy: 90.76%
# Epoch 122/200: Train Loss: 0.3845, Train Acc: 86.72%, Test Loss: 0.3378, Test Acc: 89.05%
# Epoch 123/200: Train Loss: 0.3840, Train Acc: 86.58%, Test Loss: 0.3301, Test Acc: 88.76%
# Epoch 124/200: Train Loss: 0.3774, Train Acc: 87.08%, Test Loss: 0.3326, Test Acc: 88.92%
# Epoch 125/200: Train Loss: 0.3684, Train Acc: 87.26%, Test Loss: 0.2745, Test Acc: 90.83%
# New best model saved with accuracy: 90.83%
# Epoch 126/200: Train Loss: 0.3640, Train Acc: 87.38%, Test Loss: 0.2531, Test Acc: 91.21%
# New best model saved with accuracy: 91.21%
# Epoch 127/200: Train Loss: 0.3606, Train Acc: 87.57%, Test Loss: 0.2806, Test Acc: 90.62%
# Epoch 128/200: Train Loss: 0.3562, Train Acc: 87.74%, Test Loss: 0.2811, Test Acc: 90.96%
# Epoch 129/200: Train Loss: 0.3548, Train Acc: 87.66%, Test Loss: 0.2691, Test Acc: 90.94%
# Epoch 130/200: Train Loss: 0.3523, Train Acc: 87.63%, Test Loss: 0.2506, Test Acc: 91.50%
# New best model saved with accuracy: 91.50%
# Epoch 131/200: Train Loss: 0.3491, Train Acc: 87.73%, Test Loss: 0.2856, Test Acc: 90.36%
# Epoch 132/200: Train Loss: 0.3382, Train Acc: 88.40%, Test Loss: 0.2978, Test Acc: 90.12%
# Epoch 133/200: Train Loss: 0.3363, Train Acc: 88.34%, Test Loss: 0.2738, Test Acc: 90.62%
# Epoch 134/200: Train Loss: 0.3340, Train Acc: 88.32%, Test Loss: 0.2580, Test Acc: 91.26%
# Epoch 135/200: Train Loss: 0.3315, Train Acc: 88.62%, Test Loss: 0.3116, Test Acc: 89.72%
# Epoch 136/200: Train Loss: 0.3299, Train Acc: 88.53%, Test Loss: 0.3216, Test Acc: 89.40%
# Epoch 137/200: Train Loss: 0.3167, Train Acc: 89.09%, Test Loss: 0.2465, Test Acc: 91.50%
# Epoch 138/200: Train Loss: 0.3170, Train Acc: 89.07%, Test Loss: 0.2627, Test Acc: 91.40%
# Epoch 139/200: Train Loss: 0.3077, Train Acc: 89.37%, Test Loss: 0.2516, Test Acc: 91.86%
# New best model saved with accuracy: 91.86%
# Epoch 140/200: Train Loss: 0.3012, Train Acc: 89.69%, Test Loss: 0.2528, Test Acc: 91.99%
# New best model saved with accuracy: 91.99%
# Epoch 141/200: Train Loss: 0.3031, Train Acc: 89.50%, Test Loss: 0.2486, Test Acc: 91.63%
# Epoch 142/200: Train Loss: 0.3017, Train Acc: 89.62%, Test Loss: 0.2327, Test Acc: 92.22%
# New best model saved with accuracy: 92.22%
# Epoch 143/200: Train Loss: 0.2899, Train Acc: 89.85%, Test Loss: 0.2989, Test Acc: 90.42%
# Epoch 144/200: Train Loss: 0.2837, Train Acc: 90.15%, Test Loss: 0.2481, Test Acc: 91.98%
# Epoch 145/200: Train Loss: 0.2811, Train Acc: 90.35%, Test Loss: 0.2280, Test Acc: 92.60%
# New best model saved with accuracy: 92.60%
# Epoch 146/200: Train Loss: 0.2725, Train Acc: 90.54%, Test Loss: 0.2737, Test Acc: 91.23%
# Epoch 147/200: Train Loss: 0.2728, Train Acc: 90.54%, Test Loss: 0.2084, Test Acc: 93.17%
# New best model saved with accuracy: 93.17%
# Epoch 148/200: Train Loss: 0.2660, Train Acc: 90.71%, Test Loss: 0.2172, Test Acc: 92.82%
# Epoch 149/200: Train Loss: 0.2648, Train Acc: 90.78%, Test Loss: 0.2406, Test Acc: 91.88%
# Epoch 150/200: Train Loss: 0.2580, Train Acc: 91.08%, Test Loss: 0.2158, Test Acc: 93.07%
# Epoch 151/200: Train Loss: 0.2588, Train Acc: 91.04%, Test Loss: 0.2147, Test Acc: 92.84%
# Epoch 152/200: Train Loss: 0.2475, Train Acc: 91.50%, Test Loss: 0.2323, Test Acc: 92.53%
# Epoch 153/200: Train Loss: 0.2414, Train Acc: 91.53%, Test Loss: 0.2400, Test Acc: 92.33%
# Epoch 154/200: Train Loss: 0.2363, Train Acc: 91.77%, Test Loss: 0.2214, Test Acc: 92.97%
# Epoch 155/200: Train Loss: 0.2312, Train Acc: 91.95%, Test Loss: 0.2005, Test Acc: 93.65%
# New best model saved with accuracy: 93.65%
# Epoch 156/200: Train Loss: 0.2261, Train Acc: 92.18%, Test Loss: 0.2187, Test Acc: 92.87%
# Epoch 157/200: Train Loss: 0.2220, Train Acc: 92.21%, Test Loss: 0.2217, Test Acc: 93.03%
# Epoch 158/200: Train Loss: 0.2124, Train Acc: 92.62%, Test Loss: 0.1943, Test Acc: 93.65%
# Epoch 159/200: Train Loss: 0.2077, Train Acc: 92.77%, Test Loss: 0.1886, Test Acc: 94.08%
# New best model saved with accuracy: 94.08%
# Epoch 160/200: Train Loss: 0.2073, Train Acc: 92.92%, Test Loss: 0.1866, Test Acc: 94.01%
# Epoch 161/200: Train Loss: 0.2015, Train Acc: 93.13%, Test Loss: 0.1878, Test Acc: 94.15%
# New best model saved with accuracy: 94.15%
# Epoch 162/200: Train Loss: 0.1945, Train Acc: 93.19%, Test Loss: 0.1897, Test Acc: 94.01%
# Epoch 163/200: Train Loss: 0.1895, Train Acc: 93.48%, Test Loss: 0.1725, Test Acc: 94.48%
# New best model saved with accuracy: 94.48%
# Epoch 164/200: Train Loss: 0.1855, Train Acc: 93.50%, Test Loss: 0.1958, Test Acc: 93.78%
# Epoch 165/200: Train Loss: 0.1787, Train Acc: 93.80%, Test Loss: 0.1877, Test Acc: 94.39%
# Epoch 166/200: Train Loss: 0.1668, Train Acc: 94.14%, Test Loss: 0.1888, Test Acc: 93.95%
# Epoch 167/200: Train Loss: 0.1714, Train Acc: 94.11%, Test Loss: 0.1911, Test Acc: 93.77%
# Epoch 168/200: Train Loss: 0.1634, Train Acc: 94.34%, Test Loss: 0.1748, Test Acc: 94.48%
# Epoch 169/200: Train Loss: 0.1542, Train Acc: 94.72%, Test Loss: 0.1639, Test Acc: 94.89%
# New best model saved with accuracy: 94.89%
# Epoch 170/200: Train Loss: 0.1512, Train Acc: 94.89%, Test Loss: 0.1715, Test Acc: 94.70%
# Epoch 171/200: Train Loss: 0.1488, Train Acc: 94.83%, Test Loss: 0.1672, Test Acc: 94.87%
# Epoch 172/200: Train Loss: 0.1381, Train Acc: 95.21%, Test Loss: 0.1722, Test Acc: 94.89%
# Epoch 173/200: Train Loss: 0.1398, Train Acc: 95.20%, Test Loss: 0.1697, Test Acc: 94.78%
# Epoch 174/200: Train Loss: 0.1339, Train Acc: 95.34%, Test Loss: 0.1759, Test Acc: 94.84%
# Epoch 175/200: Train Loss: 0.1342, Train Acc: 95.44%, Test Loss: 0.1751, Test Acc: 94.79%
# Epoch 176/200: Train Loss: 0.1265, Train Acc: 95.73%, Test Loss: 0.1716, Test Acc: 95.08%
# New best model saved with accuracy: 95.08%
# Epoch 177/200: Train Loss: 0.1197, Train Acc: 95.94%, Test Loss: 0.1741, Test Acc: 95.00%
# Epoch 178/200: Train Loss: 0.1152, Train Acc: 96.08%, Test Loss: 0.1640, Test Acc: 95.07%
# Epoch 179/200: Train Loss: 0.1077, Train Acc: 96.33%, Test Loss: 0.1617, Test Acc: 95.10%
# New best model saved with accuracy: 95.10%
# Epoch 180/200: Train Loss: 0.1074, Train Acc: 96.35%, Test Loss: 0.1639, Test Acc: 95.10%
# Epoch 181/200: Train Loss: 0.1055, Train Acc: 96.42%, Test Loss: 0.1554, Test Acc: 95.17%
# New best model saved with accuracy: 95.17%
# Epoch 182/200: Train Loss: 0.1016, Train Acc: 96.64%, Test Loss: 0.1575, Test Acc: 95.36%
# New best model saved with accuracy: 95.36%
# Epoch 183/200: Train Loss: 0.0970, Train Acc: 96.79%, Test Loss: 0.1542, Test Acc: 95.55%
# New best model saved with accuracy: 95.55%
# Epoch 184/200: Train Loss: 0.0935, Train Acc: 96.79%, Test Loss: 0.1496, Test Acc: 95.35%
# Epoch 185/200: Train Loss: 0.0872, Train Acc: 97.18%, Test Loss: 0.1528, Test Acc: 95.49%
# Epoch 186/200: Train Loss: 0.0913, Train Acc: 96.97%, Test Loss: 0.1522, Test Acc: 95.51%
# Epoch 187/200: Train Loss: 0.0878, Train Acc: 97.00%, Test Loss: 0.1562, Test Acc: 95.45%
# Epoch 188/200: Train Loss: 0.0841, Train Acc: 97.14%, Test Loss: 0.1513, Test Acc: 95.49%
# Epoch 189/200: Train Loss: 0.0812, Train Acc: 97.27%, Test Loss: 0.1525, Test Acc: 95.55%
# Epoch 190/200: Train Loss: 0.0812, Train Acc: 97.27%, Test Loss: 0.1496, Test Acc: 95.52%
# Epoch 191/200: Train Loss: 0.0777, Train Acc: 97.34%, Test Loss: 0.1507, Test Acc: 95.68%
# New best model saved with accuracy: 95.68%
# Epoch 192/200: Train Loss: 0.0773, Train Acc: 97.43%, Test Loss: 0.1451, Test Acc: 95.72%
# New best model saved with accuracy: 95.72%
# Epoch 193/200: Train Loss: 0.0757, Train Acc: 97.40%, Test Loss: 0.1476, Test Acc: 95.65%
# Epoch 194/200: Train Loss: 0.0728, Train Acc: 97.57%, Test Loss: 0.1463, Test Acc: 95.67%
# Epoch 195/200: Train Loss: 0.0764, Train Acc: 97.48%, Test Loss: 0.1478, Test Acc: 95.69%
# Epoch 196/200: Train Loss: 0.0718, Train Acc: 97.55%, Test Loss: 0.1467, Test Acc: 95.77%
# New best model saved with accuracy: 95.77%
# Epoch 197/200: Train Loss: 0.0725, Train Acc: 97.55%, Test Loss: 0.1460, Test Acc: 95.76%
# Epoch 198/200: Train Loss: 0.0717, Train Acc: 97.59%, Test Loss: 0.1473, Test Acc: 95.67%
# Epoch 199/200: Train Loss: 0.0744, Train Acc: 97.51%, Test Loss: 0.1466, Test Acc: 95.71%
# Epoch 200/200: Train Loss: 0.0721, Train Acc: 97.62%, Test Loss: 0.1469, Test Acc: 95.71%
# Training completed! Best accuracy: 95.77%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_model2.pth'):
        checkpoint = torch.load('model/best_model2.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 98%
# Accuracy of bird  : 94%
# Accuracy of cat   : 91%
# Accuracy of deer  : 97%
# Accuracy of dog   : 91%
# Accuracy of frog  : 98%
# Accuracy of horse : 98%
# Accuracy of ship  : 97%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.96      0.96      0.96      1000
#          car       0.97      0.98      0.98      1000
#         bird       0.95      0.94      0.94      1000
#          cat       0.90      0.91      0.90      1000
#         deer       0.95      0.97      0.96      1000
#          dog       0.92      0.91      0.92      1000
#         frog       0.98      0.98      0.98      1000
#        horse       0.99      0.98      0.98      1000
#         ship       0.97      0.97      0.97      1000
#        truck       0.97      0.96      0.97      1000
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
# === ROC曲线 ===
