# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA4.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.0209, Train Acc: 27.10%, Test Loss: 1.6529, Test Acc: 39.26%
# New best model saved with accuracy: 39.26%
# Epoch 2/200: Train Loss: 1.6014, Train Acc: 40.80%, Test Loss: 1.5396, Test Acc: 44.54%
# New best model saved with accuracy: 44.54%
# Epoch 3/200: Train Loss: 1.3878, Train Acc: 49.72%, Test Loss: 1.2256, Test Acc: 56.04%
# New best model saved with accuracy: 56.04%
# Epoch 4/200: Train Loss: 1.2147, Train Acc: 56.66%, Test Loss: 1.2107, Test Acc: 57.77%
# New best model saved with accuracy: 57.77%
# Epoch 5/200: Train Loss: 1.0818, Train Acc: 61.79%, Test Loss: 1.0138, Test Acc: 63.97%
# New best model saved with accuracy: 63.97%
# Epoch 6/200: Train Loss: 0.9741, Train Acc: 65.78%, Test Loss: 0.8981, Test Acc: 68.53%
# New best model saved with accuracy: 68.53%
# Epoch 7/200: Train Loss: 0.8662, Train Acc: 69.68%, Test Loss: 0.7559, Test Acc: 74.00%
# New best model saved with accuracy: 74.00%
# Epoch 8/200: Train Loss: 0.8009, Train Acc: 72.27%, Test Loss: 0.9783, Test Acc: 68.00%
# Epoch 9/200: Train Loss: 0.7587, Train Acc: 73.78%, Test Loss: 0.7478, Test Acc: 74.64%
# New best model saved with accuracy: 74.64%
# Epoch 10/200: Train Loss: 0.7280, Train Acc: 74.87%, Test Loss: 0.7407, Test Acc: 74.92%
# New best model saved with accuracy: 74.92%
# Epoch 11/200: Train Loss: 0.6945, Train Acc: 75.90%, Test Loss: 0.6777, Test Acc: 77.61%
# New best model saved with accuracy: 77.61%
# Epoch 12/200: Train Loss: 0.6815, Train Acc: 76.40%, Test Loss: 0.7390, Test Acc: 75.08%
# Epoch 13/200: Train Loss: 0.6611, Train Acc: 77.15%, Test Loss: 0.6655, Test Acc: 77.42%
# Epoch 14/200: Train Loss: 0.6436, Train Acc: 77.83%, Test Loss: 0.6737, Test Acc: 76.83%
# Epoch 15/200: Train Loss: 0.6345, Train Acc: 77.95%, Test Loss: 0.6823, Test Acc: 77.90%
# New best model saved with accuracy: 77.90%
# Epoch 16/200: Train Loss: 0.6225, Train Acc: 78.55%, Test Loss: 0.6253, Test Acc: 78.63%
# New best model saved with accuracy: 78.63%
# Epoch 17/200: Train Loss: 0.6148, Train Acc: 78.80%, Test Loss: 0.6338, Test Acc: 78.52%
# Epoch 18/200: Train Loss: 0.5994, Train Acc: 79.24%, Test Loss: 0.5551, Test Acc: 81.19%
# New best model saved with accuracy: 81.19%
# Epoch 19/200: Train Loss: 0.5981, Train Acc: 79.21%, Test Loss: 0.6981, Test Acc: 77.33%
# Epoch 20/200: Train Loss: 0.5803, Train Acc: 80.16%, Test Loss: 0.6289, Test Acc: 79.06%
# Epoch 21/200: Train Loss: 0.5764, Train Acc: 80.28%, Test Loss: 0.5224, Test Acc: 82.26%
# New best model saved with accuracy: 82.26%
# Epoch 22/200: Train Loss: 0.5728, Train Acc: 80.17%, Test Loss: 0.5190, Test Acc: 82.93%
# New best model saved with accuracy: 82.93%
# Epoch 23/200: Train Loss: 0.5725, Train Acc: 80.37%, Test Loss: 0.5451, Test Acc: 82.18%
# Epoch 24/200: Train Loss: 0.5603, Train Acc: 80.74%, Test Loss: 0.7258, Test Acc: 76.72%
# Epoch 25/200: Train Loss: 0.5542, Train Acc: 80.96%, Test Loss: 0.5486, Test Acc: 80.69%
# Epoch 26/200: Train Loss: 0.5488, Train Acc: 81.20%, Test Loss: 0.5920, Test Acc: 80.07%
# Epoch 27/200: Train Loss: 0.5525, Train Acc: 81.14%, Test Loss: 0.6134, Test Acc: 80.43%
# Epoch 28/200: Train Loss: 0.5429, Train Acc: 81.46%, Test Loss: 0.6446, Test Acc: 78.18%
# Epoch 29/200: Train Loss: 0.5477, Train Acc: 81.29%, Test Loss: 0.6544, Test Acc: 78.59%
# Epoch 30/200: Train Loss: 0.5424, Train Acc: 81.34%, Test Loss: 0.6128, Test Acc: 79.64%
# Epoch 31/200: Train Loss: 0.5341, Train Acc: 81.64%, Test Loss: 0.6064, Test Acc: 79.02%
# Epoch 32/200: Train Loss: 0.5284, Train Acc: 81.93%, Test Loss: 0.7004, Test Acc: 78.16%
# Epoch 33/200: Train Loss: 0.5291, Train Acc: 81.88%, Test Loss: 0.8650, Test Acc: 74.57%
# Epoch 34/200: Train Loss: 0.5288, Train Acc: 81.78%, Test Loss: 0.5069, Test Acc: 82.62%
# Epoch 35/200: Train Loss: 0.5211, Train Acc: 82.02%, Test Loss: 0.6703, Test Acc: 78.47%
# Epoch 36/200: Train Loss: 0.5254, Train Acc: 81.99%, Test Loss: 0.4953, Test Acc: 83.14%
# New best model saved with accuracy: 83.14%
# Epoch 37/200: Train Loss: 0.5196, Train Acc: 82.10%, Test Loss: 0.6502, Test Acc: 79.36%
# Epoch 38/200: Train Loss: 0.5259, Train Acc: 82.03%, Test Loss: 0.5663, Test Acc: 81.70%
# Epoch 39/200: Train Loss: 0.5222, Train Acc: 82.09%, Test Loss: 0.6541, Test Acc: 78.29%
# Epoch 40/200: Train Loss: 0.5172, Train Acc: 82.22%, Test Loss: 0.5455, Test Acc: 81.29%
# Epoch 41/200: Train Loss: 0.5132, Train Acc: 82.35%, Test Loss: 0.5280, Test Acc: 82.36%
# Epoch 42/200: Train Loss: 0.5079, Train Acc: 82.67%, Test Loss: 0.5437, Test Acc: 81.70%
# Epoch 43/200: Train Loss: 0.5101, Train Acc: 82.54%, Test Loss: 0.5947, Test Acc: 80.64%
# Epoch 44/200: Train Loss: 0.5043, Train Acc: 82.87%, Test Loss: 0.5278, Test Acc: 82.23%
# Epoch 45/200: Train Loss: 0.5073, Train Acc: 82.53%, Test Loss: 0.5584, Test Acc: 81.42%
# Epoch 46/200: Train Loss: 0.5051, Train Acc: 82.67%, Test Loss: 0.4801, Test Acc: 83.70%
# New best model saved with accuracy: 83.70%
# Epoch 47/200: Train Loss: 0.5097, Train Acc: 82.62%, Test Loss: 0.4800, Test Acc: 83.68%
# Epoch 48/200: Train Loss: 0.5001, Train Acc: 83.02%, Test Loss: 0.5575, Test Acc: 81.54%
# Epoch 49/200: Train Loss: 0.5065, Train Acc: 82.67%, Test Loss: 0.9026, Test Acc: 72.70%
# Epoch 50/200: Train Loss: 0.4983, Train Acc: 82.89%, Test Loss: 0.5008, Test Acc: 83.41%
# Epoch 51/200: Train Loss: 0.5073, Train Acc: 82.46%, Test Loss: 0.5313, Test Acc: 82.10%
# Epoch 52/200: Train Loss: 0.4994, Train Acc: 82.98%, Test Loss: 0.6212, Test Acc: 80.34%
# Epoch 53/200: Train Loss: 0.5013, Train Acc: 82.91%, Test Loss: 0.4696, Test Acc: 84.14%
# New best model saved with accuracy: 84.14%
# Epoch 54/200: Train Loss: 0.4955, Train Acc: 83.13%, Test Loss: 0.4982, Test Acc: 83.58%
# Epoch 55/200: Train Loss: 0.4997, Train Acc: 82.89%, Test Loss: 0.4758, Test Acc: 83.72%
# Epoch 56/200: Train Loss: 0.4916, Train Acc: 83.26%, Test Loss: 1.0468, Test Acc: 71.59%
# Epoch 57/200: Train Loss: 0.5002, Train Acc: 82.75%, Test Loss: 0.4406, Test Acc: 84.95%
# New best model saved with accuracy: 84.95%
# Epoch 58/200: Train Loss: 0.4936, Train Acc: 83.23%, Test Loss: 0.4971, Test Acc: 83.13%
# Epoch 59/200: Train Loss: 0.4930, Train Acc: 83.14%, Test Loss: 0.4804, Test Acc: 83.91%
# Epoch 60/200: Train Loss: 0.4950, Train Acc: 82.99%, Test Loss: 0.6277, Test Acc: 79.85%
# Epoch 61/200: Train Loss: 0.4954, Train Acc: 83.08%, Test Loss: 0.5056, Test Acc: 83.22%
# Epoch 62/200: Train Loss: 0.4923, Train Acc: 83.12%, Test Loss: 0.4660, Test Acc: 84.22%
# Epoch 63/200: Train Loss: 0.4940, Train Acc: 83.15%, Test Loss: 0.5315, Test Acc: 82.39%
# Epoch 64/200: Train Loss: 0.4895, Train Acc: 83.26%, Test Loss: 0.5651, Test Acc: 81.10%
# Epoch 65/200: Train Loss: 0.4915, Train Acc: 83.18%, Test Loss: 0.4064, Test Acc: 86.12%
# New best model saved with accuracy: 86.12%
# Epoch 66/200: Train Loss: 0.4946, Train Acc: 83.05%, Test Loss: 0.5376, Test Acc: 82.99%
# Epoch 67/200: Train Loss: 0.4903, Train Acc: 83.27%, Test Loss: 0.5223, Test Acc: 81.99%
# Epoch 68/200: Train Loss: 0.4914, Train Acc: 83.10%, Test Loss: 0.5371, Test Acc: 82.26%
# Epoch 69/200: Train Loss: 0.4972, Train Acc: 82.96%, Test Loss: 0.4974, Test Acc: 82.80%
# Epoch 70/200: Train Loss: 0.4894, Train Acc: 83.34%, Test Loss: 0.4893, Test Acc: 83.60%
# Epoch 71/200: Train Loss: 0.3193, Train Acc: 89.19%, Test Loss: 0.2412, Test Acc: 91.67%
# New best model saved with accuracy: 91.67%
# Epoch 72/200: Train Loss: 0.2578, Train Acc: 91.18%, Test Loss: 0.2200, Test Acc: 92.40%
# New best model saved with accuracy: 92.40%
# Epoch 73/200: Train Loss: 0.2350, Train Acc: 92.02%, Test Loss: 0.2181, Test Acc: 92.61%
# New best model saved with accuracy: 92.61%
# Epoch 74/200: Train Loss: 0.2182, Train Acc: 92.42%, Test Loss: 0.2226, Test Acc: 92.53%
# Epoch 75/200: Train Loss: 0.2096, Train Acc: 92.85%, Test Loss: 0.2162, Test Acc: 92.58%
# Epoch 76/200: Train Loss: 0.1999, Train Acc: 93.17%, Test Loss: 0.2121, Test Acc: 93.27%
# New best model saved with accuracy: 93.27%
# Epoch 77/200: Train Loss: 0.1929, Train Acc: 93.36%, Test Loss: 0.2114, Test Acc: 92.89%
# Epoch 78/200: Train Loss: 0.1867, Train Acc: 93.57%, Test Loss: 0.2078, Test Acc: 93.16%
# Epoch 79/200: Train Loss: 0.1787, Train Acc: 93.86%, Test Loss: 0.2032, Test Acc: 93.26%
# Epoch 80/200: Train Loss: 0.1736, Train Acc: 93.94%, Test Loss: 0.2026, Test Acc: 93.08%
# Epoch 81/200: Train Loss: 0.1707, Train Acc: 94.05%, Test Loss: 0.2126, Test Acc: 93.06%
# Epoch 82/200: Train Loss: 0.1664, Train Acc: 94.24%, Test Loss: 0.2135, Test Acc: 93.15%
# Epoch 83/200: Train Loss: 0.1601, Train Acc: 94.37%, Test Loss: 0.2082, Test Acc: 93.37%
# New best model saved with accuracy: 93.37%
# Epoch 84/200: Train Loss: 0.1566, Train Acc: 94.66%, Test Loss: 0.2037, Test Acc: 93.24%
# Epoch 85/200: Train Loss: 0.1513, Train Acc: 94.74%, Test Loss: 0.2092, Test Acc: 93.21%
# Epoch 86/200: Train Loss: 0.1529, Train Acc: 94.59%, Test Loss: 0.2050, Test Acc: 93.26%
# Epoch 87/200: Train Loss: 0.1511, Train Acc: 94.65%, Test Loss: 0.2090, Test Acc: 93.52%
# New best model saved with accuracy: 93.52%
# Epoch 88/200: Train Loss: 0.1537, Train Acc: 94.69%, Test Loss: 0.2142, Test Acc: 93.39%
# Epoch 89/200: Train Loss: 0.1423, Train Acc: 95.06%, Test Loss: 0.2088, Test Acc: 93.61%
# New best model saved with accuracy: 93.61%
# Epoch 90/200: Train Loss: 0.1467, Train Acc: 94.89%, Test Loss: 0.2179, Test Acc: 93.06%
# Epoch 91/200: Train Loss: 0.1401, Train Acc: 95.17%, Test Loss: 0.2011, Test Acc: 93.87%
# New best model saved with accuracy: 93.87%
# Epoch 92/200: Train Loss: 0.1435, Train Acc: 94.97%, Test Loss: 0.2164, Test Acc: 93.23%
# Epoch 93/200: Train Loss: 0.1433, Train Acc: 94.94%, Test Loss: 0.2328, Test Acc: 92.56%
# Epoch 94/200: Train Loss: 0.1417, Train Acc: 95.18%, Test Loss: 0.2201, Test Acc: 93.29%
# Epoch 95/200: Train Loss: 0.1394, Train Acc: 95.21%, Test Loss: 0.2175, Test Acc: 93.29%
# Epoch 96/200: Train Loss: 0.1390, Train Acc: 95.18%, Test Loss: 0.2344, Test Acc: 92.86%
# Epoch 97/200: Train Loss: 0.1392, Train Acc: 95.07%, Test Loss: 0.2238, Test Acc: 93.17%
# Epoch 98/200: Train Loss: 0.1351, Train Acc: 95.34%, Test Loss: 0.2348, Test Acc: 92.83%
# Epoch 99/200: Train Loss: 0.1385, Train Acc: 95.28%, Test Loss: 0.2505, Test Acc: 92.52%
# Epoch 100/200: Train Loss: 0.1405, Train Acc: 95.07%, Test Loss: 0.2329, Test Acc: 92.82%
# Epoch 101/200: Train Loss: 0.1378, Train Acc: 95.27%, Test Loss: 0.2368, Test Acc: 92.51%
# Epoch 102/200: Train Loss: 0.1437, Train Acc: 95.06%, Test Loss: 0.2458, Test Acc: 92.67%
# Epoch 103/200: Train Loss: 0.1346, Train Acc: 95.39%, Test Loss: 0.2419, Test Acc: 92.28%
# Epoch 104/200: Train Loss: 0.1396, Train Acc: 95.14%, Test Loss: 0.2459, Test Acc: 92.36%
# Epoch 105/200: Train Loss: 0.1411, Train Acc: 95.08%, Test Loss: 0.2556, Test Acc: 92.11%
# Epoch 106/200: Train Loss: 0.1397, Train Acc: 95.17%, Test Loss: 0.2307, Test Acc: 92.84%
# Epoch 107/200: Train Loss: 0.1350, Train Acc: 95.38%, Test Loss: 0.2401, Test Acc: 92.65%
# Epoch 108/200: Train Loss: 0.1377, Train Acc: 95.17%, Test Loss: 0.2189, Test Acc: 93.11%
# Epoch 109/200: Train Loss: 0.1335, Train Acc: 95.36%, Test Loss: 0.2312, Test Acc: 93.10%
# Epoch 110/200: Train Loss: 0.1359, Train Acc: 95.31%, Test Loss: 0.2591, Test Acc: 92.07%
# Epoch 111/200: Train Loss: 0.1318, Train Acc: 95.42%, Test Loss: 0.2520, Test Acc: 92.21%
# Epoch 112/200: Train Loss: 0.1395, Train Acc: 95.21%, Test Loss: 0.2640, Test Acc: 92.21%
# Epoch 113/200: Train Loss: 0.1334, Train Acc: 95.35%, Test Loss: 0.2546, Test Acc: 92.07%
# Epoch 114/200: Train Loss: 0.1356, Train Acc: 95.32%, Test Loss: 0.2472, Test Acc: 92.61%
# Epoch 115/200: Train Loss: 0.1386, Train Acc: 95.33%, Test Loss: 0.2475, Test Acc: 92.10%
# Epoch 116/200: Train Loss: 0.1329, Train Acc: 95.43%, Test Loss: 0.2342, Test Acc: 93.17%
# Epoch 117/200: Train Loss: 0.1348, Train Acc: 95.37%, Test Loss: 0.2554, Test Acc: 92.04%
# Epoch 118/200: Train Loss: 0.1336, Train Acc: 95.36%, Test Loss: 0.2561, Test Acc: 92.21%
# Epoch 119/200: Train Loss: 0.1363, Train Acc: 95.39%, Test Loss: 0.2474, Test Acc: 92.60%
# Epoch 120/200: Train Loss: 0.1314, Train Acc: 95.56%, Test Loss: 0.2335, Test Acc: 92.76%
# Epoch 121/200: Train Loss: 0.0855, Train Acc: 97.15%, Test Loss: 0.1862, Test Acc: 94.10%
# New best model saved with accuracy: 94.10%
# Epoch 122/200: Train Loss: 0.0683, Train Acc: 97.77%, Test Loss: 0.1865, Test Acc: 94.43%
# New best model saved with accuracy: 94.43%
# Epoch 123/200: Train Loss: 0.0597, Train Acc: 98.08%, Test Loss: 0.1821, Test Acc: 94.63%
# New best model saved with accuracy: 94.63%
# Epoch 124/200: Train Loss: 0.0532, Train Acc: 98.35%, Test Loss: 0.1805, Test Acc: 94.55%
# Epoch 125/200: Train Loss: 0.0512, Train Acc: 98.38%, Test Loss: 0.1817, Test Acc: 94.66%
# New best model saved with accuracy: 94.66%
# Epoch 126/200: Train Loss: 0.0486, Train Acc: 98.47%, Test Loss: 0.1797, Test Acc: 94.71%
# New best model saved with accuracy: 94.71%
# Epoch 127/200: Train Loss: 0.0448, Train Acc: 98.55%, Test Loss: 0.1815, Test Acc: 94.67%
# Epoch 128/200: Train Loss: 0.0434, Train Acc: 98.55%, Test Loss: 0.1808, Test Acc: 94.71%
# Epoch 129/200: Train Loss: 0.0418, Train Acc: 98.65%, Test Loss: 0.1843, Test Acc: 94.75%
# New best model saved with accuracy: 94.75%
# Epoch 130/200: Train Loss: 0.0426, Train Acc: 98.65%, Test Loss: 0.1844, Test Acc: 94.77%
# New best model saved with accuracy: 94.77%
# Epoch 131/200: Train Loss: 0.0401, Train Acc: 98.76%, Test Loss: 0.1842, Test Acc: 94.73%
# Epoch 132/200: Train Loss: 0.0384, Train Acc: 98.79%, Test Loss: 0.1815, Test Acc: 94.83%
# New best model saved with accuracy: 94.83%
# Epoch 133/200: Train Loss: 0.0376, Train Acc: 98.80%, Test Loss: 0.1824, Test Acc: 94.86%
# New best model saved with accuracy: 94.86%
# Epoch 134/200: Train Loss: 0.0375, Train Acc: 98.79%, Test Loss: 0.1831, Test Acc: 94.80%
# Epoch 135/200: Train Loss: 0.0353, Train Acc: 98.93%, Test Loss: 0.1835, Test Acc: 95.02%
# New best model saved with accuracy: 95.02%
# Epoch 136/200: Train Loss: 0.0356, Train Acc: 98.87%, Test Loss: 0.1831, Test Acc: 94.87%
# Epoch 137/200: Train Loss: 0.0336, Train Acc: 98.98%, Test Loss: 0.1820, Test Acc: 94.85%
# Epoch 138/200: Train Loss: 0.0329, Train Acc: 98.97%, Test Loss: 0.1849, Test Acc: 94.89%
# Epoch 139/200: Train Loss: 0.0329, Train Acc: 98.99%, Test Loss: 0.1854, Test Acc: 94.78%
# Epoch 140/200: Train Loss: 0.0320, Train Acc: 99.00%, Test Loss: 0.1856, Test Acc: 94.94%
# Epoch 141/200: Train Loss: 0.0324, Train Acc: 98.98%, Test Loss: 0.1868, Test Acc: 94.75%
# Epoch 142/200: Train Loss: 0.0316, Train Acc: 99.02%, Test Loss: 0.1843, Test Acc: 94.75%
# Epoch 143/200: Train Loss: 0.0296, Train Acc: 99.12%, Test Loss: 0.1921, Test Acc: 94.55%
# Epoch 144/200: Train Loss: 0.0300, Train Acc: 99.07%, Test Loss: 0.1923, Test Acc: 94.52%
# Epoch 145/200: Train Loss: 0.0295, Train Acc: 99.12%, Test Loss: 0.1900, Test Acc: 94.80%
# Epoch 146/200: Train Loss: 0.0288, Train Acc: 99.12%, Test Loss: 0.1936, Test Acc: 94.66%
# Epoch 147/200: Train Loss: 0.0277, Train Acc: 99.10%, Test Loss: 0.1915, Test Acc: 94.77%
# Epoch 148/200: Train Loss: 0.0285, Train Acc: 99.11%, Test Loss: 0.1934, Test Acc: 94.71%
# Epoch 149/200: Train Loss: 0.0276, Train Acc: 99.17%, Test Loss: 0.1944, Test Acc: 94.72%
# Epoch 150/200: Train Loss: 0.0277, Train Acc: 99.13%, Test Loss: 0.1944, Test Acc: 94.75%
# Epoch 151/200: Train Loss: 0.0279, Train Acc: 99.13%, Test Loss: 0.1925, Test Acc: 94.76%
# Epoch 152/200: Train Loss: 0.0258, Train Acc: 99.19%, Test Loss: 0.1898, Test Acc: 94.86%
# Epoch 153/200: Train Loss: 0.0252, Train Acc: 99.18%, Test Loss: 0.1904, Test Acc: 94.86%
# Epoch 154/200: Train Loss: 0.0243, Train Acc: 99.27%, Test Loss: 0.1949, Test Acc: 94.73%
# Epoch 155/200: Train Loss: 0.0270, Train Acc: 99.14%, Test Loss: 0.1911, Test Acc: 94.79%
# Epoch 156/200: Train Loss: 0.0245, Train Acc: 99.23%, Test Loss: 0.1945, Test Acc: 94.70%
# Epoch 157/200: Train Loss: 0.0243, Train Acc: 99.25%, Test Loss: 0.1962, Test Acc: 94.78%
# Epoch 158/200: Train Loss: 0.0240, Train Acc: 99.25%, Test Loss: 0.1989, Test Acc: 94.81%
# Epoch 159/200: Train Loss: 0.0243, Train Acc: 99.28%, Test Loss: 0.1939, Test Acc: 94.98%
# Epoch 160/200: Train Loss: 0.0238, Train Acc: 99.30%, Test Loss: 0.1941, Test Acc: 94.84%
# Epoch 161/200: Train Loss: 0.0222, Train Acc: 99.36%, Test Loss: 0.1924, Test Acc: 94.87%
# Epoch 162/200: Train Loss: 0.0216, Train Acc: 99.38%, Test Loss: 0.1898, Test Acc: 94.90%
# Epoch 163/200: Train Loss: 0.0223, Train Acc: 99.31%, Test Loss: 0.1887, Test Acc: 94.98%
# Epoch 164/200: Train Loss: 0.0209, Train Acc: 99.41%, Test Loss: 0.1888, Test Acc: 94.95%
# Epoch 165/200: Train Loss: 0.0205, Train Acc: 99.39%, Test Loss: 0.1887, Test Acc: 95.02%
# Epoch 166/200: Train Loss: 0.0194, Train Acc: 99.42%, Test Loss: 0.1894, Test Acc: 94.99%
# Epoch 167/200: Train Loss: 0.0207, Train Acc: 99.36%, Test Loss: 0.1890, Test Acc: 94.98%
# Epoch 168/200: Train Loss: 0.0212, Train Acc: 99.37%, Test Loss: 0.1886, Test Acc: 95.00%
# Epoch 169/200: Train Loss: 0.0204, Train Acc: 99.41%, Test Loss: 0.1873, Test Acc: 95.04%
# New best model saved with accuracy: 95.04%
# Epoch 170/200: Train Loss: 0.0187, Train Acc: 99.46%, Test Loss: 0.1869, Test Acc: 95.07%
# New best model saved with accuracy: 95.07%
# Epoch 171/200: Train Loss: 0.0189, Train Acc: 99.41%, Test Loss: 0.1888, Test Acc: 95.02%
# Epoch 172/200: Train Loss: 0.0200, Train Acc: 99.43%, Test Loss: 0.1876, Test Acc: 95.02%
# Epoch 173/200: Train Loss: 0.0203, Train Acc: 99.38%, Test Loss: 0.1891, Test Acc: 95.06%
# Epoch 174/200: Train Loss: 0.0191, Train Acc: 99.43%, Test Loss: 0.1876, Test Acc: 95.14%
# New best model saved with accuracy: 95.14%
# Epoch 175/200: Train Loss: 0.0202, Train Acc: 99.38%, Test Loss: 0.1883, Test Acc: 95.09%
# Epoch 176/200: Train Loss: 0.0191, Train Acc: 99.46%, Test Loss: 0.1886, Test Acc: 95.13%
# Epoch 177/200: Train Loss: 0.0193, Train Acc: 99.43%, Test Loss: 0.1880, Test Acc: 95.12%
# Epoch 178/200: Train Loss: 0.0200, Train Acc: 99.34%, Test Loss: 0.1893, Test Acc: 94.91%
# Epoch 179/200: Train Loss: 0.0181, Train Acc: 99.47%, Test Loss: 0.1886, Test Acc: 95.01%
# Epoch 180/200: Train Loss: 0.0185, Train Acc: 99.48%, Test Loss: 0.1891, Test Acc: 94.99%
# Epoch 181/200: Train Loss: 0.0179, Train Acc: 99.47%, Test Loss: 0.1885, Test Acc: 94.95%
# Epoch 182/200: Train Loss: 0.0187, Train Acc: 99.48%, Test Loss: 0.1876, Test Acc: 95.07%
# Epoch 183/200: Train Loss: 0.0188, Train Acc: 99.43%, Test Loss: 0.1887, Test Acc: 95.10%
# Epoch 184/200: Train Loss: 0.0185, Train Acc: 99.46%, Test Loss: 0.1875, Test Acc: 95.01%
# Epoch 185/200: Train Loss: 0.0192, Train Acc: 99.43%, Test Loss: 0.1872, Test Acc: 95.06%
# Epoch 186/200: Train Loss: 0.0189, Train Acc: 99.46%, Test Loss: 0.1878, Test Acc: 95.11%
# Epoch 187/200: Train Loss: 0.0200, Train Acc: 99.40%, Test Loss: 0.1890, Test Acc: 94.95%
# Epoch 188/200: Train Loss: 0.0197, Train Acc: 99.41%, Test Loss: 0.1896, Test Acc: 95.00%
# Epoch 189/200: Train Loss: 0.0201, Train Acc: 99.38%, Test Loss: 0.1887, Test Acc: 95.02%
# Epoch 190/200: Train Loss: 0.0184, Train Acc: 99.46%, Test Loss: 0.1884, Test Acc: 94.97%
# Epoch 191/200: Train Loss: 0.0179, Train Acc: 99.48%, Test Loss: 0.1903, Test Acc: 95.05%
# Epoch 192/200: Train Loss: 0.0193, Train Acc: 99.42%, Test Loss: 0.1899, Test Acc: 94.98%
# Epoch 193/200: Train Loss: 0.0189, Train Acc: 99.46%, Test Loss: 0.1890, Test Acc: 94.99%
# Epoch 194/200: Train Loss: 0.0183, Train Acc: 99.45%, Test Loss: 0.1905, Test Acc: 95.00%
# Epoch 195/200: Train Loss: 0.0188, Train Acc: 99.43%, Test Loss: 0.1894, Test Acc: 95.03%
# Epoch 196/200: Train Loss: 0.0183, Train Acc: 99.47%, Test Loss: 0.1888, Test Acc: 95.07%
# Epoch 197/200: Train Loss: 0.0196, Train Acc: 99.41%, Test Loss: 0.1886, Test Acc: 94.98%
# Epoch 198/200: Train Loss: 0.0186, Train Acc: 99.47%, Test Loss: 0.1889, Test Acc: 95.02%
# Epoch 199/200: Train Loss: 0.0184, Train Acc: 99.47%, Test Loss: 0.1897, Test Acc: 95.01%
# Epoch 200/200: Train Loss: 0.0189, Train Acc: 99.44%, Test Loss: 0.1893, Test Acc: 95.04%
# Training completed! Best accuracy: 95.14%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA4.pth'):
        checkpoint = torch.load('model/best_modelA4.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 95%
# Accuracy of car   : 98%
# Accuracy of bird  : 93%
# Accuracy of cat   : 90%
# Accuracy of deer  : 96%
# Accuracy of dog   : 91%
# Accuracy of frog  : 97%
# Accuracy of horse : 97%
# Accuracy of ship  : 97%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.95      0.95      0.95      1000
#          car       0.97      0.98      0.97      1000
#         bird       0.95      0.93      0.94      1000
#          cat       0.90      0.91      0.90      1000
#         deer       0.94      0.96      0.95      1000
#          dog       0.93      0.91      0.92      1000
#         frog       0.97      0.97      0.97      1000
#        horse       0.98      0.97      0.98      1000
#         ship       0.96      0.97      0.96      1000
#        truck       0.96      0.96      0.96      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
