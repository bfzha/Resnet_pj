# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA4.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.0023, Train Acc: 27.12%, Test Loss: 1.7299, Test Acc: 35.53%
# New best model saved with accuracy: 35.53%
# Epoch 2/200: Train Loss: 1.6457, Train Acc: 39.22%, Test Loss: 1.4845, Test Acc: 46.54%
# New best model saved with accuracy: 46.54%
# Epoch 3/200: Train Loss: 1.3701, Train Acc: 50.28%, Test Loss: 1.2077, Test Acc: 57.85%
# New best model saved with accuracy: 57.85%
# Epoch 4/200: Train Loss: 1.1499, Train Acc: 59.03%, Test Loss: 1.1268, Test Acc: 59.96%
# New best model saved with accuracy: 59.96%
# Epoch 5/200: Train Loss: 1.0063, Train Acc: 64.57%, Test Loss: 0.8673, Test Acc: 70.32%
# New best model saved with accuracy: 70.32%
# Epoch 6/200: Train Loss: 0.8801, Train Acc: 69.25%, Test Loss: 0.8634, Test Acc: 71.36%
# New best model saved with accuracy: 71.36%
# Epoch 7/200: Train Loss: 0.8026, Train Acc: 72.06%, Test Loss: 0.6812, Test Acc: 76.33%
# New best model saved with accuracy: 76.33%
# Epoch 8/200: Train Loss: 0.7598, Train Acc: 73.58%, Test Loss: 0.7365, Test Acc: 74.64%
# Epoch 9/200: Train Loss: 0.7178, Train Acc: 75.10%, Test Loss: 0.7726, Test Acc: 74.34%
# Epoch 10/200: Train Loss: 0.6979, Train Acc: 75.86%, Test Loss: 0.7764, Test Acc: 74.49%
# Epoch 11/200: Train Loss: 0.6764, Train Acc: 76.68%, Test Loss: 0.6545, Test Acc: 76.93%
# New best model saved with accuracy: 76.93%
# Epoch 12/200: Train Loss: 0.6507, Train Acc: 77.24%, Test Loss: 0.7524, Test Acc: 75.08%
# Epoch 13/200: Train Loss: 0.6398, Train Acc: 78.01%, Test Loss: 0.5990, Test Acc: 79.97%
# New best model saved with accuracy: 79.97%
# Epoch 14/200: Train Loss: 0.6328, Train Acc: 78.15%, Test Loss: 0.6208, Test Acc: 79.20%
# Epoch 15/200: Train Loss: 0.6118, Train Acc: 78.72%, Test Loss: 0.6060, Test Acc: 79.64%
# Epoch 16/200: Train Loss: 0.6041, Train Acc: 79.26%, Test Loss: 0.6874, Test Acc: 76.43%
# Epoch 17/200: Train Loss: 0.5943, Train Acc: 79.40%, Test Loss: 0.6320, Test Acc: 78.74%
# Epoch 18/200: Train Loss: 0.5865, Train Acc: 79.84%, Test Loss: 0.5223, Test Acc: 82.36%
# New best model saved with accuracy: 82.36%
# Epoch 19/200: Train Loss: 0.5765, Train Acc: 79.93%, Test Loss: 0.6364, Test Acc: 78.92%
# Epoch 20/200: Train Loss: 0.5719, Train Acc: 80.28%, Test Loss: 0.5580, Test Acc: 81.36%
# Epoch 21/200: Train Loss: 0.5649, Train Acc: 80.59%, Test Loss: 0.5271, Test Acc: 82.97%
# New best model saved with accuracy: 82.97%
# Epoch 22/200: Train Loss: 0.5681, Train Acc: 80.39%, Test Loss: 0.6384, Test Acc: 78.53%
# Epoch 23/200: Train Loss: 0.5595, Train Acc: 80.90%, Test Loss: 0.5929, Test Acc: 80.52%
# Epoch 24/200: Train Loss: 0.5552, Train Acc: 80.83%, Test Loss: 0.5061, Test Acc: 82.70%
# Epoch 25/200: Train Loss: 0.5467, Train Acc: 81.31%, Test Loss: 0.9288, Test Acc: 73.14%
# Epoch 26/200: Train Loss: 0.5486, Train Acc: 81.32%, Test Loss: 0.6666, Test Acc: 78.44%
# Epoch 27/200: Train Loss: 0.5421, Train Acc: 81.54%, Test Loss: 0.5836, Test Acc: 81.13%
# Epoch 28/200: Train Loss: 0.5396, Train Acc: 81.65%, Test Loss: 0.4731, Test Acc: 83.52%
# New best model saved with accuracy: 83.52%
# Epoch 29/200: Train Loss: 0.5418, Train Acc: 81.44%, Test Loss: 0.5329, Test Acc: 82.46%
# Epoch 30/200: Train Loss: 0.5351, Train Acc: 81.63%, Test Loss: 0.5774, Test Acc: 81.11%
# Epoch 31/200: Train Loss: 0.5386, Train Acc: 81.63%, Test Loss: 0.7575, Test Acc: 76.49%
# Epoch 32/200: Train Loss: 0.5286, Train Acc: 81.82%, Test Loss: 0.5502, Test Acc: 81.63%
# Epoch 33/200: Train Loss: 0.5277, Train Acc: 82.02%, Test Loss: 0.5785, Test Acc: 81.29%
# Epoch 34/200: Train Loss: 0.5235, Train Acc: 82.06%, Test Loss: 0.6235, Test Acc: 79.51%
# Epoch 35/200: Train Loss: 0.5187, Train Acc: 82.28%, Test Loss: 0.5308, Test Acc: 82.79%
# Epoch 36/200: Train Loss: 0.5279, Train Acc: 82.06%, Test Loss: 0.5574, Test Acc: 81.20%
# Epoch 37/200: Train Loss: 0.5186, Train Acc: 82.20%, Test Loss: 0.5865, Test Acc: 80.36%
# Epoch 38/200: Train Loss: 0.5197, Train Acc: 81.99%, Test Loss: 0.5046, Test Acc: 83.03%
# Epoch 39/200: Train Loss: 0.5176, Train Acc: 82.39%, Test Loss: 0.4820, Test Acc: 83.33%
# Epoch 40/200: Train Loss: 0.5114, Train Acc: 82.41%, Test Loss: 0.5282, Test Acc: 82.47%
# Epoch 41/200: Train Loss: 0.5050, Train Acc: 82.67%, Test Loss: 0.5215, Test Acc: 82.91%
# Epoch 42/200: Train Loss: 0.5145, Train Acc: 82.44%, Test Loss: 0.5195, Test Acc: 82.63%
# Epoch 43/200: Train Loss: 0.5059, Train Acc: 82.69%, Test Loss: 0.5843, Test Acc: 81.22%
# Epoch 44/200: Train Loss: 0.5084, Train Acc: 82.64%, Test Loss: 0.5356, Test Acc: 81.86%
# Epoch 45/200: Train Loss: 0.5078, Train Acc: 82.52%, Test Loss: 0.6684, Test Acc: 78.16%
# Epoch 46/200: Train Loss: 0.5054, Train Acc: 82.59%, Test Loss: 0.4677, Test Acc: 84.32%
# New best model saved with accuracy: 84.32%
# Epoch 47/200: Train Loss: 0.5045, Train Acc: 82.72%, Test Loss: 0.5538, Test Acc: 81.09%
# Epoch 48/200: Train Loss: 0.5078, Train Acc: 82.62%, Test Loss: 0.5780, Test Acc: 80.75%
# Epoch 49/200: Train Loss: 0.5004, Train Acc: 82.81%, Test Loss: 0.7335, Test Acc: 76.50%
# Epoch 50/200: Train Loss: 0.5054, Train Acc: 82.82%, Test Loss: 0.5131, Test Acc: 82.78%
# Epoch 51/200: Train Loss: 0.4980, Train Acc: 82.98%, Test Loss: 0.8181, Test Acc: 73.56%
# Epoch 52/200: Train Loss: 0.5032, Train Acc: 82.73%, Test Loss: 0.5157, Test Acc: 82.78%
# Epoch 53/200: Train Loss: 0.4961, Train Acc: 82.88%, Test Loss: 0.4529, Test Acc: 84.54%
# New best model saved with accuracy: 84.54%
# Epoch 54/200: Train Loss: 0.4971, Train Acc: 82.96%, Test Loss: 0.4638, Test Acc: 84.77%
# New best model saved with accuracy: 84.77%
# Epoch 55/200: Train Loss: 0.4890, Train Acc: 83.09%, Test Loss: 0.6036, Test Acc: 80.23%
# Epoch 56/200: Train Loss: 0.5006, Train Acc: 82.96%, Test Loss: 0.5026, Test Acc: 83.04%
# Epoch 57/200: Train Loss: 0.4912, Train Acc: 83.32%, Test Loss: 0.5717, Test Acc: 80.76%
# Epoch 58/200: Train Loss: 0.4915, Train Acc: 83.07%, Test Loss: 0.5633, Test Acc: 82.28%
# Epoch 59/200: Train Loss: 0.4924, Train Acc: 83.08%, Test Loss: 0.5342, Test Acc: 82.57%
# Epoch 60/200: Train Loss: 0.4970, Train Acc: 83.20%, Test Loss: 0.4816, Test Acc: 84.19%
# Epoch 61/200: Train Loss: 0.4968, Train Acc: 82.97%, Test Loss: 0.4735, Test Acc: 83.82%
# Epoch 62/200: Train Loss: 0.4858, Train Acc: 83.43%, Test Loss: 0.5925, Test Acc: 81.01%
# Epoch 63/200: Train Loss: 0.4922, Train Acc: 83.32%, Test Loss: 0.4698, Test Acc: 83.87%
# Epoch 64/200: Train Loss: 0.4950, Train Acc: 82.96%, Test Loss: 0.4808, Test Acc: 83.35%
# Epoch 65/200: Train Loss: 0.4895, Train Acc: 83.17%, Test Loss: 0.4945, Test Acc: 83.68%
# Epoch 66/200: Train Loss: 0.4855, Train Acc: 83.28%, Test Loss: 0.4619, Test Acc: 84.69%
# Epoch 67/200: Train Loss: 0.4877, Train Acc: 83.39%, Test Loss: 0.5607, Test Acc: 81.48%
# Epoch 68/200: Train Loss: 0.4972, Train Acc: 82.85%, Test Loss: 0.4800, Test Acc: 83.52%
# Epoch 69/200: Train Loss: 0.4861, Train Acc: 83.35%, Test Loss: 0.5853, Test Acc: 81.01%
# Epoch 70/200: Train Loss: 0.4869, Train Acc: 83.33%, Test Loss: 0.5346, Test Acc: 82.10%
# Epoch 71/200: Train Loss: 0.3092, Train Acc: 89.44%, Test Loss: 0.2330, Test Acc: 91.89%
# New best model saved with accuracy: 91.89%
# Epoch 72/200: Train Loss: 0.2568, Train Acc: 91.24%, Test Loss: 0.2217, Test Acc: 92.43%
# New best model saved with accuracy: 92.43%
# Epoch 73/200: Train Loss: 0.2306, Train Acc: 92.22%, Test Loss: 0.2119, Test Acc: 92.76%
# New best model saved with accuracy: 92.76%
# Epoch 74/200: Train Loss: 0.2170, Train Acc: 92.52%, Test Loss: 0.2130, Test Acc: 93.02%
# New best model saved with accuracy: 93.02%
# Epoch 75/200: Train Loss: 0.2096, Train Acc: 92.82%, Test Loss: 0.2047, Test Acc: 93.11%
# New best model saved with accuracy: 93.11%
# Epoch 76/200: Train Loss: 0.1967, Train Acc: 93.26%, Test Loss: 0.1992, Test Acc: 93.30%
# New best model saved with accuracy: 93.30%
# Epoch 77/200: Train Loss: 0.1902, Train Acc: 93.34%, Test Loss: 0.1957, Test Acc: 93.44%
# New best model saved with accuracy: 93.44%
# Epoch 78/200: Train Loss: 0.1819, Train Acc: 93.71%, Test Loss: 0.2023, Test Acc: 93.49%
# New best model saved with accuracy: 93.49%
# Epoch 79/200: Train Loss: 0.1759, Train Acc: 93.93%, Test Loss: 0.1994, Test Acc: 93.35%
# Epoch 80/200: Train Loss: 0.1717, Train Acc: 94.05%, Test Loss: 0.2005, Test Acc: 93.46%
# Epoch 81/200: Train Loss: 0.1677, Train Acc: 94.20%, Test Loss: 0.1958, Test Acc: 93.46%
# Epoch 82/200: Train Loss: 0.1624, Train Acc: 94.38%, Test Loss: 0.2055, Test Acc: 93.41%
# Epoch 83/200: Train Loss: 0.1622, Train Acc: 94.38%, Test Loss: 0.2005, Test Acc: 93.47%
# Epoch 84/200: Train Loss: 0.1585, Train Acc: 94.46%, Test Loss: 0.2033, Test Acc: 93.16%
# Epoch 85/200: Train Loss: 0.1513, Train Acc: 94.77%, Test Loss: 0.2017, Test Acc: 93.54%
# New best model saved with accuracy: 93.54%
# Epoch 86/200: Train Loss: 0.1500, Train Acc: 94.81%, Test Loss: 0.2037, Test Acc: 93.61%
# New best model saved with accuracy: 93.61%
# Epoch 87/200: Train Loss: 0.1457, Train Acc: 95.06%, Test Loss: 0.2069, Test Acc: 93.44%
# Epoch 88/200: Train Loss: 0.1445, Train Acc: 94.95%, Test Loss: 0.2196, Test Acc: 92.86%
# Epoch 89/200: Train Loss: 0.1453, Train Acc: 94.96%, Test Loss: 0.2007, Test Acc: 93.43%
# Epoch 90/200: Train Loss: 0.1438, Train Acc: 95.06%, Test Loss: 0.2120, Test Acc: 93.11%
# Epoch 91/200: Train Loss: 0.1434, Train Acc: 94.99%, Test Loss: 0.2088, Test Acc: 93.39%
# Epoch 92/200: Train Loss: 0.1426, Train Acc: 95.02%, Test Loss: 0.2269, Test Acc: 92.90%
# Epoch 93/200: Train Loss: 0.1400, Train Acc: 95.15%, Test Loss: 0.2326, Test Acc: 92.54%
# Epoch 94/200: Train Loss: 0.1374, Train Acc: 95.35%, Test Loss: 0.2235, Test Acc: 93.24%
# Epoch 95/200: Train Loss: 0.1378, Train Acc: 95.24%, Test Loss: 0.2161, Test Acc: 92.86%
# Epoch 96/200: Train Loss: 0.1392, Train Acc: 95.18%, Test Loss: 0.2142, Test Acc: 93.13%
# Epoch 97/200: Train Loss: 0.1370, Train Acc: 95.22%, Test Loss: 0.2029, Test Acc: 93.43%
# Epoch 98/200: Train Loss: 0.1390, Train Acc: 95.21%, Test Loss: 0.2297, Test Acc: 92.51%
# Epoch 99/200: Train Loss: 0.1368, Train Acc: 95.35%, Test Loss: 0.2457, Test Acc: 92.27%
# Epoch 100/200: Train Loss: 0.1381, Train Acc: 95.20%, Test Loss: 0.2507, Test Acc: 92.23%
# Epoch 101/200: Train Loss: 0.1347, Train Acc: 95.24%, Test Loss: 0.2188, Test Acc: 93.11%
# Epoch 102/200: Train Loss: 0.1414, Train Acc: 95.10%, Test Loss: 0.2139, Test Acc: 93.50%
# Epoch 103/200: Train Loss: 0.1341, Train Acc: 95.46%, Test Loss: 0.2325, Test Acc: 92.48%
# Epoch 104/200: Train Loss: 0.1331, Train Acc: 95.44%, Test Loss: 0.2457, Test Acc: 92.32%
# Epoch 105/200: Train Loss: 0.1383, Train Acc: 95.23%, Test Loss: 0.2321, Test Acc: 92.88%
# Epoch 106/200: Train Loss: 0.1360, Train Acc: 95.29%, Test Loss: 0.2339, Test Acc: 92.64%
# Epoch 107/200: Train Loss: 0.1361, Train Acc: 95.32%, Test Loss: 0.2358, Test Acc: 92.70%
# Epoch 108/200: Train Loss: 0.1344, Train Acc: 95.37%, Test Loss: 0.2556, Test Acc: 92.22%
# Epoch 109/200: Train Loss: 0.1316, Train Acc: 95.44%, Test Loss: 0.2483, Test Acc: 92.30%
# Epoch 110/200: Train Loss: 0.1361, Train Acc: 95.31%, Test Loss: 0.2272, Test Acc: 92.98%
# Epoch 111/200: Train Loss: 0.1376, Train Acc: 95.18%, Test Loss: 0.2196, Test Acc: 92.82%
# Epoch 112/200: Train Loss: 0.1315, Train Acc: 95.47%, Test Loss: 0.2516, Test Acc: 92.51%
# Epoch 113/200: Train Loss: 0.1378, Train Acc: 95.20%, Test Loss: 0.2405, Test Acc: 92.63%
# Epoch 114/200: Train Loss: 0.1299, Train Acc: 95.62%, Test Loss: 0.2237, Test Acc: 93.10%
# Epoch 115/200: Train Loss: 0.1353, Train Acc: 95.35%, Test Loss: 0.2300, Test Acc: 92.91%
# Epoch 116/200: Train Loss: 0.1357, Train Acc: 95.33%, Test Loss: 0.2469, Test Acc: 92.56%
# Epoch 117/200: Train Loss: 0.1345, Train Acc: 95.33%, Test Loss: 0.2536, Test Acc: 92.17%
# Epoch 118/200: Train Loss: 0.1315, Train Acc: 95.49%, Test Loss: 0.2429, Test Acc: 92.49%
# Epoch 119/200: Train Loss: 0.1299, Train Acc: 95.52%, Test Loss: 0.2631, Test Acc: 92.00%
# Epoch 120/200: Train Loss: 0.1330, Train Acc: 95.39%, Test Loss: 0.2647, Test Acc: 92.25%
# Epoch 121/200: Train Loss: 0.0856, Train Acc: 97.11%, Test Loss: 0.1837, Test Acc: 94.39%
# New best model saved with accuracy: 94.39%
# Epoch 122/200: Train Loss: 0.0693, Train Acc: 97.72%, Test Loss: 0.1790, Test Acc: 94.66%
# New best model saved with accuracy: 94.66%
# Epoch 123/200: Train Loss: 0.0588, Train Acc: 98.16%, Test Loss: 0.1751, Test Acc: 94.86%
# New best model saved with accuracy: 94.86%
# Epoch 124/200: Train Loss: 0.0534, Train Acc: 98.29%, Test Loss: 0.1752, Test Acc: 94.80%
# Epoch 125/200: Train Loss: 0.0518, Train Acc: 98.36%, Test Loss: 0.1761, Test Acc: 94.85%
# Epoch 126/200: Train Loss: 0.0465, Train Acc: 98.53%, Test Loss: 0.1767, Test Acc: 94.79%
# Epoch 127/200: Train Loss: 0.0447, Train Acc: 98.53%, Test Loss: 0.1775, Test Acc: 94.79%
# Epoch 128/200: Train Loss: 0.0433, Train Acc: 98.69%, Test Loss: 0.1814, Test Acc: 94.67%
# Epoch 129/200: Train Loss: 0.0431, Train Acc: 98.63%, Test Loss: 0.1778, Test Acc: 94.80%
# Epoch 130/200: Train Loss: 0.0403, Train Acc: 98.74%, Test Loss: 0.1750, Test Acc: 94.94%
# New best model saved with accuracy: 94.94%
# Epoch 131/200: Train Loss: 0.0382, Train Acc: 98.83%, Test Loss: 0.1766, Test Acc: 94.79%
# Epoch 132/200: Train Loss: 0.0384, Train Acc: 98.78%, Test Loss: 0.1746, Test Acc: 95.02%
# New best model saved with accuracy: 95.02%
# Epoch 133/200: Train Loss: 0.0380, Train Acc: 98.84%, Test Loss: 0.1792, Test Acc: 94.84%
# Epoch 134/200: Train Loss: 0.0367, Train Acc: 98.89%, Test Loss: 0.1798, Test Acc: 94.85%
# Epoch 135/200: Train Loss: 0.0361, Train Acc: 98.86%, Test Loss: 0.1762, Test Acc: 94.99%
# Epoch 136/200: Train Loss: 0.0345, Train Acc: 98.94%, Test Loss: 0.1780, Test Acc: 94.90%
# Epoch 137/200: Train Loss: 0.0324, Train Acc: 99.00%, Test Loss: 0.1777, Test Acc: 94.95%
# Epoch 138/200: Train Loss: 0.0319, Train Acc: 99.02%, Test Loss: 0.1794, Test Acc: 94.95%
# Epoch 139/200: Train Loss: 0.0300, Train Acc: 99.08%, Test Loss: 0.1784, Test Acc: 95.09%
# New best model saved with accuracy: 95.09%
# Epoch 140/200: Train Loss: 0.0304, Train Acc: 99.05%, Test Loss: 0.1771, Test Acc: 95.03%
# Epoch 141/200: Train Loss: 0.0319, Train Acc: 99.04%, Test Loss: 0.1817, Test Acc: 94.90%
# Epoch 142/200: Train Loss: 0.0286, Train Acc: 99.13%, Test Loss: 0.1818, Test Acc: 94.96%
# Epoch 143/200: Train Loss: 0.0283, Train Acc: 99.13%, Test Loss: 0.1811, Test Acc: 94.97%
# Epoch 144/200: Train Loss: 0.0290, Train Acc: 99.12%, Test Loss: 0.1842, Test Acc: 94.79%
# Epoch 145/200: Train Loss: 0.0286, Train Acc: 99.10%, Test Loss: 0.1837, Test Acc: 94.79%
# Epoch 146/200: Train Loss: 0.0284, Train Acc: 99.12%, Test Loss: 0.1812, Test Acc: 94.75%
# Epoch 147/200: Train Loss: 0.0273, Train Acc: 99.18%, Test Loss: 0.1826, Test Acc: 94.75%
# Epoch 148/200: Train Loss: 0.0258, Train Acc: 99.21%, Test Loss: 0.1811, Test Acc: 94.93%
# Epoch 149/200: Train Loss: 0.0259, Train Acc: 99.19%, Test Loss: 0.1811, Test Acc: 94.87%
# Epoch 150/200: Train Loss: 0.0262, Train Acc: 99.19%, Test Loss: 0.1843, Test Acc: 94.78%
# Epoch 151/200: Train Loss: 0.0259, Train Acc: 99.20%, Test Loss: 0.1790, Test Acc: 94.87%
# Epoch 152/200: Train Loss: 0.0250, Train Acc: 99.24%, Test Loss: 0.1831, Test Acc: 94.92%
# Epoch 153/200: Train Loss: 0.0262, Train Acc: 99.18%, Test Loss: 0.1826, Test Acc: 94.77%
# Epoch 154/200: Train Loss: 0.0247, Train Acc: 99.25%, Test Loss: 0.1831, Test Acc: 94.84%
# Epoch 155/200: Train Loss: 0.0255, Train Acc: 99.21%, Test Loss: 0.1827, Test Acc: 94.88%
# Epoch 156/200: Train Loss: 0.0252, Train Acc: 99.23%, Test Loss: 0.1834, Test Acc: 94.81%
# Epoch 157/200: Train Loss: 0.0244, Train Acc: 99.29%, Test Loss: 0.1806, Test Acc: 94.98%
# Epoch 158/200: Train Loss: 0.0233, Train Acc: 99.26%, Test Loss: 0.1847, Test Acc: 94.86%
# Epoch 159/200: Train Loss: 0.0239, Train Acc: 99.32%, Test Loss: 0.1821, Test Acc: 94.91%
# Epoch 160/200: Train Loss: 0.0230, Train Acc: 99.33%, Test Loss: 0.1849, Test Acc: 94.84%
# Epoch 161/200: Train Loss: 0.0222, Train Acc: 99.30%, Test Loss: 0.1830, Test Acc: 94.87%
# Epoch 162/200: Train Loss: 0.0214, Train Acc: 99.37%, Test Loss: 0.1832, Test Acc: 94.92%
# Epoch 163/200: Train Loss: 0.0220, Train Acc: 99.37%, Test Loss: 0.1821, Test Acc: 95.01%
# Epoch 164/200: Train Loss: 0.0192, Train Acc: 99.41%, Test Loss: 0.1823, Test Acc: 94.95%
# Epoch 165/200: Train Loss: 0.0195, Train Acc: 99.42%, Test Loss: 0.1835, Test Acc: 95.04%
# Epoch 166/200: Train Loss: 0.0209, Train Acc: 99.38%, Test Loss: 0.1827, Test Acc: 95.02%
# Epoch 167/200: Train Loss: 0.0208, Train Acc: 99.35%, Test Loss: 0.1820, Test Acc: 95.12%
# New best model saved with accuracy: 95.12%
# Epoch 168/200: Train Loss: 0.0188, Train Acc: 99.48%, Test Loss: 0.1824, Test Acc: 95.04%
# Epoch 169/200: Train Loss: 0.0195, Train Acc: 99.46%, Test Loss: 0.1823, Test Acc: 94.98%
# Epoch 170/200: Train Loss: 0.0202, Train Acc: 99.39%, Test Loss: 0.1821, Test Acc: 95.04%
# Epoch 171/200: Train Loss: 0.0181, Train Acc: 99.46%, Test Loss: 0.1806, Test Acc: 95.06%
# Epoch 172/200: Train Loss: 0.0218, Train Acc: 99.34%, Test Loss: 0.1817, Test Acc: 95.12%
# Epoch 173/200: Train Loss: 0.0200, Train Acc: 99.42%, Test Loss: 0.1814, Test Acc: 95.02%
# Epoch 174/200: Train Loss: 0.0187, Train Acc: 99.48%, Test Loss: 0.1833, Test Acc: 95.01%
# Epoch 175/200: Train Loss: 0.0203, Train Acc: 99.38%, Test Loss: 0.1814, Test Acc: 95.12%
# Epoch 176/200: Train Loss: 0.0196, Train Acc: 99.46%, Test Loss: 0.1832, Test Acc: 95.03%
# Epoch 177/200: Train Loss: 0.0174, Train Acc: 99.48%, Test Loss: 0.1827, Test Acc: 95.05%
# Epoch 178/200: Train Loss: 0.0193, Train Acc: 99.40%, Test Loss: 0.1815, Test Acc: 95.06%
# Epoch 179/200: Train Loss: 0.0188, Train Acc: 99.46%, Test Loss: 0.1819, Test Acc: 95.06%
# Epoch 180/200: Train Loss: 0.0205, Train Acc: 99.39%, Test Loss: 0.1806, Test Acc: 95.16%
# New best model saved with accuracy: 95.16%
# Epoch 181/200: Train Loss: 0.0200, Train Acc: 99.40%, Test Loss: 0.1807, Test Acc: 95.11%
# Epoch 182/200: Train Loss: 0.0188, Train Acc: 99.47%, Test Loss: 0.1810, Test Acc: 95.06%
# Epoch 183/200: Train Loss: 0.0197, Train Acc: 99.45%, Test Loss: 0.1819, Test Acc: 95.07%
# Epoch 184/200: Train Loss: 0.0187, Train Acc: 99.48%, Test Loss: 0.1815, Test Acc: 95.08%
# Epoch 185/200: Train Loss: 0.0188, Train Acc: 99.44%, Test Loss: 0.1834, Test Acc: 95.03%
# Epoch 186/200: Train Loss: 0.0197, Train Acc: 99.44%, Test Loss: 0.1831, Test Acc: 95.06%
# Epoch 187/200: Train Loss: 0.0193, Train Acc: 99.44%, Test Loss: 0.1830, Test Acc: 95.02%
# Epoch 188/200: Train Loss: 0.0188, Train Acc: 99.41%, Test Loss: 0.1816, Test Acc: 95.08%
# Epoch 189/200: Train Loss: 0.0194, Train Acc: 99.44%, Test Loss: 0.1828, Test Acc: 95.05%
# Epoch 190/200: Train Loss: 0.0188, Train Acc: 99.43%, Test Loss: 0.1819, Test Acc: 94.98%
# Epoch 191/200: Train Loss: 0.0189, Train Acc: 99.45%, Test Loss: 0.1825, Test Acc: 95.09%
# Epoch 192/200: Train Loss: 0.0179, Train Acc: 99.48%, Test Loss: 0.1820, Test Acc: 95.13%
# Epoch 193/200: Train Loss: 0.0176, Train Acc: 99.47%, Test Loss: 0.1805, Test Acc: 95.12%
# Epoch 194/200: Train Loss: 0.0182, Train Acc: 99.47%, Test Loss: 0.1801, Test Acc: 95.15%
# Epoch 195/200: Train Loss: 0.0173, Train Acc: 99.50%, Test Loss: 0.1816, Test Acc: 95.11%
# Epoch 196/200: Train Loss: 0.0193, Train Acc: 99.42%, Test Loss: 0.1815, Test Acc: 95.08%
# Epoch 197/200: Train Loss: 0.0185, Train Acc: 99.42%, Test Loss: 0.1822, Test Acc: 95.07%
# Epoch 198/200: Train Loss: 0.0198, Train Acc: 99.43%, Test Loss: 0.1806, Test Acc: 95.12%
# Epoch 199/200: Train Loss: 0.0196, Train Acc: 99.41%, Test Loss: 0.1825, Test Acc: 95.07%
# Epoch 200/200: Train Loss: 0.0183, Train Acc: 99.48%, Test Loss: 0.1833, Test Acc: 95.06%
# Training completed! Best accuracy: 95.16%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA4.pth'):
        checkpoint = torch.load('model/best_modelA4.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 95%
# Accuracy of car   : 98%
# Accuracy of bird  : 94%
# Accuracy of cat   : 90%
# Accuracy of deer  : 96%
# Accuracy of dog   : 92%
# Accuracy of frog  : 96%
# Accuracy of horse : 97%
# Accuracy of ship  : 97%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.96      0.95      0.95      1000
#          car       0.98      0.98      0.98      1000
#         bird       0.94      0.94      0.94      1000
#          cat       0.89      0.90      0.89      1000
#         deer       0.95      0.96      0.96      1000
#          dog       0.92      0.92      0.92      1000
#         frog       0.97      0.96      0.97      1000
#        horse       0.98      0.97      0.97      1000
#         ship       0.97      0.97      0.97      1000
#        truck       0.97      0.96      0.97      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
