# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp3_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    transforms.RandomRotation(degrees=15), 
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_model3.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.6506, Train Acc: 39.42%, Test Loss: 1.4763, Test Acc: 49.89%
# New best model saved with accuracy: 49.89%
# Epoch 2/200: Train Loss: 1.2583, Train Acc: 54.64%, Test Loss: 1.0557, Test Acc: 63.03%
# New best model saved with accuracy: 63.03%
# Epoch 3/200: Train Loss: 1.0579, Train Acc: 62.43%, Test Loss: 0.9544, Test Acc: 67.38%
# New best model saved with accuracy: 67.38%
# Epoch 4/200: Train Loss: 0.9519, Train Acc: 66.40%, Test Loss: 0.8716, Test Acc: 71.81%
# New best model saved with accuracy: 71.81%
# Epoch 5/200: Train Loss: 0.8795, Train Acc: 69.01%, Test Loss: 0.6778, Test Acc: 76.63%
# New best model saved with accuracy: 76.63%
# Epoch 6/200: Train Loss: 0.8311, Train Acc: 70.92%, Test Loss: 0.8136, Test Acc: 72.73%
# Epoch 7/200: Train Loss: 0.7887, Train Acc: 72.50%, Test Loss: 0.7353, Test Acc: 75.88%
# Epoch 8/200: Train Loss: 0.7539, Train Acc: 73.46%, Test Loss: 0.6264, Test Acc: 79.42%
# New best model saved with accuracy: 79.42%
# Epoch 9/200: Train Loss: 0.7273, Train Acc: 74.65%, Test Loss: 0.6562, Test Acc: 78.05%
# Epoch 10/200: Train Loss: 0.7022, Train Acc: 75.83%, Test Loss: 0.6362, Test Acc: 78.73%
# Epoch 11/200: Train Loss: 0.6803, Train Acc: 76.33%, Test Loss: 0.5380, Test Acc: 82.04%
# New best model saved with accuracy: 82.04%
# Epoch 12/200: Train Loss: 0.6568, Train Acc: 77.25%, Test Loss: 0.5566, Test Acc: 81.90%
# Epoch 13/200: Train Loss: 0.6420, Train Acc: 77.57%, Test Loss: 0.6336, Test Acc: 79.56%
# Epoch 14/200: Train Loss: 0.6210, Train Acc: 78.63%, Test Loss: 0.6856, Test Acc: 79.18%
# Epoch 15/200: Train Loss: 0.6046, Train Acc: 78.94%, Test Loss: 0.5093, Test Acc: 82.17%
# New best model saved with accuracy: 82.17%
# Epoch 16/200: Train Loss: 0.5899, Train Acc: 79.55%, Test Loss: 0.5139, Test Acc: 83.19%
# New best model saved with accuracy: 83.19%
# Epoch 17/200: Train Loss: 0.5700, Train Acc: 80.26%, Test Loss: 0.4954, Test Acc: 84.09%
# New best model saved with accuracy: 84.09%
# Epoch 18/200: Train Loss: 0.5581, Train Acc: 80.70%, Test Loss: 0.4325, Test Acc: 85.79%
# New best model saved with accuracy: 85.79%
# Epoch 19/200: Train Loss: 0.5516, Train Acc: 80.88%, Test Loss: 0.4603, Test Acc: 84.25%
# Epoch 20/200: Train Loss: 0.5331, Train Acc: 81.53%, Test Loss: 0.4605, Test Acc: 84.80%
# Epoch 21/200: Train Loss: 0.5225, Train Acc: 81.94%, Test Loss: 0.3635, Test Acc: 87.33%
# New best model saved with accuracy: 87.33%
# Epoch 22/200: Train Loss: 0.5200, Train Acc: 82.06%, Test Loss: 0.4288, Test Acc: 85.48%
# Epoch 23/200: Train Loss: 0.5043, Train Acc: 82.61%, Test Loss: 0.3681, Test Acc: 87.30%
# Epoch 24/200: Train Loss: 0.4995, Train Acc: 82.85%, Test Loss: 0.3832, Test Acc: 87.42%
# New best model saved with accuracy: 87.42%
# Epoch 25/200: Train Loss: 0.4888, Train Acc: 83.00%, Test Loss: 0.3826, Test Acc: 86.91%
# Epoch 26/200: Train Loss: 0.4768, Train Acc: 83.55%, Test Loss: 0.3764, Test Acc: 87.34%
# Epoch 27/200: Train Loss: 0.4717, Train Acc: 83.69%, Test Loss: 0.4365, Test Acc: 86.35%
# Epoch 28/200: Train Loss: 0.4631, Train Acc: 83.83%, Test Loss: 0.3600, Test Acc: 88.23%
# New best model saved with accuracy: 88.23%
# Epoch 29/200: Train Loss: 0.4599, Train Acc: 84.18%, Test Loss: 0.3477, Test Acc: 88.29%
# New best model saved with accuracy: 88.29%
# Epoch 30/200: Train Loss: 0.4499, Train Acc: 84.35%, Test Loss: 0.3561, Test Acc: 88.38%
# New best model saved with accuracy: 88.38%
# Epoch 31/200: Train Loss: 0.4451, Train Acc: 84.68%, Test Loss: 0.3431, Test Acc: 88.57%
# New best model saved with accuracy: 88.57%
# Epoch 32/200: Train Loss: 0.4385, Train Acc: 84.79%, Test Loss: 0.3363, Test Acc: 88.81%
# New best model saved with accuracy: 88.81%
# Epoch 33/200: Train Loss: 0.4316, Train Acc: 85.03%, Test Loss: 0.3589, Test Acc: 88.35%
# Epoch 34/200: Train Loss: 0.4221, Train Acc: 85.49%, Test Loss: 0.3693, Test Acc: 88.05%
# Epoch 35/200: Train Loss: 0.4208, Train Acc: 85.47%, Test Loss: 0.3099, Test Acc: 89.77%
# New best model saved with accuracy: 89.77%
# Epoch 36/200: Train Loss: 0.4167, Train Acc: 85.63%, Test Loss: 0.3317, Test Acc: 89.29%
# Epoch 37/200: Train Loss: 0.4095, Train Acc: 85.81%, Test Loss: 0.3381, Test Acc: 89.00%
# Epoch 38/200: Train Loss: 0.4002, Train Acc: 86.14%, Test Loss: 0.3555, Test Acc: 88.81%
# Epoch 39/200: Train Loss: 0.4014, Train Acc: 86.04%, Test Loss: 0.2971, Test Acc: 90.42%
# New best model saved with accuracy: 90.42%
# Epoch 40/200: Train Loss: 0.3947, Train Acc: 86.09%, Test Loss: 0.3338, Test Acc: 89.25%
# Epoch 41/200: Train Loss: 0.3884, Train Acc: 86.48%, Test Loss: 0.3291, Test Acc: 89.53%
# Epoch 42/200: Train Loss: 0.3844, Train Acc: 86.73%, Test Loss: 0.3104, Test Acc: 89.96%
# Epoch 43/200: Train Loss: 0.3799, Train Acc: 86.89%, Test Loss: 0.3379, Test Acc: 88.96%
# Epoch 44/200: Train Loss: 0.3749, Train Acc: 87.05%, Test Loss: 0.3144, Test Acc: 89.87%
# Epoch 45/200: Train Loss: 0.3769, Train Acc: 86.88%, Test Loss: 0.3108, Test Acc: 89.87%
# Epoch 46/200: Train Loss: 0.3696, Train Acc: 87.08%, Test Loss: 0.2981, Test Acc: 90.08%
# Epoch 47/200: Train Loss: 0.3612, Train Acc: 87.50%, Test Loss: 0.2931, Test Acc: 90.81%
# New best model saved with accuracy: 90.81%
# Epoch 48/200: Train Loss: 0.3541, Train Acc: 87.81%, Test Loss: 0.2820, Test Acc: 90.72%
# Epoch 49/200: Train Loss: 0.3568, Train Acc: 87.60%, Test Loss: 0.3043, Test Acc: 90.00%
# Epoch 50/200: Train Loss: 0.3520, Train Acc: 87.80%, Test Loss: 0.3119, Test Acc: 89.97%
# Epoch 51/200: Train Loss: 0.3458, Train Acc: 87.95%, Test Loss: 0.2847, Test Acc: 90.58%
# Epoch 52/200: Train Loss: 0.3484, Train Acc: 88.01%, Test Loss: 0.2752, Test Acc: 90.88%
# New best model saved with accuracy: 90.88%
# Epoch 53/200: Train Loss: 0.3471, Train Acc: 87.93%, Test Loss: 0.3151, Test Acc: 89.78%
# Epoch 54/200: Train Loss: 0.3363, Train Acc: 88.29%, Test Loss: 0.2725, Test Acc: 91.40%
# New best model saved with accuracy: 91.40%
# Epoch 55/200: Train Loss: 0.3347, Train Acc: 88.30%, Test Loss: 0.2602, Test Acc: 91.34%
# Epoch 56/200: Train Loss: 0.3303, Train Acc: 88.66%, Test Loss: 0.2802, Test Acc: 90.84%
# Epoch 57/200: Train Loss: 0.3345, Train Acc: 88.51%, Test Loss: 0.2571, Test Acc: 91.79%
# New best model saved with accuracy: 91.79%
# Epoch 58/200: Train Loss: 0.3300, Train Acc: 88.52%, Test Loss: 0.2958, Test Acc: 90.63%
# Epoch 59/200: Train Loss: 0.3242, Train Acc: 88.77%, Test Loss: 0.2592, Test Acc: 91.81%
# New best model saved with accuracy: 91.81%
# Epoch 60/200: Train Loss: 0.3199, Train Acc: 88.96%, Test Loss: 0.2894, Test Acc: 90.61%
# Epoch 61/200: Train Loss: 0.3156, Train Acc: 88.94%, Test Loss: 0.2865, Test Acc: 90.74%
# Epoch 62/200: Train Loss: 0.3130, Train Acc: 89.09%, Test Loss: 0.2557, Test Acc: 91.47%
# Epoch 63/200: Train Loss: 0.3093, Train Acc: 89.32%, Test Loss: 0.2640, Test Acc: 91.83%
# New best model saved with accuracy: 91.83%
# Epoch 64/200: Train Loss: 0.3049, Train Acc: 89.54%, Test Loss: 0.2735, Test Acc: 91.24%
# Epoch 65/200: Train Loss: 0.3086, Train Acc: 89.40%, Test Loss: 0.2709, Test Acc: 91.50%
# Epoch 66/200: Train Loss: 0.2995, Train Acc: 89.58%, Test Loss: 0.2490, Test Acc: 92.04%
# New best model saved with accuracy: 92.04%
# Epoch 67/200: Train Loss: 0.2963, Train Acc: 89.72%, Test Loss: 0.2984, Test Acc: 90.45%
# Epoch 68/200: Train Loss: 0.2984, Train Acc: 89.70%, Test Loss: 0.2550, Test Acc: 91.68%
# Epoch 69/200: Train Loss: 0.2937, Train Acc: 89.79%, Test Loss: 0.2500, Test Acc: 92.20%
# New best model saved with accuracy: 92.20%
# Epoch 70/200: Train Loss: 0.2900, Train Acc: 89.95%, Test Loss: 0.2713, Test Acc: 91.68%
# Epoch 71/200: Train Loss: 0.2915, Train Acc: 89.84%, Test Loss: 0.2461, Test Acc: 92.43%
# New best model saved with accuracy: 92.43%
# Epoch 72/200: Train Loss: 0.2884, Train Acc: 90.14%, Test Loss: 0.2732, Test Acc: 91.55%
# Epoch 73/200: Train Loss: 0.2822, Train Acc: 90.15%, Test Loss: 0.2642, Test Acc: 91.76%
# Epoch 74/200: Train Loss: 0.2809, Train Acc: 90.30%, Test Loss: 0.2488, Test Acc: 92.42%
# Epoch 75/200: Train Loss: 0.2792, Train Acc: 90.28%, Test Loss: 0.2370, Test Acc: 92.67%
# New best model saved with accuracy: 92.67%
# Epoch 76/200: Train Loss: 0.2775, Train Acc: 90.37%, Test Loss: 0.2327, Test Acc: 92.61%
# Epoch 77/200: Train Loss: 0.2716, Train Acc: 90.58%, Test Loss: 0.2521, Test Acc: 92.23%
# Epoch 78/200: Train Loss: 0.2720, Train Acc: 90.63%, Test Loss: 0.2479, Test Acc: 92.48%
# Epoch 79/200: Train Loss: 0.2692, Train Acc: 90.70%, Test Loss: 0.2380, Test Acc: 92.60%
# Epoch 80/200: Train Loss: 0.2650, Train Acc: 90.68%, Test Loss: 0.2666, Test Acc: 92.03%
# Epoch 81/200: Train Loss: 0.2631, Train Acc: 90.86%, Test Loss: 0.2465, Test Acc: 92.34%
# Epoch 82/200: Train Loss: 0.2637, Train Acc: 90.87%, Test Loss: 0.2308, Test Acc: 92.77%
# New best model saved with accuracy: 92.77%
# Epoch 83/200: Train Loss: 0.2598, Train Acc: 90.97%, Test Loss: 0.2581, Test Acc: 92.16%
# Epoch 84/200: Train Loss: 0.2581, Train Acc: 91.12%, Test Loss: 0.2481, Test Acc: 92.47%
# Epoch 85/200: Train Loss: 0.2531, Train Acc: 91.26%, Test Loss: 0.2435, Test Acc: 92.46%
# Epoch 86/200: Train Loss: 0.2478, Train Acc: 91.44%, Test Loss: 0.2444, Test Acc: 92.55%
# Epoch 87/200: Train Loss: 0.2466, Train Acc: 91.40%, Test Loss: 0.2361, Test Acc: 92.83%
# New best model saved with accuracy: 92.83%
# Epoch 88/200: Train Loss: 0.2493, Train Acc: 91.30%, Test Loss: 0.2368, Test Acc: 92.68%
# Epoch 89/200: Train Loss: 0.2445, Train Acc: 91.67%, Test Loss: 0.2258, Test Acc: 92.75%
# Epoch 90/200: Train Loss: 0.2434, Train Acc: 91.61%, Test Loss: 0.2372, Test Acc: 92.68%
# Epoch 91/200: Train Loss: 0.2391, Train Acc: 91.61%, Test Loss: 0.2308, Test Acc: 93.12%
# New best model saved with accuracy: 93.12%
# Epoch 92/200: Train Loss: 0.2384, Train Acc: 91.70%, Test Loss: 0.2353, Test Acc: 92.90%
# Epoch 93/200: Train Loss: 0.2360, Train Acc: 92.00%, Test Loss: 0.2323, Test Acc: 92.96%
# Epoch 94/200: Train Loss: 0.2358, Train Acc: 91.87%, Test Loss: 0.2323, Test Acc: 93.00%
# Epoch 95/200: Train Loss: 0.2301, Train Acc: 92.06%, Test Loss: 0.2335, Test Acc: 92.78%
# Epoch 96/200: Train Loss: 0.2305, Train Acc: 92.08%, Test Loss: 0.2147, Test Acc: 93.32%
# New best model saved with accuracy: 93.32%
# Epoch 97/200: Train Loss: 0.2221, Train Acc: 92.36%, Test Loss: 0.2377, Test Acc: 92.78%
# Epoch 98/200: Train Loss: 0.2261, Train Acc: 92.23%, Test Loss: 0.2531, Test Acc: 92.69%
# Epoch 99/200: Train Loss: 0.2180, Train Acc: 92.47%, Test Loss: 0.2294, Test Acc: 93.11%
# Epoch 100/200: Train Loss: 0.2263, Train Acc: 92.13%, Test Loss: 0.2286, Test Acc: 93.02%
# Epoch 101/200: Train Loss: 0.2138, Train Acc: 92.52%, Test Loss: 0.2283, Test Acc: 93.22%
# Epoch 102/200: Train Loss: 0.2148, Train Acc: 92.63%, Test Loss: 0.2231, Test Acc: 93.03%
# Epoch 103/200: Train Loss: 0.2152, Train Acc: 92.45%, Test Loss: 0.2234, Test Acc: 93.09%
# Epoch 104/200: Train Loss: 0.2130, Train Acc: 92.69%, Test Loss: 0.2414, Test Acc: 93.05%
# Epoch 105/200: Train Loss: 0.2133, Train Acc: 92.69%, Test Loss: 0.2162, Test Acc: 93.51%
# New best model saved with accuracy: 93.51%
# Epoch 106/200: Train Loss: 0.2063, Train Acc: 92.91%, Test Loss: 0.2350, Test Acc: 93.04%
# Epoch 107/200: Train Loss: 0.2030, Train Acc: 92.97%, Test Loss: 0.2333, Test Acc: 93.25%
# Epoch 108/200: Train Loss: 0.1992, Train Acc: 93.17%, Test Loss: 0.2195, Test Acc: 93.38%
# Epoch 109/200: Train Loss: 0.2014, Train Acc: 93.12%, Test Loss: 0.2349, Test Acc: 93.02%
# Epoch 110/200: Train Loss: 0.2004, Train Acc: 93.21%, Test Loss: 0.2330, Test Acc: 93.29%
# Epoch 111/200: Train Loss: 0.1910, Train Acc: 93.42%, Test Loss: 0.2411, Test Acc: 93.02%
# Epoch 112/200: Train Loss: 0.1953, Train Acc: 93.20%, Test Loss: 0.2417, Test Acc: 93.10%
# Epoch 113/200: Train Loss: 0.1929, Train Acc: 93.45%, Test Loss: 0.2141, Test Acc: 93.76%
# New best model saved with accuracy: 93.76%
# Epoch 114/200: Train Loss: 0.1873, Train Acc: 93.55%, Test Loss: 0.2314, Test Acc: 93.31%
# Epoch 115/200: Train Loss: 0.1907, Train Acc: 93.62%, Test Loss: 0.2163, Test Acc: 93.28%
# Epoch 116/200: Train Loss: 0.1856, Train Acc: 93.69%, Test Loss: 0.2227, Test Acc: 93.53%
# Epoch 117/200: Train Loss: 0.1811, Train Acc: 93.84%, Test Loss: 0.2375, Test Acc: 92.99%
# Epoch 118/200: Train Loss: 0.1839, Train Acc: 93.70%, Test Loss: 0.2171, Test Acc: 93.58%
# Epoch 119/200: Train Loss: 0.1841, Train Acc: 93.61%, Test Loss: 0.2213, Test Acc: 93.66%
# Epoch 120/200: Train Loss: 0.1741, Train Acc: 94.01%, Test Loss: 0.2201, Test Acc: 93.54%
# Epoch 121/200: Train Loss: 0.1723, Train Acc: 94.10%, Test Loss: 0.2096, Test Acc: 93.76%
# Epoch 122/200: Train Loss: 0.1731, Train Acc: 94.04%, Test Loss: 0.2164, Test Acc: 93.89%
# New best model saved with accuracy: 93.89%
# Epoch 123/200: Train Loss: 0.1723, Train Acc: 94.04%, Test Loss: 0.2274, Test Acc: 93.91%
# New best model saved with accuracy: 93.91%
# Epoch 124/200: Train Loss: 0.1715, Train Acc: 94.06%, Test Loss: 0.2223, Test Acc: 93.70%
# Epoch 125/200: Train Loss: 0.1676, Train Acc: 94.20%, Test Loss: 0.2148, Test Acc: 93.96%
# New best model saved with accuracy: 93.96%
# Epoch 126/200: Train Loss: 0.1659, Train Acc: 94.33%, Test Loss: 0.2098, Test Acc: 94.10%
# New best model saved with accuracy: 94.10%
# Epoch 127/200: Train Loss: 0.1598, Train Acc: 94.55%, Test Loss: 0.2177, Test Acc: 93.76%
# Epoch 128/200: Train Loss: 0.1641, Train Acc: 94.42%, Test Loss: 0.2297, Test Acc: 93.56%
# Epoch 129/200: Train Loss: 0.1595, Train Acc: 94.51%, Test Loss: 0.2139, Test Acc: 93.97%
# Epoch 130/200: Train Loss: 0.1549, Train Acc: 94.69%, Test Loss: 0.2298, Test Acc: 93.41%
# Epoch 131/200: Train Loss: 0.1586, Train Acc: 94.59%, Test Loss: 0.2166, Test Acc: 93.70%
# Epoch 132/200: Train Loss: 0.1543, Train Acc: 94.73%, Test Loss: 0.2089, Test Acc: 94.07%
# Epoch 133/200: Train Loss: 0.1532, Train Acc: 94.74%, Test Loss: 0.2175, Test Acc: 93.82%
# Epoch 134/200: Train Loss: 0.1516, Train Acc: 94.90%, Test Loss: 0.2033, Test Acc: 94.31%
# New best model saved with accuracy: 94.31%
# Epoch 135/200: Train Loss: 0.1514, Train Acc: 94.87%, Test Loss: 0.2075, Test Acc: 94.16%
# Epoch 136/200: Train Loss: 0.1452, Train Acc: 95.04%, Test Loss: 0.2138, Test Acc: 94.06%
# Epoch 137/200: Train Loss: 0.1439, Train Acc: 95.07%, Test Loss: 0.2217, Test Acc: 94.08%
# Epoch 138/200: Train Loss: 0.1442, Train Acc: 95.14%, Test Loss: 0.2153, Test Acc: 94.09%
# Epoch 139/200: Train Loss: 0.1425, Train Acc: 95.12%, Test Loss: 0.2110, Test Acc: 93.98%
# Epoch 140/200: Train Loss: 0.1410, Train Acc: 95.18%, Test Loss: 0.2113, Test Acc: 94.21%
# Epoch 141/200: Train Loss: 0.1347, Train Acc: 95.41%, Test Loss: 0.2004, Test Acc: 94.44%
# New best model saved with accuracy: 94.44%
# Epoch 142/200: Train Loss: 0.1356, Train Acc: 95.38%, Test Loss: 0.2023, Test Acc: 94.38%
# Epoch 143/200: Train Loss: 0.1331, Train Acc: 95.40%, Test Loss: 0.2100, Test Acc: 94.27%
# Epoch 144/200: Train Loss: 0.1303, Train Acc: 95.54%, Test Loss: 0.1960, Test Acc: 94.65%
# New best model saved with accuracy: 94.65%
# Epoch 145/200: Train Loss: 0.1317, Train Acc: 95.39%, Test Loss: 0.2092, Test Acc: 94.41%
# Epoch 146/200: Train Loss: 0.1283, Train Acc: 95.60%, Test Loss: 0.1980, Test Acc: 94.43%
# Epoch 147/200: Train Loss: 0.1254, Train Acc: 95.70%, Test Loss: 0.2003, Test Acc: 94.71%
# New best model saved with accuracy: 94.71%
# Epoch 148/200: Train Loss: 0.1254, Train Acc: 95.67%, Test Loss: 0.2026, Test Acc: 94.65%
# Epoch 149/200: Train Loss: 0.1270, Train Acc: 95.69%, Test Loss: 0.1989, Test Acc: 94.69%
# Epoch 150/200: Train Loss: 0.1214, Train Acc: 95.88%, Test Loss: 0.1986, Test Acc: 94.84%
# New best model saved with accuracy: 94.84%
# Epoch 151/200: Train Loss: 0.1227, Train Acc: 95.86%, Test Loss: 0.1963, Test Acc: 94.43%
# Epoch 152/200: Train Loss: 0.1201, Train Acc: 95.92%, Test Loss: 0.2031, Test Acc: 94.57%
# Epoch 153/200: Train Loss: 0.1163, Train Acc: 96.03%, Test Loss: 0.2027, Test Acc: 94.51%
# Epoch 154/200: Train Loss: 0.1155, Train Acc: 96.06%, Test Loss: 0.2004, Test Acc: 94.64%
# Epoch 155/200: Train Loss: 0.1203, Train Acc: 95.88%, Test Loss: 0.1957, Test Acc: 94.62%
# Epoch 156/200: Train Loss: 0.1133, Train Acc: 96.22%, Test Loss: 0.1953, Test Acc: 94.75%
# Epoch 157/200: Train Loss: 0.1161, Train Acc: 96.10%, Test Loss: 0.2007, Test Acc: 94.69%
# Epoch 158/200: Train Loss: 0.1099, Train Acc: 96.24%, Test Loss: 0.1911, Test Acc: 94.63%
# Epoch 159/200: Train Loss: 0.1081, Train Acc: 96.26%, Test Loss: 0.1904, Test Acc: 94.80%
# Epoch 160/200: Train Loss: 0.1060, Train Acc: 96.33%, Test Loss: 0.1924, Test Acc: 94.90%
# New best model saved with accuracy: 94.90%
# Epoch 161/200: Train Loss: 0.1124, Train Acc: 96.20%, Test Loss: 0.2006, Test Acc: 94.81%
# Epoch 162/200: Train Loss: 0.1082, Train Acc: 96.38%, Test Loss: 0.1905, Test Acc: 94.95%
# New best model saved with accuracy: 94.95%
# Epoch 163/200: Train Loss: 0.1051, Train Acc: 96.43%, Test Loss: 0.1960, Test Acc: 94.93%
# Epoch 164/200: Train Loss: 0.1020, Train Acc: 96.52%, Test Loss: 0.1926, Test Acc: 94.70%
# Epoch 165/200: Train Loss: 0.1054, Train Acc: 96.51%, Test Loss: 0.1981, Test Acc: 94.54%
# Epoch 166/200: Train Loss: 0.1020, Train Acc: 96.54%, Test Loss: 0.1954, Test Acc: 94.80%
# Epoch 167/200: Train Loss: 0.1028, Train Acc: 96.56%, Test Loss: 0.1914, Test Acc: 94.89%
# Epoch 168/200: Train Loss: 0.1004, Train Acc: 96.54%, Test Loss: 0.1905, Test Acc: 95.00%
# New best model saved with accuracy: 95.00%
# Epoch 169/200: Train Loss: 0.0995, Train Acc: 96.71%, Test Loss: 0.1885, Test Acc: 95.00%
# Epoch 170/200: Train Loss: 0.1003, Train Acc: 96.61%, Test Loss: 0.1928, Test Acc: 95.01%
# New best model saved with accuracy: 95.01%
# Epoch 171/200: Train Loss: 0.0954, Train Acc: 96.75%, Test Loss: 0.1866, Test Acc: 94.99%
# Epoch 172/200: Train Loss: 0.0965, Train Acc: 96.75%, Test Loss: 0.1890, Test Acc: 95.06%
# New best model saved with accuracy: 95.06%
# Epoch 173/200: Train Loss: 0.0938, Train Acc: 96.85%, Test Loss: 0.1887, Test Acc: 94.95%
# Epoch 174/200: Train Loss: 0.0977, Train Acc: 96.77%, Test Loss: 0.1905, Test Acc: 95.13%
# New best model saved with accuracy: 95.13%
# Epoch 175/200: Train Loss: 0.0906, Train Acc: 96.91%, Test Loss: 0.1929, Test Acc: 95.00%
# Epoch 176/200: Train Loss: 0.0923, Train Acc: 96.87%, Test Loss: 0.1912, Test Acc: 95.04%
# Epoch 177/200: Train Loss: 0.0897, Train Acc: 96.91%, Test Loss: 0.1926, Test Acc: 94.89%
# Epoch 178/200: Train Loss: 0.0954, Train Acc: 96.80%, Test Loss: 0.1905, Test Acc: 95.03%
# Epoch 179/200: Train Loss: 0.0930, Train Acc: 96.88%, Test Loss: 0.1908, Test Acc: 95.01%
# Epoch 180/200: Train Loss: 0.0902, Train Acc: 96.94%, Test Loss: 0.1910, Test Acc: 95.02%
# Epoch 181/200: Train Loss: 0.0896, Train Acc: 96.93%, Test Loss: 0.1900, Test Acc: 95.11%
# Epoch 182/200: Train Loss: 0.0882, Train Acc: 97.05%, Test Loss: 0.1893, Test Acc: 95.11%
# Epoch 183/200: Train Loss: 0.0899, Train Acc: 96.99%, Test Loss: 0.1920, Test Acc: 95.13%
# Epoch 184/200: Train Loss: 0.0841, Train Acc: 97.21%, Test Loss: 0.1915, Test Acc: 95.14%
# New best model saved with accuracy: 95.14%
# Epoch 185/200: Train Loss: 0.0855, Train Acc: 97.08%, Test Loss: 0.1908, Test Acc: 95.12%
# Epoch 186/200: Train Loss: 0.0880, Train Acc: 97.06%, Test Loss: 0.1887, Test Acc: 95.10%
# Epoch 187/200: Train Loss: 0.0887, Train Acc: 97.00%, Test Loss: 0.1882, Test Acc: 95.07%
# Epoch 188/200: Train Loss: 0.0859, Train Acc: 97.12%, Test Loss: 0.1878, Test Acc: 95.15%
# New best model saved with accuracy: 95.15%
# Epoch 189/200: Train Loss: 0.0856, Train Acc: 97.07%, Test Loss: 0.1902, Test Acc: 94.99%
# Epoch 190/200: Train Loss: 0.0891, Train Acc: 97.03%, Test Loss: 0.1899, Test Acc: 95.18%
# New best model saved with accuracy: 95.18%
# Epoch 191/200: Train Loss: 0.0855, Train Acc: 97.08%, Test Loss: 0.1879, Test Acc: 95.16%
# Epoch 192/200: Train Loss: 0.0874, Train Acc: 97.10%, Test Loss: 0.1900, Test Acc: 95.12%
# Epoch 193/200: Train Loss: 0.0858, Train Acc: 97.08%, Test Loss: 0.1900, Test Acc: 95.10%
# Epoch 194/200: Train Loss: 0.0891, Train Acc: 96.99%, Test Loss: 0.1881, Test Acc: 95.23%
# New best model saved with accuracy: 95.23%
# Epoch 195/200: Train Loss: 0.0862, Train Acc: 97.04%, Test Loss: 0.1892, Test Acc: 95.14%
# Epoch 196/200: Train Loss: 0.0851, Train Acc: 97.13%, Test Loss: 0.1876, Test Acc: 95.24%
# New best model saved with accuracy: 95.24%
# Epoch 197/200: Train Loss: 0.0869, Train Acc: 97.12%, Test Loss: 0.1890, Test Acc: 95.14%
# Epoch 198/200: Train Loss: 0.0855, Train Acc: 97.14%, Test Loss: 0.1898, Test Acc: 95.09%
# Epoch 199/200: Train Loss: 0.0852, Train Acc: 97.12%, Test Loss: 0.1897, Test Acc: 95.16%
# Epoch 200/200: Train Loss: 0.0852, Train Acc: 97.13%, Test Loss: 0.1913, Test Acc: 95.20%
# Training completed! Best accuracy: 95.24%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_model3.pth'):
        checkpoint = torch.load('model/best_model3.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 98%
# Accuracy of bird  : 95%
# Accuracy of cat   : 90%
# Accuracy of deer  : 96%
# Accuracy of dog   : 91%
# Accuracy of frog  : 98%
# Accuracy of horse : 96%
# Accuracy of ship  : 96%
# Accuracy of truck : 95%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.96      0.96      0.96      1000
#          car       0.97      0.98      0.98      1000
#         bird       0.94      0.95      0.94      1000
#          cat       0.90      0.91      0.90      1000
#         deer       0.96      0.96      0.96      1000
#          dog       0.91      0.91      0.91      1000
#         frog       0.98      0.98      0.98      1000
#        horse       0.98      0.96      0.97      1000
#         ship       0.97      0.96      0.96      1000
#        truck       0.97      0.95      0.96      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
