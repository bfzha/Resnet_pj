# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    #transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    #transforms.RandomRotation(degrees=15), 
    #transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA1.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 2.0542, Train Acc: 26.50%, Test Loss: 1.6088, Test Acc: 38.96%
# New best model saved with accuracy: 38.96%
# Epoch 2/200: Train Loss: 1.5219, Train Acc: 43.66%, Test Loss: 1.4295, Test Acc: 46.41%
# New best model saved with accuracy: 46.41%
# Epoch 3/200: Train Loss: 1.2845, Train Acc: 53.40%, Test Loss: 1.1676, Test Acc: 58.80%
# New best model saved with accuracy: 58.80%
# Epoch 4/200: Train Loss: 1.0781, Train Acc: 61.64%, Test Loss: 1.2132, Test Acc: 57.86%
# Epoch 5/200: Train Loss: 0.9093, Train Acc: 68.03%, Test Loss: 1.0220, Test Acc: 66.12%
# New best model saved with accuracy: 66.12%
# Epoch 6/200: Train Loss: 0.7680, Train Acc: 72.90%, Test Loss: 0.8733, Test Acc: 70.71%
# New best model saved with accuracy: 70.71%
# Epoch 7/200: Train Loss: 0.6682, Train Acc: 76.66%, Test Loss: 0.6817, Test Acc: 76.48%
# New best model saved with accuracy: 76.48%
# Epoch 8/200: Train Loss: 0.6039, Train Acc: 79.13%, Test Loss: 0.6490, Test Acc: 77.66%
# New best model saved with accuracy: 77.66%
# Epoch 9/200: Train Loss: 0.5635, Train Acc: 80.58%, Test Loss: 0.7109, Test Acc: 75.56%
# Epoch 10/200: Train Loss: 0.5315, Train Acc: 81.54%, Test Loss: 0.6040, Test Acc: 79.74%
# New best model saved with accuracy: 79.74%
# Epoch 11/200: Train Loss: 0.5103, Train Acc: 82.35%, Test Loss: 0.5949, Test Acc: 79.61%
# Epoch 12/200: Train Loss: 0.4876, Train Acc: 83.26%, Test Loss: 0.5985, Test Acc: 80.04%
# New best model saved with accuracy: 80.04%
# Epoch 13/200: Train Loss: 0.4711, Train Acc: 83.81%, Test Loss: 0.7951, Test Acc: 75.35%
# Epoch 14/200: Train Loss: 0.4604, Train Acc: 84.08%, Test Loss: 0.6683, Test Acc: 77.74%
# Epoch 15/200: Train Loss: 0.4499, Train Acc: 84.55%, Test Loss: 0.5035, Test Acc: 83.24%
# New best model saved with accuracy: 83.24%
# Epoch 16/200: Train Loss: 0.4325, Train Acc: 85.18%, Test Loss: 0.6608, Test Acc: 78.37%
# Epoch 17/200: Train Loss: 0.4243, Train Acc: 85.65%, Test Loss: 0.5241, Test Acc: 82.61%
# Epoch 18/200: Train Loss: 0.4185, Train Acc: 85.72%, Test Loss: 0.4957, Test Acc: 83.64%
# New best model saved with accuracy: 83.64%
# Epoch 19/200: Train Loss: 0.4129, Train Acc: 85.78%, Test Loss: 0.4915, Test Acc: 83.61%
# Epoch 20/200: Train Loss: 0.3991, Train Acc: 86.34%, Test Loss: 0.4374, Test Acc: 85.07%
# New best model saved with accuracy: 85.07%
# Epoch 21/200: Train Loss: 0.3937, Train Acc: 86.53%, Test Loss: 0.6250, Test Acc: 79.62%
# Epoch 22/200: Train Loss: 0.3948, Train Acc: 86.39%, Test Loss: 0.5009, Test Acc: 83.22%
# Epoch 23/200: Train Loss: 0.3888, Train Acc: 86.68%, Test Loss: 0.4941, Test Acc: 82.84%
# Epoch 24/200: Train Loss: 0.3812, Train Acc: 87.17%, Test Loss: 0.7081, Test Acc: 76.33%
# Epoch 25/200: Train Loss: 0.3755, Train Acc: 87.01%, Test Loss: 0.5551, Test Acc: 82.41%
# Epoch 26/200: Train Loss: 0.3776, Train Acc: 87.25%, Test Loss: 0.6307, Test Acc: 79.92%
# Epoch 27/200: Train Loss: 0.3712, Train Acc: 87.22%, Test Loss: 0.4606, Test Acc: 84.56%
# Epoch 28/200: Train Loss: 0.3710, Train Acc: 87.25%, Test Loss: 0.4888, Test Acc: 83.72%
# Epoch 29/200: Train Loss: 0.3587, Train Acc: 87.64%, Test Loss: 0.4780, Test Acc: 84.01%
# Epoch 30/200: Train Loss: 0.3627, Train Acc: 87.81%, Test Loss: 0.5570, Test Acc: 82.32%
# Epoch 31/200: Train Loss: 0.3567, Train Acc: 87.69%, Test Loss: 0.6586, Test Acc: 79.57%
# Epoch 32/200: Train Loss: 0.3605, Train Acc: 87.61%, Test Loss: 0.5090, Test Acc: 83.00%
# Epoch 33/200: Train Loss: 0.3506, Train Acc: 88.05%, Test Loss: 0.5327, Test Acc: 82.41%
# Epoch 34/200: Train Loss: 0.3519, Train Acc: 88.10%, Test Loss: 0.4879, Test Acc: 83.52%
# Epoch 35/200: Train Loss: 0.3479, Train Acc: 88.12%, Test Loss: 0.6785, Test Acc: 80.25%
# Epoch 36/200: Train Loss: 0.3531, Train Acc: 87.91%, Test Loss: 0.4991, Test Acc: 83.96%
# Epoch 37/200: Train Loss: 0.3473, Train Acc: 88.19%, Test Loss: 0.4751, Test Acc: 84.39%
# Epoch 38/200: Train Loss: 0.3452, Train Acc: 88.21%, Test Loss: 0.5669, Test Acc: 80.86%
# Epoch 39/200: Train Loss: 0.3455, Train Acc: 88.22%, Test Loss: 0.4067, Test Acc: 86.39%
# New best model saved with accuracy: 86.39%
# Epoch 40/200: Train Loss: 0.3472, Train Acc: 88.12%, Test Loss: 0.4509, Test Acc: 85.14%
# Epoch 41/200: Train Loss: 0.3421, Train Acc: 88.37%, Test Loss: 0.6771, Test Acc: 79.79%
# Epoch 42/200: Train Loss: 0.3411, Train Acc: 88.29%, Test Loss: 0.4131, Test Acc: 86.19%
# Epoch 43/200: Train Loss: 0.3341, Train Acc: 88.62%, Test Loss: 0.5053, Test Acc: 84.05%
# Epoch 44/200: Train Loss: 0.3422, Train Acc: 88.33%, Test Loss: 0.5965, Test Acc: 80.97%
# Epoch 45/200: Train Loss: 0.3380, Train Acc: 88.50%, Test Loss: 0.4747, Test Acc: 84.57%
# Epoch 46/200: Train Loss: 0.3345, Train Acc: 88.58%, Test Loss: 0.5666, Test Acc: 81.65%
# Epoch 47/200: Train Loss: 0.3359, Train Acc: 88.55%, Test Loss: 0.4443, Test Acc: 85.09%
# Epoch 48/200: Train Loss: 0.3288, Train Acc: 89.00%, Test Loss: 0.5217, Test Acc: 82.82%
# Epoch 49/200: Train Loss: 0.3368, Train Acc: 88.56%, Test Loss: 0.5295, Test Acc: 82.98%
# Epoch 50/200: Train Loss: 0.3317, Train Acc: 88.83%, Test Loss: 0.5296, Test Acc: 82.70%
# Epoch 51/200: Train Loss: 0.3281, Train Acc: 88.87%, Test Loss: 0.4615, Test Acc: 84.93%
# Epoch 52/200: Train Loss: 0.3334, Train Acc: 88.59%, Test Loss: 0.5596, Test Acc: 81.82%
# Epoch 53/200: Train Loss: 0.3318, Train Acc: 88.77%, Test Loss: 0.5249, Test Acc: 82.45%
# Epoch 54/200: Train Loss: 0.3256, Train Acc: 89.05%, Test Loss: 0.5011, Test Acc: 83.35%
# Epoch 55/200: Train Loss: 0.3340, Train Acc: 88.76%, Test Loss: 0.4456, Test Acc: 85.20%
# Epoch 56/200: Train Loss: 0.3261, Train Acc: 88.97%, Test Loss: 0.4829, Test Acc: 84.02%
# Epoch 57/200: Train Loss: 0.3288, Train Acc: 88.87%, Test Loss: 0.4896, Test Acc: 83.81%
# Epoch 58/200: Train Loss: 0.3320, Train Acc: 88.56%, Test Loss: 0.6509, Test Acc: 79.93%
# Epoch 59/200: Train Loss: 0.3266, Train Acc: 88.72%, Test Loss: 0.6159, Test Acc: 81.11%
# Epoch 60/200: Train Loss: 0.3235, Train Acc: 88.92%, Test Loss: 0.5245, Test Acc: 82.75%
# Epoch 61/200: Train Loss: 0.3241, Train Acc: 89.05%, Test Loss: 0.5710, Test Acc: 82.21%
# Epoch 62/200: Train Loss: 0.3288, Train Acc: 88.85%, Test Loss: 0.4581, Test Acc: 84.82%
# Epoch 63/200: Train Loss: 0.3250, Train Acc: 88.90%, Test Loss: 0.5184, Test Acc: 83.21%
# Epoch 64/200: Train Loss: 0.3246, Train Acc: 88.91%, Test Loss: 0.4214, Test Acc: 86.13%
# Epoch 65/200: Train Loss: 0.3256, Train Acc: 88.80%, Test Loss: 0.5720, Test Acc: 81.97%
# Epoch 66/200: Train Loss: 0.3223, Train Acc: 89.02%, Test Loss: 0.5217, Test Acc: 83.18%
# Epoch 67/200: Train Loss: 0.3231, Train Acc: 88.79%, Test Loss: 0.4118, Test Acc: 86.09%
# Epoch 68/200: Train Loss: 0.3251, Train Acc: 88.88%, Test Loss: 0.4427, Test Acc: 85.61%
# Epoch 69/200: Train Loss: 0.3202, Train Acc: 89.04%, Test Loss: 0.5961, Test Acc: 81.26%
# Epoch 70/200: Train Loss: 0.3191, Train Acc: 89.28%, Test Loss: 0.5708, Test Acc: 81.92%
# Epoch 71/200: Train Loss: 0.1673, Train Acc: 94.48%, Test Loss: 0.2150, Test Acc: 92.90%
# New best model saved with accuracy: 92.90%
# Epoch 72/200: Train Loss: 0.1228, Train Acc: 95.92%, Test Loss: 0.2031, Test Acc: 93.34%
# New best model saved with accuracy: 93.34%
# Epoch 73/200: Train Loss: 0.1016, Train Acc: 96.69%, Test Loss: 0.1968, Test Acc: 93.45%
# New best model saved with accuracy: 93.45%
# Epoch 74/200: Train Loss: 0.0887, Train Acc: 97.00%, Test Loss: 0.2033, Test Acc: 93.50%
# New best model saved with accuracy: 93.50%
# Epoch 75/200: Train Loss: 0.0804, Train Acc: 97.35%, Test Loss: 0.1950, Test Acc: 93.66%
# New best model saved with accuracy: 93.66%
# Epoch 76/200: Train Loss: 0.0716, Train Acc: 97.67%, Test Loss: 0.1986, Test Acc: 93.61%
# Epoch 77/200: Train Loss: 0.0645, Train Acc: 97.85%, Test Loss: 0.1969, Test Acc: 93.83%
# New best model saved with accuracy: 93.83%
# Epoch 78/200: Train Loss: 0.0579, Train Acc: 98.08%, Test Loss: 0.2025, Test Acc: 93.66%
# Epoch 79/200: Train Loss: 0.0540, Train Acc: 98.23%, Test Loss: 0.2090, Test Acc: 93.66%
# Epoch 80/200: Train Loss: 0.0467, Train Acc: 98.53%, Test Loss: 0.2120, Test Acc: 93.49%
# Epoch 81/200: Train Loss: 0.0444, Train Acc: 98.54%, Test Loss: 0.2125, Test Acc: 93.91%
# New best model saved with accuracy: 93.91%
# Epoch 82/200: Train Loss: 0.0387, Train Acc: 98.73%, Test Loss: 0.2115, Test Acc: 93.91%
# Epoch 83/200: Train Loss: 0.0369, Train Acc: 98.82%, Test Loss: 0.2301, Test Acc: 93.35%
# Epoch 84/200: Train Loss: 0.0364, Train Acc: 98.83%, Test Loss: 0.2456, Test Acc: 93.09%
# Epoch 85/200: Train Loss: 0.0390, Train Acc: 98.72%, Test Loss: 0.2324, Test Acc: 93.24%
# Epoch 86/200: Train Loss: 0.0341, Train Acc: 98.89%, Test Loss: 0.2350, Test Acc: 93.38%
# Epoch 87/200: Train Loss: 0.0331, Train Acc: 98.94%, Test Loss: 0.2286, Test Acc: 93.73%
# Epoch 88/200: Train Loss: 0.0323, Train Acc: 98.97%, Test Loss: 0.2347, Test Acc: 93.47%
# Epoch 89/200: Train Loss: 0.0324, Train Acc: 98.95%, Test Loss: 0.2375, Test Acc: 93.57%
# Epoch 90/200: Train Loss: 0.0321, Train Acc: 99.00%, Test Loss: 0.2224, Test Acc: 93.94%
# New best model saved with accuracy: 93.94%
# Epoch 91/200: Train Loss: 0.0330, Train Acc: 98.94%, Test Loss: 0.2253, Test Acc: 93.82%
# Epoch 92/200: Train Loss: 0.0348, Train Acc: 98.88%, Test Loss: 0.2216, Test Acc: 93.94%
# Epoch 93/200: Train Loss: 0.0336, Train Acc: 98.88%, Test Loss: 0.2191, Test Acc: 93.60%
# Epoch 94/200: Train Loss: 0.0293, Train Acc: 99.11%, Test Loss: 0.2281, Test Acc: 93.78%
# Epoch 95/200: Train Loss: 0.0307, Train Acc: 98.98%, Test Loss: 0.2577, Test Acc: 93.12%
# Epoch 96/200: Train Loss: 0.0359, Train Acc: 98.80%, Test Loss: 0.2396, Test Acc: 93.46%
# Epoch 97/200: Train Loss: 0.0348, Train Acc: 98.87%, Test Loss: 0.2462, Test Acc: 93.19%
# Epoch 98/200: Train Loss: 0.0342, Train Acc: 98.90%, Test Loss: 0.2442, Test Acc: 93.14%
# Epoch 99/200: Train Loss: 0.0379, Train Acc: 98.75%, Test Loss: 0.2418, Test Acc: 93.14%
# Epoch 100/200: Train Loss: 0.0371, Train Acc: 98.78%, Test Loss: 0.2403, Test Acc: 93.59%
# Epoch 101/200: Train Loss: 0.0360, Train Acc: 98.83%, Test Loss: 0.3074, Test Acc: 91.65%
# Epoch 102/200: Train Loss: 0.0387, Train Acc: 98.74%, Test Loss: 0.3040, Test Acc: 91.90%
# Epoch 103/200: Train Loss: 0.0419, Train Acc: 98.60%, Test Loss: 0.2631, Test Acc: 92.67%
# Epoch 104/200: Train Loss: 0.0407, Train Acc: 98.72%, Test Loss: 0.2584, Test Acc: 92.88%
# Epoch 105/200: Train Loss: 0.0418, Train Acc: 98.67%, Test Loss: 0.2540, Test Acc: 93.06%
# Epoch 106/200: Train Loss: 0.0442, Train Acc: 98.53%, Test Loss: 0.2406, Test Acc: 93.08%
# Epoch 107/200: Train Loss: 0.0435, Train Acc: 98.58%, Test Loss: 0.2649, Test Acc: 92.57%
# Epoch 108/200: Train Loss: 0.0434, Train Acc: 98.55%, Test Loss: 0.2634, Test Acc: 92.65%
# Epoch 109/200: Train Loss: 0.0402, Train Acc: 98.69%, Test Loss: 0.2592, Test Acc: 92.98%
# Epoch 110/200: Train Loss: 0.0440, Train Acc: 98.55%, Test Loss: 0.2760, Test Acc: 92.68%
# Epoch 111/200: Train Loss: 0.0446, Train Acc: 98.52%, Test Loss: 0.2642, Test Acc: 92.41%
# Epoch 112/200: Train Loss: 0.0450, Train Acc: 98.52%, Test Loss: 0.2645, Test Acc: 92.66%
# Epoch 113/200: Train Loss: 0.0461, Train Acc: 98.51%, Test Loss: 0.2545, Test Acc: 93.11%
# Epoch 114/200: Train Loss: 0.0436, Train Acc: 98.56%, Test Loss: 0.2612, Test Acc: 92.93%
# Epoch 115/200: Train Loss: 0.0454, Train Acc: 98.59%, Test Loss: 0.2600, Test Acc: 92.90%
# Epoch 116/200: Train Loss: 0.0462, Train Acc: 98.49%, Test Loss: 0.2751, Test Acc: 92.38%
# Epoch 117/200: Train Loss: 0.0446, Train Acc: 98.54%, Test Loss: 0.2850, Test Acc: 91.92%
# Epoch 118/200: Train Loss: 0.0451, Train Acc: 98.51%, Test Loss: 0.2485, Test Acc: 92.87%
# Epoch 119/200: Train Loss: 0.0445, Train Acc: 98.58%, Test Loss: 0.2449, Test Acc: 93.05%
# Epoch 120/200: Train Loss: 0.0489, Train Acc: 98.33%, Test Loss: 0.3026, Test Acc: 92.06%
# Epoch 121/200: Train Loss: 0.0238, Train Acc: 99.30%, Test Loss: 0.2026, Test Acc: 94.27%
# New best model saved with accuracy: 94.27%
# Epoch 122/200: Train Loss: 0.0133, Train Acc: 99.67%, Test Loss: 0.1975, Test Acc: 94.44%
# New best model saved with accuracy: 94.44%
# Epoch 123/200: Train Loss: 0.0101, Train Acc: 99.77%, Test Loss: 0.1943, Test Acc: 94.57%
# New best model saved with accuracy: 94.57%
# Epoch 124/200: Train Loss: 0.0084, Train Acc: 99.83%, Test Loss: 0.1943, Test Acc: 94.73%
# New best model saved with accuracy: 94.73%
# Epoch 125/200: Train Loss: 0.0079, Train Acc: 99.86%, Test Loss: 0.1956, Test Acc: 94.76%
# New best model saved with accuracy: 94.76%
# Epoch 126/200: Train Loss: 0.0069, Train Acc: 99.88%, Test Loss: 0.1955, Test Acc: 94.71%
# Epoch 127/200: Train Loss: 0.0065, Train Acc: 99.90%, Test Loss: 0.1965, Test Acc: 94.70%
# Epoch 128/200: Train Loss: 0.0059, Train Acc: 99.90%, Test Loss: 0.1975, Test Acc: 94.78%
# New best model saved with accuracy: 94.78%
# Epoch 129/200: Train Loss: 0.0053, Train Acc: 99.91%, Test Loss: 0.1987, Test Acc: 94.74%
# Epoch 130/200: Train Loss: 0.0052, Train Acc: 99.92%, Test Loss: 0.1969, Test Acc: 94.75%
# Epoch 131/200: Train Loss: 0.0050, Train Acc: 99.93%, Test Loss: 0.1989, Test Acc: 94.94%
# New best model saved with accuracy: 94.94%
# Epoch 132/200: Train Loss: 0.0043, Train Acc: 99.96%, Test Loss: 0.1951, Test Acc: 94.94%
# Epoch 133/200: Train Loss: 0.0042, Train Acc: 99.95%, Test Loss: 0.1934, Test Acc: 94.98%
# New best model saved with accuracy: 94.98%
# Epoch 134/200: Train Loss: 0.0042, Train Acc: 99.95%, Test Loss: 0.1936, Test Acc: 94.82%
# Epoch 135/200: Train Loss: 0.0039, Train Acc: 99.95%, Test Loss: 0.1954, Test Acc: 94.78%
# Epoch 136/200: Train Loss: 0.0040, Train Acc: 99.95%, Test Loss: 0.1964, Test Acc: 94.78%
# Epoch 137/200: Train Loss: 0.0036, Train Acc: 99.95%, Test Loss: 0.1952, Test Acc: 94.86%
# Epoch 138/200: Train Loss: 0.0037, Train Acc: 99.94%, Test Loss: 0.1973, Test Acc: 94.89%
# Epoch 139/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.1978, Test Acc: 94.89%
# Epoch 140/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.1963, Test Acc: 94.84%
# Epoch 141/200: Train Loss: 0.0033, Train Acc: 99.97%, Test Loss: 0.1959, Test Acc: 94.90%
# Epoch 142/200: Train Loss: 0.0030, Train Acc: 99.98%, Test Loss: 0.1973, Test Acc: 94.93%
# Epoch 143/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.1956, Test Acc: 94.81%
# Epoch 144/200: Train Loss: 0.0032, Train Acc: 99.96%, Test Loss: 0.1949, Test Acc: 94.92%
# Epoch 145/200: Train Loss: 0.0029, Train Acc: 99.97%, Test Loss: 0.1927, Test Acc: 94.91%
# Epoch 146/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1936, Test Acc: 94.98%
# Epoch 147/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.1947, Test Acc: 94.81%
# Epoch 148/200: Train Loss: 0.0029, Train Acc: 99.97%, Test Loss: 0.1936, Test Acc: 94.97%
# Epoch 149/200: Train Loss: 0.0028, Train Acc: 99.97%, Test Loss: 0.1935, Test Acc: 94.95%
# Epoch 150/200: Train Loss: 0.0029, Train Acc: 99.98%, Test Loss: 0.1912, Test Acc: 94.98%
# Epoch 151/200: Train Loss: 0.0027, Train Acc: 99.98%, Test Loss: 0.1923, Test Acc: 94.95%
# Epoch 152/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1929, Test Acc: 95.03%
# New best model saved with accuracy: 95.03%
# Epoch 153/200: Train Loss: 0.0028, Train Acc: 99.98%, Test Loss: 0.1931, Test Acc: 95.12%
# New best model saved with accuracy: 95.12%
# Epoch 154/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1923, Test Acc: 95.02%
# Epoch 155/200: Train Loss: 0.0027, Train Acc: 99.98%, Test Loss: 0.1924, Test Acc: 95.00%
# Epoch 156/200: Train Loss: 0.0026, Train Acc: 99.97%, Test Loss: 0.1920, Test Acc: 95.05%
# Epoch 157/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1919, Test Acc: 95.03%
# Epoch 158/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1926, Test Acc: 95.07%
# Epoch 159/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1928, Test Acc: 95.09%
# Epoch 160/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1905, Test Acc: 95.05%
# Epoch 161/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1919, Test Acc: 94.97%
# Epoch 162/200: Train Loss: 0.0026, Train Acc: 99.97%, Test Loss: 0.1919, Test Acc: 95.08%
# Epoch 163/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1892, Test Acc: 95.10%
# Epoch 164/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1911, Test Acc: 95.13%
# New best model saved with accuracy: 95.13%
# Epoch 165/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1912, Test Acc: 94.99%
# Epoch 166/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1917, Test Acc: 95.07%
# Epoch 167/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1913, Test Acc: 95.06%
# Epoch 168/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1917, Test Acc: 95.04%
# Epoch 169/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1906, Test Acc: 95.05%
# Epoch 170/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1905, Test Acc: 95.00%
# Epoch 171/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1910, Test Acc: 95.08%
# Epoch 172/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1903, Test Acc: 95.13%
# Epoch 173/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1907, Test Acc: 95.11%
# Epoch 174/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1911, Test Acc: 95.00%
# Epoch 175/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1911, Test Acc: 95.10%
# Epoch 176/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1907, Test Acc: 95.08%
# Epoch 177/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1920, Test Acc: 95.08%
# Epoch 178/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1910, Test Acc: 95.03%
# Epoch 179/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1912, Test Acc: 95.13%
# Epoch 180/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1915, Test Acc: 95.04%
# Epoch 181/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1904, Test Acc: 95.06%
# Epoch 182/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1909, Test Acc: 95.05%
# Epoch 183/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1906, Test Acc: 95.04%
# Epoch 184/200: Train Loss: 0.0022, Train Acc: 99.98%, Test Loss: 0.1899, Test Acc: 95.00%
# Epoch 185/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1910, Test Acc: 95.01%
# Epoch 186/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1914, Test Acc: 94.96%
# Epoch 187/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1906, Test Acc: 95.02%
# Epoch 188/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1906, Test Acc: 95.00%
# Epoch 189/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1914, Test Acc: 94.97%
# Epoch 190/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1916, Test Acc: 95.01%
# Epoch 191/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1893, Test Acc: 95.11%
# Epoch 192/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1921, Test Acc: 95.00%
# Epoch 193/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1909, Test Acc: 95.15%
# New best model saved with accuracy: 95.15%
# Epoch 194/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1914, Test Acc: 95.10%
# Epoch 195/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1902, Test Acc: 95.07%
# Epoch 196/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1916, Test Acc: 95.09%
# Epoch 197/200: Train Loss: 0.0021, Train Acc: 99.98%, Test Loss: 0.1943, Test Acc: 95.12%
# Epoch 198/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1909, Test Acc: 95.02%
# Epoch 199/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1892, Test Acc: 94.99%
# Epoch 200/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1904, Test Acc: 94.89%
# Training completed! Best accuracy: 95.15%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA1.pth'):
        checkpoint = torch.load('model/best_modelA1.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 90%
# Accuracy of car   : 93%
# Accuracy of bird  : 72%
# Accuracy of cat   : 74%
# Accuracy of deer  : 90%
# Accuracy of dog   : 77%
# Accuracy of frog  : 90%
# Accuracy of horse : 96%
# Accuracy of ship  : 90%
# Accuracy of truck : 95%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.85      0.90      0.88      1000
#          car       0.96      0.93      0.95      1000
#         bird       0.90      0.72      0.80      1000
#          cat       0.79      0.74      0.76      1000
#         deer       0.79      0.90      0.84      1000
#          dog       0.86      0.77      0.81      1000
#         frog       0.88      0.91      0.89      1000
#        horse       0.81      0.96      0.88      1000
#         ship       0.96      0.90      0.93      1000
#        truck       0.89      0.95      0.92      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
# === ROC曲线 ===
