# %%
# 导入必要的库
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import datetime
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchsummary import summary

# %%
# 设置超参数
BATCH_SIZE = 128
NUM_CLASSES = 10    
LR = 0.1 # for SGD optimizer
# LR = 3e-4 # for Adam optimizer
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
EPOCHS = 200      
# 随机种子,本次不用
# SEED = 42

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
writer = SummaryWriter(f'runs/CIFAR10_exp1_{timestamp}')

# %%
MEAN = [0.4914, 0.4822, 0.4465]
STD  = [0.2470, 0.2435, 0.2616]

# CIFAR-10类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # 以0.5的概率水平翻转图像，增加数据多样性
    transforms.RandomCrop(32, padding=4), # 32x32的图像，填充4个像素后再裁剪回32x32 模拟图像小范围位移，提高平移不变性

    #transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    #transforms.RandomRotation(degrees=15), 
    #transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 

    transforms.ToTensor(), 
    transforms.Normalize(MEAN, STD), 
    
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value='random') 
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

train_dataset = datasets.CIFAR10(root='./datasets', train=True, transform=train_transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True,num_workers=12)

test_dataset = datasets.CIFAR10(root='./datasets', train=False, transform=test_transform, download=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False,num_workers=12)

# %%
# 定义残差块 较低深度的ResNet使用BasicBlock
class BasicBlock(nn.Module):
    expansion = 1 

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %%
# 2.定义ResNet-18模型
class ResNet18(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet18, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) # 3x32x32 → 64x32x32
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2) # 64x32x32 → 128x16x16
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2) # 128x16x16 → 256x8x8
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2) # 256x8x8 → 512x4x4
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x))) # 3×32×32 → 64×32×32
        x = self.layer1(x) # 64×32×32 → 64×32×32
        x = self.layer2(x) # 64×32×32 → 128×16×16
        x = self.layer3(x) # 128×16×16 → 256×8×8
        x = self.layer4(x) # 256×8×8 → 512×4×4
        x = F.avg_pool2d(x, 4) 
        x = x.view(x.size(0), -1) 
        x = self.linear(x)
        return x
    
model = ResNet18(BasicBlock, [2, 2, 2, 2], NUM_CLASSES).to(DEVICE) # 每层的残差块数量（2+2+2+2=8个块 × 2层/块 = 16个卷积层 + 1个初始卷积 = 17层）

# 输入尺寸为 (C, H, W) = (3, 32, 32)
# 输出参数量
print("\n模型结构概览：")
#summary(model, input_size=(3, 32, 32))
# Out:
# 模型结构概览：

# %%
#3.定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# adam
# optimizer = optim.Adam(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)

# 学习率调度器 200轮 学习率衰减
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[70, 120, 160], gamma=0.1)

# 余弦退火学习率调度器 
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# %%
def train(epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for batch_idx, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    return train_loss, train_acc

# %%
# 5.测试模型
def test(epoch):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    
    return test_loss, test_acc

# %%
# 6.绘图
def plot(train_loss, test_accuracy):
    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracy, 'r', label='Test Accuracy')
    plt.title('Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
# 7.训练模型
if __name__ == '__main__':
    os.makedirs('model', exist_ok=True)
    best_accuracy = 0.0

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):  
        train_loss, train_acc = train(epoch)
        test_loss, test_acc = test(epoch)
        scheduler.step() # 更新学习率
        
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        writer.add_scalars('Accuracy', {
            'Train': train_acc,
            'Test': test_acc
        }, epoch)
        
        writer.add_scalars('Loss', {
            'Train': train_loss,
            'Test': test_loss
        }, epoch)
        
        print(f'Epoch {epoch+1}/{EPOCHS}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
        
        if test_acc > best_accuracy:
            best_accuracy = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': test_acc
            }, f'model/best_modelA1.pth')
            print(f'New best model saved with accuracy: {test_acc:.2f}%')

    writer.close()
    plot(train_losses, test_accuracies)
    print(f'Training completed! Best accuracy: {best_accuracy:.2f}%')
# Out:
# Epoch 1/200: Train Loss: 1.7981, Train Acc: 35.13%, Test Loss: 1.4767, Test Acc: 45.76%
# New best model saved with accuracy: 45.76%
# Epoch 2/200: Train Loss: 1.3031, Train Acc: 52.65%, Test Loss: 1.2277, Test Acc: 56.60%
# New best model saved with accuracy: 56.60%
# Epoch 3/200: Train Loss: 1.0447, Train Acc: 63.03%, Test Loss: 1.0424, Test Acc: 61.96%
# New best model saved with accuracy: 61.96%
# Epoch 4/200: Train Loss: 0.8762, Train Acc: 69.05%, Test Loss: 0.8015, Test Acc: 72.03%
# New best model saved with accuracy: 72.03%
# Epoch 5/200: Train Loss: 0.7363, Train Acc: 74.24%, Test Loss: 0.9721, Test Acc: 68.50%
# Epoch 6/200: Train Loss: 0.6448, Train Acc: 77.72%, Test Loss: 0.6875, Test Acc: 76.42%
# New best model saved with accuracy: 76.42%
# Epoch 7/200: Train Loss: 0.5828, Train Acc: 79.85%, Test Loss: 0.9630, Test Acc: 68.19%
# Epoch 8/200: Train Loss: 0.5421, Train Acc: 81.23%, Test Loss: 0.6281, Test Acc: 78.51%
# New best model saved with accuracy: 78.51%
# Epoch 9/200: Train Loss: 0.5124, Train Acc: 82.40%, Test Loss: 0.6692, Test Acc: 78.33%
# Epoch 10/200: Train Loss: 0.4906, Train Acc: 83.22%, Test Loss: 0.7161, Test Acc: 76.84%
# Epoch 11/200: Train Loss: 0.4717, Train Acc: 83.72%, Test Loss: 0.5407, Test Acc: 82.08%
# New best model saved with accuracy: 82.08%
# Epoch 12/200: Train Loss: 0.4624, Train Acc: 84.12%, Test Loss: 0.5381, Test Acc: 81.73%
# Epoch 13/200: Train Loss: 0.4418, Train Acc: 84.76%, Test Loss: 0.8364, Test Acc: 74.25%
# Epoch 14/200: Train Loss: 0.4353, Train Acc: 85.15%, Test Loss: 0.6378, Test Acc: 79.26%
# Epoch 15/200: Train Loss: 0.4241, Train Acc: 85.52%, Test Loss: 0.6663, Test Acc: 78.79%
# Epoch 16/200: Train Loss: 0.4112, Train Acc: 86.07%, Test Loss: 0.6828, Test Acc: 78.02%
# Epoch 17/200: Train Loss: 0.4048, Train Acc: 86.12%, Test Loss: 0.4868, Test Acc: 83.21%
# New best model saved with accuracy: 83.21%
# Epoch 18/200: Train Loss: 0.3980, Train Acc: 86.38%, Test Loss: 0.7032, Test Acc: 77.59%
# Epoch 19/200: Train Loss: 0.3903, Train Acc: 86.78%, Test Loss: 0.4569, Test Acc: 85.17%
# New best model saved with accuracy: 85.17%
# Epoch 20/200: Train Loss: 0.3867, Train Acc: 86.73%, Test Loss: 0.8354, Test Acc: 75.60%
# Epoch 21/200: Train Loss: 0.3841, Train Acc: 86.71%, Test Loss: 0.4824, Test Acc: 83.78%
# Epoch 22/200: Train Loss: 0.3706, Train Acc: 87.23%, Test Loss: 0.4558, Test Acc: 84.82%
# Epoch 23/200: Train Loss: 0.3736, Train Acc: 87.23%, Test Loss: 0.4837, Test Acc: 83.36%
# Epoch 24/200: Train Loss: 0.3699, Train Acc: 87.39%, Test Loss: 0.4682, Test Acc: 84.59%
# Epoch 25/200: Train Loss: 0.3661, Train Acc: 87.48%, Test Loss: 0.4931, Test Acc: 83.52%
# Epoch 26/200: Train Loss: 0.3631, Train Acc: 87.61%, Test Loss: 0.4749, Test Acc: 84.50%
# Epoch 27/200: Train Loss: 0.3581, Train Acc: 87.76%, Test Loss: 0.4710, Test Acc: 84.26%
# Epoch 28/200: Train Loss: 0.3519, Train Acc: 87.97%, Test Loss: 0.5799, Test Acc: 81.91%
# Epoch 29/200: Train Loss: 0.3480, Train Acc: 88.10%, Test Loss: 0.5050, Test Acc: 83.73%
# Epoch 30/200: Train Loss: 0.3483, Train Acc: 88.14%, Test Loss: 0.6183, Test Acc: 79.64%
# Epoch 31/200: Train Loss: 0.3476, Train Acc: 88.34%, Test Loss: 0.5509, Test Acc: 81.75%
# Epoch 32/200: Train Loss: 0.3507, Train Acc: 88.18%, Test Loss: 0.5140, Test Acc: 83.88%
# Epoch 33/200: Train Loss: 0.3455, Train Acc: 88.19%, Test Loss: 0.6373, Test Acc: 80.41%
# Epoch 34/200: Train Loss: 0.3413, Train Acc: 88.46%, Test Loss: 0.5170, Test Acc: 83.31%
# Epoch 35/200: Train Loss: 0.3429, Train Acc: 88.20%, Test Loss: 0.5168, Test Acc: 82.85%
# Epoch 36/200: Train Loss: 0.3409, Train Acc: 88.22%, Test Loss: 0.5986, Test Acc: 81.03%
# Epoch 37/200: Train Loss: 0.3392, Train Acc: 88.51%, Test Loss: 0.5594, Test Acc: 82.06%
# Epoch 38/200: Train Loss: 0.3385, Train Acc: 88.47%, Test Loss: 0.5114, Test Acc: 82.91%
# Epoch 39/200: Train Loss: 0.3405, Train Acc: 88.48%, Test Loss: 0.6088, Test Acc: 79.89%
# Epoch 40/200: Train Loss: 0.3377, Train Acc: 88.53%, Test Loss: 0.5586, Test Acc: 82.45%
# Epoch 41/200: Train Loss: 0.3310, Train Acc: 88.74%, Test Loss: 0.4529, Test Acc: 85.08%
# Epoch 42/200: Train Loss: 0.3271, Train Acc: 88.97%, Test Loss: 0.5078, Test Acc: 83.06%
# Epoch 43/200: Train Loss: 0.3323, Train Acc: 88.68%, Test Loss: 0.4948, Test Acc: 83.54%
# Epoch 44/200: Train Loss: 0.3301, Train Acc: 88.76%, Test Loss: 0.4894, Test Acc: 83.69%
# Epoch 45/200: Train Loss: 0.3348, Train Acc: 88.67%, Test Loss: 0.4580, Test Acc: 84.89%
# Epoch 46/200: Train Loss: 0.3271, Train Acc: 88.95%, Test Loss: 0.5624, Test Acc: 81.84%
# Epoch 47/200: Train Loss: 0.3287, Train Acc: 88.83%, Test Loss: 0.4305, Test Acc: 85.28%
# New best model saved with accuracy: 85.28%
# Epoch 48/200: Train Loss: 0.3253, Train Acc: 88.93%, Test Loss: 0.4775, Test Acc: 84.59%
# Epoch 49/200: Train Loss: 0.3253, Train Acc: 88.90%, Test Loss: 0.5975, Test Acc: 80.97%
# Epoch 50/200: Train Loss: 0.3230, Train Acc: 89.01%, Test Loss: 0.5915, Test Acc: 81.04%
# Epoch 51/200: Train Loss: 0.3291, Train Acc: 88.81%, Test Loss: 0.5961, Test Acc: 81.48%
# Epoch 52/200: Train Loss: 0.3256, Train Acc: 88.87%, Test Loss: 0.4999, Test Acc: 83.26%
# Epoch 53/200: Train Loss: 0.3221, Train Acc: 88.98%, Test Loss: 0.6374, Test Acc: 80.20%
# Epoch 54/200: Train Loss: 0.3257, Train Acc: 88.86%, Test Loss: 0.4174, Test Acc: 86.21%
# New best model saved with accuracy: 86.21%
# Epoch 55/200: Train Loss: 0.3193, Train Acc: 89.04%, Test Loss: 0.5043, Test Acc: 83.35%
# Epoch 56/200: Train Loss: 0.3258, Train Acc: 88.78%, Test Loss: 0.4428, Test Acc: 85.83%
# Epoch 57/200: Train Loss: 0.3228, Train Acc: 88.96%, Test Loss: 0.4911, Test Acc: 83.83%
# Epoch 58/200: Train Loss: 0.3181, Train Acc: 89.16%, Test Loss: 0.6106, Test Acc: 81.39%
# Epoch 59/200: Train Loss: 0.3175, Train Acc: 89.14%, Test Loss: 0.4765, Test Acc: 84.71%
# Epoch 60/200: Train Loss: 0.3202, Train Acc: 89.06%, Test Loss: 0.5820, Test Acc: 81.31%
# Epoch 61/200: Train Loss: 0.3207, Train Acc: 89.01%, Test Loss: 0.5537, Test Acc: 82.73%
# Epoch 62/200: Train Loss: 0.3239, Train Acc: 89.18%, Test Loss: 0.4555, Test Acc: 84.99%
# Epoch 63/200: Train Loss: 0.3152, Train Acc: 89.33%, Test Loss: 0.4047, Test Acc: 86.53%
# New best model saved with accuracy: 86.53%
# Epoch 64/200: Train Loss: 0.3161, Train Acc: 89.38%, Test Loss: 0.5483, Test Acc: 82.18%
# Epoch 65/200: Train Loss: 0.3214, Train Acc: 88.96%, Test Loss: 0.4952, Test Acc: 84.08%
# Epoch 66/200: Train Loss: 0.3115, Train Acc: 89.43%, Test Loss: 0.5836, Test Acc: 79.83%
# Epoch 67/200: Train Loss: 0.3211, Train Acc: 89.00%, Test Loss: 0.5498, Test Acc: 83.03%
# Epoch 68/200: Train Loss: 0.3197, Train Acc: 89.13%, Test Loss: 0.3892, Test Acc: 87.23%
# New best model saved with accuracy: 87.23%
# Epoch 69/200: Train Loss: 0.3161, Train Acc: 89.27%, Test Loss: 0.4622, Test Acc: 84.57%
# Epoch 70/200: Train Loss: 0.3129, Train Acc: 89.38%, Test Loss: 0.5602, Test Acc: 81.22%
# Epoch 71/200: Train Loss: 0.1667, Train Acc: 94.47%, Test Loss: 0.2111, Test Acc: 92.90%
# New best model saved with accuracy: 92.90%
# Epoch 72/200: Train Loss: 0.1192, Train Acc: 96.06%, Test Loss: 0.1972, Test Acc: 93.36%
# New best model saved with accuracy: 93.36%
# Epoch 73/200: Train Loss: 0.1013, Train Acc: 96.60%, Test Loss: 0.1900, Test Acc: 93.67%
# New best model saved with accuracy: 93.67%
# Epoch 74/200: Train Loss: 0.0867, Train Acc: 97.04%, Test Loss: 0.1954, Test Acc: 93.73%
# New best model saved with accuracy: 93.73%
# Epoch 75/200: Train Loss: 0.0772, Train Acc: 97.42%, Test Loss: 0.1952, Test Acc: 93.75%
# New best model saved with accuracy: 93.75%
# Epoch 76/200: Train Loss: 0.0658, Train Acc: 97.83%, Test Loss: 0.1904, Test Acc: 93.93%
# New best model saved with accuracy: 93.93%
# Epoch 77/200: Train Loss: 0.0595, Train Acc: 98.06%, Test Loss: 0.2059, Test Acc: 93.99%
# New best model saved with accuracy: 93.99%
# Epoch 78/200: Train Loss: 0.0544, Train Acc: 98.27%, Test Loss: 0.2049, Test Acc: 93.86%
# Epoch 79/200: Train Loss: 0.0487, Train Acc: 98.44%, Test Loss: 0.2039, Test Acc: 94.02%
# New best model saved with accuracy: 94.02%
# Epoch 80/200: Train Loss: 0.0481, Train Acc: 98.46%, Test Loss: 0.2056, Test Acc: 94.10%
# New best model saved with accuracy: 94.10%
# Epoch 81/200: Train Loss: 0.0420, Train Acc: 98.62%, Test Loss: 0.2066, Test Acc: 94.10%
# Epoch 82/200: Train Loss: 0.0422, Train Acc: 98.59%, Test Loss: 0.2200, Test Acc: 93.65%
# Epoch 83/200: Train Loss: 0.0384, Train Acc: 98.69%, Test Loss: 0.2211, Test Acc: 93.80%
# Epoch 84/200: Train Loss: 0.0389, Train Acc: 98.71%, Test Loss: 0.2133, Test Acc: 93.78%
# Epoch 85/200: Train Loss: 0.0357, Train Acc: 98.85%, Test Loss: 0.2281, Test Acc: 93.80%
# Epoch 86/200: Train Loss: 0.0347, Train Acc: 98.87%, Test Loss: 0.2290, Test Acc: 93.74%
# Epoch 87/200: Train Loss: 0.0313, Train Acc: 99.02%, Test Loss: 0.2329, Test Acc: 93.71%
# Epoch 88/200: Train Loss: 0.0317, Train Acc: 98.96%, Test Loss: 0.2311, Test Acc: 93.73%
# Epoch 89/200: Train Loss: 0.0335, Train Acc: 98.86%, Test Loss: 0.2383, Test Acc: 93.56%
# Epoch 90/200: Train Loss: 0.0331, Train Acc: 98.88%, Test Loss: 0.2213, Test Acc: 93.81%
# Epoch 91/200: Train Loss: 0.0333, Train Acc: 98.96%, Test Loss: 0.2344, Test Acc: 93.71%
# Epoch 92/200: Train Loss: 0.0326, Train Acc: 98.93%, Test Loss: 0.2321, Test Acc: 93.63%
# Epoch 93/200: Train Loss: 0.0311, Train Acc: 99.04%, Test Loss: 0.2355, Test Acc: 93.87%
# Epoch 94/200: Train Loss: 0.0332, Train Acc: 98.92%, Test Loss: 0.2246, Test Acc: 94.15%
# New best model saved with accuracy: 94.15%
# Epoch 95/200: Train Loss: 0.0325, Train Acc: 98.95%, Test Loss: 0.2372, Test Acc: 93.68%
# Epoch 96/200: Train Loss: 0.0328, Train Acc: 98.95%, Test Loss: 0.2344, Test Acc: 93.69%
# Epoch 97/200: Train Loss: 0.0356, Train Acc: 98.86%, Test Loss: 0.2511, Test Acc: 93.25%
# Epoch 98/200: Train Loss: 0.0376, Train Acc: 98.75%, Test Loss: 0.2439, Test Acc: 93.32%
# Epoch 99/200: Train Loss: 0.0404, Train Acc: 98.64%, Test Loss: 0.2575, Test Acc: 93.13%
# Epoch 100/200: Train Loss: 0.0405, Train Acc: 98.72%, Test Loss: 0.2399, Test Acc: 93.37%
# Epoch 101/200: Train Loss: 0.0401, Train Acc: 98.69%, Test Loss: 0.2421, Test Acc: 93.45%
# Epoch 102/200: Train Loss: 0.0389, Train Acc: 98.71%, Test Loss: 0.2362, Test Acc: 93.24%
# Epoch 103/200: Train Loss: 0.0372, Train Acc: 98.76%, Test Loss: 0.2652, Test Acc: 93.07%
# Epoch 104/200: Train Loss: 0.0403, Train Acc: 98.68%, Test Loss: 0.2566, Test Acc: 93.26%
# Epoch 105/200: Train Loss: 0.0442, Train Acc: 98.57%, Test Loss: 0.2477, Test Acc: 93.09%
# Epoch 106/200: Train Loss: 0.0455, Train Acc: 98.50%, Test Loss: 0.2365, Test Acc: 93.37%
# Epoch 107/200: Train Loss: 0.0392, Train Acc: 98.69%, Test Loss: 0.2385, Test Acc: 93.32%
# Epoch 108/200: Train Loss: 0.0418, Train Acc: 98.66%, Test Loss: 0.2615, Test Acc: 92.69%
# Epoch 109/200: Train Loss: 0.0443, Train Acc: 98.49%, Test Loss: 0.2503, Test Acc: 92.85%
# Epoch 110/200: Train Loss: 0.0462, Train Acc: 98.43%, Test Loss: 0.2745, Test Acc: 92.80%
# Epoch 111/200: Train Loss: 0.0449, Train Acc: 98.47%, Test Loss: 0.2702, Test Acc: 92.45%
# Epoch 112/200: Train Loss: 0.0458, Train Acc: 98.47%, Test Loss: 0.2686, Test Acc: 92.40%
# Epoch 113/200: Train Loss: 0.0463, Train Acc: 98.46%, Test Loss: 0.2635, Test Acc: 92.56%
# Epoch 114/200: Train Loss: 0.0428, Train Acc: 98.61%, Test Loss: 0.2383, Test Acc: 93.50%
# Epoch 115/200: Train Loss: 0.0488, Train Acc: 98.39%, Test Loss: 0.2472, Test Acc: 93.26%
# Epoch 116/200: Train Loss: 0.0434, Train Acc: 98.54%, Test Loss: 0.2509, Test Acc: 92.95%
# Epoch 117/200: Train Loss: 0.0505, Train Acc: 98.30%, Test Loss: 0.2798, Test Acc: 92.39%
# Epoch 118/200: Train Loss: 0.0500, Train Acc: 98.33%, Test Loss: 0.2492, Test Acc: 93.02%
# Epoch 119/200: Train Loss: 0.0499, Train Acc: 98.34%, Test Loss: 0.2911, Test Acc: 92.26%
# Epoch 120/200: Train Loss: 0.0504, Train Acc: 98.32%, Test Loss: 0.2406, Test Acc: 92.88%
# Epoch 121/200: Train Loss: 0.0221, Train Acc: 99.37%, Test Loss: 0.1936, Test Acc: 94.35%
# New best model saved with accuracy: 94.35%
# Epoch 122/200: Train Loss: 0.0143, Train Acc: 99.62%, Test Loss: 0.1908, Test Acc: 94.50%
# New best model saved with accuracy: 94.50%
# Epoch 123/200: Train Loss: 0.0109, Train Acc: 99.74%, Test Loss: 0.1910, Test Acc: 94.58%
# New best model saved with accuracy: 94.58%
# Epoch 124/200: Train Loss: 0.0086, Train Acc: 99.86%, Test Loss: 0.1943, Test Acc: 94.66%
# New best model saved with accuracy: 94.66%
# Epoch 125/200: Train Loss: 0.0076, Train Acc: 99.86%, Test Loss: 0.1923, Test Acc: 94.68%
# New best model saved with accuracy: 94.68%
# Epoch 126/200: Train Loss: 0.0067, Train Acc: 99.89%, Test Loss: 0.1928, Test Acc: 94.72%
# New best model saved with accuracy: 94.72%
# Epoch 127/200: Train Loss: 0.0065, Train Acc: 99.87%, Test Loss: 0.1912, Test Acc: 94.79%
# New best model saved with accuracy: 94.79%
# Epoch 128/200: Train Loss: 0.0058, Train Acc: 99.91%, Test Loss: 0.1920, Test Acc: 94.83%
# New best model saved with accuracy: 94.83%
# Epoch 129/200: Train Loss: 0.0057, Train Acc: 99.90%, Test Loss: 0.1920, Test Acc: 94.82%
# Epoch 130/200: Train Loss: 0.0051, Train Acc: 99.92%, Test Loss: 0.1927, Test Acc: 94.91%
# New best model saved with accuracy: 94.91%
# Epoch 131/200: Train Loss: 0.0051, Train Acc: 99.91%, Test Loss: 0.1913, Test Acc: 94.98%
# New best model saved with accuracy: 94.98%
# Epoch 132/200: Train Loss: 0.0046, Train Acc: 99.94%, Test Loss: 0.1929, Test Acc: 94.98%
# Epoch 133/200: Train Loss: 0.0042, Train Acc: 99.95%, Test Loss: 0.1912, Test Acc: 94.95%
# Epoch 134/200: Train Loss: 0.0042, Train Acc: 99.95%, Test Loss: 0.1907, Test Acc: 95.01%
# New best model saved with accuracy: 95.01%
# Epoch 135/200: Train Loss: 0.0041, Train Acc: 99.95%, Test Loss: 0.1940, Test Acc: 94.97%
# Epoch 136/200: Train Loss: 0.0039, Train Acc: 99.96%, Test Loss: 0.1949, Test Acc: 94.91%
# Epoch 137/200: Train Loss: 0.0039, Train Acc: 99.94%, Test Loss: 0.1922, Test Acc: 94.95%
# Epoch 138/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1903, Test Acc: 94.99%
# Epoch 139/200: Train Loss: 0.0036, Train Acc: 99.96%, Test Loss: 0.1903, Test Acc: 94.97%
# Epoch 140/200: Train Loss: 0.0037, Train Acc: 99.95%, Test Loss: 0.1907, Test Acc: 94.94%
# Epoch 141/200: Train Loss: 0.0034, Train Acc: 99.97%, Test Loss: 0.1886, Test Acc: 95.04%
# New best model saved with accuracy: 95.04%
# Epoch 142/200: Train Loss: 0.0033, Train Acc: 99.97%, Test Loss: 0.1888, Test Acc: 94.97%
# Epoch 143/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.1880, Test Acc: 95.06%
# New best model saved with accuracy: 95.06%
# Epoch 144/200: Train Loss: 0.0033, Train Acc: 99.96%, Test Loss: 0.1905, Test Acc: 95.03%
# Epoch 145/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1915, Test Acc: 94.98%
# Epoch 146/200: Train Loss: 0.0029, Train Acc: 99.97%, Test Loss: 0.1896, Test Acc: 95.00%
# Epoch 147/200: Train Loss: 0.0027, Train Acc: 99.98%, Test Loss: 0.1893, Test Acc: 94.91%
# Epoch 148/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1906, Test Acc: 94.98%
# Epoch 149/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1898, Test Acc: 94.80%
# Epoch 150/200: Train Loss: 0.0031, Train Acc: 99.97%, Test Loss: 0.1896, Test Acc: 95.04%
# Epoch 151/200: Train Loss: 0.0028, Train Acc: 99.97%, Test Loss: 0.1892, Test Acc: 95.11%
# New best model saved with accuracy: 95.11%
# Epoch 152/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1894, Test Acc: 95.10%
# Epoch 153/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1893, Test Acc: 95.11%
# Epoch 154/200: Train Loss: 0.0030, Train Acc: 99.97%, Test Loss: 0.1897, Test Acc: 95.06%
# Epoch 155/200: Train Loss: 0.0026, Train Acc: 99.97%, Test Loss: 0.1902, Test Acc: 95.13%
# New best model saved with accuracy: 95.13%
# Epoch 156/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1889, Test Acc: 95.27%
# New best model saved with accuracy: 95.27%
# Epoch 157/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1891, Test Acc: 95.00%
# Epoch 158/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1880, Test Acc: 95.05%
# Epoch 159/200: Train Loss: 0.0026, Train Acc: 99.98%, Test Loss: 0.1870, Test Acc: 95.10%
# Epoch 160/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1875, Test Acc: 95.11%
# Epoch 161/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1877, Test Acc: 95.18%
# Epoch 162/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1900, Test Acc: 95.02%
# Epoch 163/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1877, Test Acc: 95.03%
# Epoch 164/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1886, Test Acc: 94.97%
# Epoch 165/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1892, Test Acc: 95.09%
# Epoch 166/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1872, Test Acc: 95.02%
# Epoch 167/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1892, Test Acc: 95.00%
# Epoch 168/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1863, Test Acc: 95.21%
# Epoch 169/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1887, Test Acc: 95.07%
# Epoch 170/200: Train Loss: 0.0022, Train Acc: 99.98%, Test Loss: 0.1878, Test Acc: 95.06%
# Epoch 171/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1893, Test Acc: 94.99%
# Epoch 172/200: Train Loss: 0.0025, Train Acc: 99.98%, Test Loss: 0.1880, Test Acc: 94.98%
# Epoch 173/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1882, Test Acc: 95.08%
# Epoch 174/200: Train Loss: 0.0024, Train Acc: 99.99%, Test Loss: 0.1910, Test Acc: 95.01%
# Epoch 175/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1867, Test Acc: 95.11%
# Epoch 176/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1875, Test Acc: 95.13%
# Epoch 177/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1876, Test Acc: 95.09%
# Epoch 178/200: Train Loss: 0.0021, Train Acc: 100.00%, Test Loss: 0.1862, Test Acc: 95.17%
# Epoch 179/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1863, Test Acc: 95.14%
# Epoch 180/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1877, Test Acc: 95.08%
# Epoch 181/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1876, Test Acc: 95.10%
# Epoch 182/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1886, Test Acc: 95.04%
# Epoch 183/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1862, Test Acc: 95.03%
# Epoch 184/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1867, Test Acc: 95.09%
# Epoch 185/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1871, Test Acc: 95.12%
# Epoch 186/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1866, Test Acc: 95.05%
# Epoch 187/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1882, Test Acc: 95.14%
# Epoch 188/200: Train Loss: 0.0024, Train Acc: 99.98%, Test Loss: 0.1875, Test Acc: 95.00%
# Epoch 189/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1869, Test Acc: 95.11%
# Epoch 190/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1866, Test Acc: 95.11%
# Epoch 191/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1863, Test Acc: 95.14%
# Epoch 192/200: Train Loss: 0.0022, Train Acc: 99.98%, Test Loss: 0.1868, Test Acc: 95.01%
# Epoch 193/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1882, Test Acc: 95.15%
# Epoch 194/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1875, Test Acc: 95.09%
# Epoch 195/200: Train Loss: 0.0023, Train Acc: 99.98%, Test Loss: 0.1876, Test Acc: 95.08%
# Epoch 196/200: Train Loss: 0.0023, Train Acc: 99.99%, Test Loss: 0.1873, Test Acc: 95.11%
# Epoch 197/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1863, Test Acc: 95.13%
# Epoch 198/200: Train Loss: 0.0020, Train Acc: 99.99%, Test Loss: 0.1861, Test Acc: 95.08%
# Epoch 199/200: Train Loss: 0.0021, Train Acc: 99.99%, Test Loss: 0.1882, Test Acc: 95.02%
# Epoch 200/200: Train Loss: 0.0022, Train Acc: 99.99%, Test Loss: 0.1863, Test Acc: 95.13%
# Training completed! Best accuracy: 95.27%

# %%
# 评估模块，加载最佳模型并生成分类报告和混淆矩阵
# 评估
# 7.1 计算每个类别的准确率
def test_per_class(model, test_loader):
    model.eval()
    class_correct = list(0. for _ in range(10))
    class_total = list(0. for _ in range(10))
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(images)):
                label = labels[i].item()  # 转换为 Python 整数
                class_correct[label] += c[i].item()
                class_total[label] += 1
                
    for i in range(10):
        if class_total[i] > 0:
            print(f'Accuracy of {classes[i]:5s} : {100 * class_correct[i]/class_total[i]:2.0f}%')
        else:
            print(f'Accuracy of {classes[i]:5s} : N/A')


# 7.2 获取预测结果用于混淆矩阵和分类报告
def get_predictions(model, test_loader):
    model.eval()
    y_trues = []
    y_preds = []
    y_scores = []  # 用于ROC曲线的概率分数
    
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(DEVICE)
            logits = model(x)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = logits.argmax(dim=1).cpu()
            
            y_scores.append(probs)
            y_preds.extend(preds.numpy())
            y_trues.extend(y.numpy())
    
    y_scores = np.vstack(y_scores)
    return y_trues, y_preds, y_scores


# 7.3 生成混淆矩阵与分类报告
def evaluate_classification(model, test_loader):
    # 获取预测结果
    y_trues, y_preds, y_scores = get_predictions(model, test_loader)
    
    # 分类报告
    print("Classification Report:")
    print(classification_report(y_trues, y_preds, target_names=classes))
    
    # 混淆矩阵
    cm = confusion_matrix(y_trues, y_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=classes)
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
    
    return y_trues, y_preds, y_scores


# 7.4 绘制ROC曲线
'''
采用 One-vs-Rest 方法，对每个类分别绘制 ROC 曲线。
AUC 越高，说明该类的分类能力越强。
'''
def plot_roc_curve(y_trues, y_scores, classes):
    n_classes = len(classes)
    y_trues_bin = label_binarize(y_trues, classes=list(range(n_classes)))
    
    # 针对每一类画ROC
    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_trues_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {classes[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (one-vs-rest)')
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 使用新增函数进行评估
if __name__ == '__main__':
    # 加载最佳模型
    if os.path.exists('model/best_modelA1.pth'):
        checkpoint = torch.load('model/best_modelA1.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(DEVICE)
        
        print("\n=== 每个类别的准确率 ===")
        test_per_class(model, test_loader)
        
        print("\n=== 分类报告和混淆矩阵 ===")
        y_trues, y_preds, y_scores = evaluate_classification(model, test_loader)
        
        print("\n=== ROC曲线 ===")
        plot_roc_curve(y_trues, y_scores, classes)
    else:
        print("未找到最佳模型文件 'model/best_model.pth'，请先运行训练。")
# Out:
# === 每个类别的准确率 ===
# Accuracy of plane : 96%
# Accuracy of car   : 98%
# Accuracy of bird  : 94%
# Accuracy of cat   : 89%
# Accuracy of deer  : 97%
# Accuracy of dog   : 91%
# Accuracy of frog  : 97%
# Accuracy of horse : 97%
# Accuracy of ship  : 97%
# Accuracy of truck : 96%
#
# === 分类报告和混淆矩阵 ===
# Classification Report:
#               precision    recall  f1-score   support
#
#        plane       0.94      0.96      0.95      1000
#          car       0.97      0.98      0.97      1000
#         bird       0.95      0.94      0.95      1000
#          cat       0.90      0.89      0.90      1000
#         deer       0.96      0.97      0.96      1000
#          dog       0.92      0.91      0.91      1000
#         frog       0.97      0.97      0.97      1000
#        horse       0.97      0.97      0.97      1000
#         ship       0.97      0.97      0.97      1000
#        truck       0.97      0.96      0.97      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
# === ROC曲线 ===
